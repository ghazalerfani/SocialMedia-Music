# %% [markdown]
# This notebook combines all the raw social media data and creates a single formatted notebook to be used for further processing. The output of the notebook is a pickle file.

# %% [markdown]
# ## Import Statements

# %%
# Imports
import glob
import pandas as pd
from collections import Counter
import numpy as np
import time
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import OneHotEncoder
import warnings
from datetime import datetime, date
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Helper Functions

# %%
def createFileFileLocationDict():
    '''
        This function creates a dictionary that stores the mapping between 
        the file and its location. It assumes the base directory for the file
        path to be same as the current directory from where the python notebook is
        being run
    '''
    filemap = {}
    filemap['master_artist_list'] = './Data/RawData/Artists/master_artists_list.csv'
    filemap['facebook_data'] = './Data/RawData/Facebook/*.csv'
    filemap['twitter_data'] = './Data/RawData/Twitter/*.csv'
    filemap['instagram_data'] = './Data/RawData/Instagram/*.csv'
    filemap['youtube_data'] = './Data/RawData/Youtube/youtube_to_combine.csv'
    filemap['music_brainz_data'] = './Data/RawData/MusicBrainz/musicbrainz_data.csv'
    
    return filemap

# %%
def readMasterArtistFile(master_artist_file_location):
    '''
        This function takes the master artist file location
        as a parameter and returns a dataframe with the 
        contents of the master artists file
    '''
    # Read master artists file and store in data frame
    artists = pd.read_csv(master_artist_file_location,encoding="ISO-8859-1")
    
    return artists

# %%
def time_of_day_creation(x):
    '''
    Takes in an integer and returns one of four time slots:
    ['12am-6am', '6am-12pm', '12pm-6pm', '6pm-12am']
    '''
    
    slots_out = ['created_12am-6am', 'created_6am-12pm', 'created_12pm-6pm', 'created_6pm-12am']
    slot0 = np.arange(0,6)
    slot1 = np.arange(6,12)
    slot2 = np.arange(12,18)
    slot3 = np.arange(18,24)

    if x in slot0:
        return slots_out[0]
    elif x in slot1:
        return slots_out[1]
    elif x in slot2:
        return slots_out[2]
    elif x in slot3:
        return slots_out[3]
    else:
        return 'NaN'

# %%
def calculateRollupPosts(social_media_df,social_media_type, social_media_handle_field, master_artist_file):
    '''
        This function takes 3 parameters:
        1. The dataframe containing raw data of a social platform
        2. The type pf social media account (facebook, twitter, instagram or youtube)
        3. The field name that stores the social media handle of the platform
        
        The function computes the aggregated number of posts by the artist on the platform in the last 7 days and last 30 days
        
        The funcion outputs the modified dataframe with the aggregated number of posts
    '''
    
    time_range = pd.date_range(start='1/1/2016', end='6/30/2019', freq='d').to_frame(index=False)
    time_range.rename(columns={0: 'Time Period'}, inplace=True)
    master_artists_list = pd.read_csv(master_artist_file, usecols=[social_media_type])
    time_range['join_key'] = 0
    master_artists_list['join_key'] = 0
    artists_time_range = master_artists_list.merge(time_range, how='left', on = 'join_key')
    artists_time_range.drop('join_key',1, inplace=True)
    artists_time_range.rename(columns={0: 'Time Period'}, inplace=True)
    social_media_df['Created_Day'] = social_media_df.created.dt.floor('d')
    df_aggregate = social_media_df.groupby([social_media_handle_field, 'Created_Day'], as_index=False).agg({"created": "count"})
    df_aggregate.rename(columns={'created': 'Posts In Day'}, inplace=True)
    df_merged = artists_time_range.merge(df_aggregate, how='left', left_on=[social_media_type,'Time Period'], right_on=[social_media_handle_field,'Created_Day'])
    df_merged['Posts In Day'] = df_merged['Posts In Day'].fillna(0)
    df_merged['last_7_days'] = df_merged[['Posts In Day']].groupby(df_merged[social_media_type]).apply(lambda g: g.rolling(7, min_periods=1).sum())
    df_merged['last_30_days'] = df_merged[['Posts In Day']].groupby(df_merged[social_media_type]).apply(lambda g: g.rolling(30, min_periods=1).sum())
    df_merged.drop(columns=[social_media_handle_field, 'Created_Day','Posts In Day'], inplace=True)
    social_media_df = social_media_df.merge(df_merged, how='left', right_on=[social_media_type,'Time Period'], left_on=[social_media_handle_field,'Created_Day'])
    social_media_df.drop(columns=[social_media_type, 'Time Period','Created_Day'], inplace=True)
    
    return social_media_df

# %%
def read_and_clean_facebook(facebook_directory, master_artist_file):
    '''
    Reads in all Facebook files from Data/RawData/Facebook folder into pandas dataframe.
    Reads the master artist list from Data/RawData/Artists folder.
    
    Filters the dataframe to necessary columns. 
    Converts columns into appropriate data types.
    Creates new custom columns based on current columns.
    Creates dummy features on categorical columns.
    
    Returns a dataframe that can then be exported, used for Exploratory Data Analysis, modeling, or 
    combination with other social media platform data that shares the same format (Twitter, Instagram, Youtube). 
    '''
    
    #Loads the Facebook files into a list of files and concatenates into a dataframe
    files = glob.glob(facebook_directory)
    df_list = [pd.read_csv(file, encoding="ISO-8859-1") for file in files]
    df = pd.concat(df_list)
    
    #Field descriptions are available here: https://github.com/CrowdTangle/API/wiki/Post
    
    #Reduce the number of features in the dataframe
    selected_columns = ['User Name', 'Page Likes at Posting', 'Created', 'Type', 
                        'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 
                        'Angry', 'Thankful', 'Message', 'Score']
    df = df[selected_columns]
    
    #Convert the date of posting to datetime
    df['Created'] = pd.to_datetime(df['Created']).dt.tz_localize(None)

    #Convert Message Description to a string
    df['Description'] = df['Message'].astype(str)
    
    #Create custom feature that counts the number of characters in a post
    df['description_length'] = df['Description'].apply(len)
    
    #Create custom feature that counts the number of hashtags in a post
    df['hashtag_count'] = df['Description'].apply(lambda x : x.count('#'))
    
    #Creates a custom feature that calculates the Social Engagement Score for Facebook
    df['social_engagement_score'] = (df['Likes'] + df['Comments'] + df['Shares'] + df['Love'] + df['Wow'] + df['Haha'] + df['Sad'] + df['Angry'] + df['Thankful']) / df['Page Likes at Posting']
    
    #These are the types of Facebook posts
    types = ['Photo', 'Link', 'Status', 'Native Video', 'YouTube', 'Video', 'Live Video Complete', 'Vine', 'Live Video', 'Live Video Scheduled']
    #Combine Photo and Album into one type
    df.loc[df.Type == 'Status', 'Type'] = "Text"
    df.loc[df.Type.isin(['Native Video', 'YouTube', 'Video', 'Live Video Complete', 'Vine', 'Live Video', 'Live Video Scheduled']),  'Type'] = "Video"
    
    #Creates dummy features for the Type column
    df = pd.concat([df,pd.get_dummies(df['Type'],prefix='type')],axis=1)
    
    #Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
    df['time_of_day'] = df['Created'].apply(lambda x : time_of_day_creation(x.hour))
        
    #Creates dummy features for the time of day column
    df = pd.concat([df,pd.get_dummies(df['time_of_day'])],axis=1)
      
    #Creates new feature to calculate the time between this post and the previous post, by user
    df.sort_values(by=['User Name','Created'], inplace=True)
    df['time_since_last_post'] = df.groupby('User Name')['Created'].diff()
    
    #Dropping columns no longer required
    df.drop(['Message', 'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Thankful','time_of_day', 'Type'],axis=1,inplace=True)    
    
    #Rename the columns to align with format used in master dataframe (Youtube+Twitter+Instagram+Facebook)
    df.rename(columns={'Description':'description', 'Score': 'crowdtangle_score',
                           'Page Likes at Posting': 'count_of_followers', 'User Name':'artist_name',
                           'Created': 'created', 'type_Video': 'type_video','type_Photo':'type_photo',
                           'type_Link':'type_link', 'type_Text':'type_text'
                           },inplace=True)
    
    #Placeholder columns
    df['within_week_release'] = 0 
    df['within_month_release'] = 0 
    
    # Columns to indicate type of social platform
    df['Facebook'] = 1
    df['Instagram'] = 0
    df['Twitter'] = 0
    df['Youtube'] = 0
    
    #Creates features to count the number of posts in last 7,30 days 
    df = calculateRollupPosts(df,'facebook','artist_name',master_artist_file)
    
    #Drops artists that are not used in this version of music analysis
    artists_to_remove = ['carlosvives', 'mirandalambert', 'bradpaisley', 'thetimmcgraw',
                     'chrisyoungmusic', 'lukecombs', 'willienelsonofficial']
    df = df[~df['artist_name'].isin(artists_to_remove)]
    
    df.reset_index(inplace=True, drop=True)
    
    return df

# %%
def read_and_clean_instagram(instagram_directory, master_artist_file):
    '''
    Reads in all Instagram files from Data/RawData/Instagram into a pandas dataframe.
    Reads the master artist list from Data/RawData/Artists folder
    
    Filters the dataframe to necessary columns. 
    Converts columns into appropriate data types.
    Creates new custom columns based on current columns.
    Creates dummy features on categorical columns.
    
    Returns a dataframe that can then be exported, used for Exploratory Data Analysis, modeling, or 
    combination with other social media platform data that shares the same format (Twitter, Facebook, Youtube). 
    '''
    
    #Loads the Instagram files into a list of files and concatenates into a dataframe
    files = glob.glob(instagram_directory)
    df_list = [pd.read_csv(file,encoding="ISO-8859-1") for file in files]
    df = pd.concat(df_list)
    
    #Field descriptions are available here: https://github.com/CrowdTangle/API/wiki/Post
    
    #Reduce the number of features in the dataframe
    selected_columns = ['User Name', 'Followers at Posting', 'Created', 'Type', 
                        'Likes', 'Comments', 'Views', 'Description','Score']
    df = df[selected_columns]
    
    #Convert the date of posting to datetime
    df['Created'] = pd.to_datetime(df['Created']).dt.tz_localize(None)
    
    #Convert Description to a string
    df['Description'] = df['Description'].astype(str)
    
    #Create custom feature that counts the number of characters in a post
    df['description_length'] = df['Description'].apply(len)
    
    #Create custom feature that counts the number of hashtags in a post
    df['hashtag_count'] = df['Description'].apply(lambda x : x.count('#'))
    
    #Creates a custom feature that calculates the Social Engagement Score for Instagram
    df['social_engagement_score'] = (df['Likes'] + df['Comments']) / df['Followers at Posting']
    
    #These are the three types of Instagram posts
    types = ['Photo', 'Video', 'Album']
    #Combine Photo and Album into one type
    df.loc[df.Type == 'Album', 'Type'] = "Photo"
    
    #Creates dummy features for the Type column
    df = pd.concat([df,pd.get_dummies(df['Type'],prefix='type')],axis=1)
    
    #Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
    df['time_of_day'] = df['Created'].apply(lambda x : time_of_day_creation(x.hour))
        
    #Creates dummy features for the time of day column
    df = pd.concat([df,pd.get_dummies(df['time_of_day'])],axis=1)
      
    #Creates new feature to calculate the time between this post and the previous post, by user
    df.sort_values(by=['User Name','Created'], inplace=True)
    df['time_since_last_post'] = df.groupby('User Name')['Created'].diff()
    
    #Dropping columns no longer required
    df.drop(['Likes','Comments','Views','time_of_day','Type'],axis=1,inplace=True)    
    
    #Rename the columns to align with format used in master dataframe (Youtube+Twitter+Instagram+Facebook)
    df.rename(columns={'Description':'description', 'Score': 'crowdtangle_score',
                           'Followers at Posting': 'count_of_followers', 'User Name':'artist_name',
                           'Created': 'created', 'type_Video': 'type_video','type_Photo':'type_photo'
                           },inplace=True)
    
    #Placeholder columns
    df['type_text'] = 0
    df['type_link'] = 0
    df['within_week_release'] = 0 
    df['within_month_release'] = 0 
    
    # Columns to indicate type of social platform
    df['Facebook'] = 0
    df['Instagram'] = 1
    df['Twitter'] = 0
    df['Youtube'] = 0
    
    #Creates features to count the number of posts in last 7,30 days 
    df = calculateRollupPosts(df,'instagram','artist_name',master_artist_file)
    
    #Drops artists that are not used in this version of music analysis
    artists_to_remove = ['carlosvives', 'mirandalambert', 'bradpaisley', 'thetimmcgraw',
                     'chrisyoungmusic', 'lukecombs', 'willienelsonofficial']
    df = df[~df['artist_name'].isin(artists_to_remove)]
    
    df.reset_index(inplace=True, drop=True)
    
    return df

# %%
def read_and_clean_twitter(twitter_directory, master_artist_file):
    '''
    Reads in all Twitter files from Data/RawData/Twitter into a pandas dataframe.
    Reads the master artist list from Data/RawData/Artists folder
    
    Filters the dataframe to necessary columns. 
    Converts columns into appropriate data types.
    Creates new custom columns based on current columns.
    Creates dummy features on categorical columns.
    
    Returns a dataframe that can then be exported, used for Exploratory Data Analysis, modeling, or 
    combination with other social media platform data that shares the same format (Twitter, Facebook, Youtube). 
    '''
    
    #Loads the Instagram files into a list of files and concatenates into a dataframe
    files = glob.glob(twitter_directory)
    df_list = [pd.read_csv(file,encoding="ISO-8859-1") for file in files]
    df = pd.concat(df_list)
    
    #Field descriptions are available here: https://github.com/CrowdTangle/API/wiki/Post
    
    #Reduce the number of features in the dataframe
    selected_columns = ['User Name', 'Followers at Posting', 'Created', 'Type', 
                        'Likes', 'Retweets','Message','Score']
    df = df[selected_columns]
    df = df.dropna()
    df = df.reset_index(drop = True)
    
    #Convert the date of posting to datetime
    df['Created'] = pd.to_datetime(df['Created']).dt.tz_localize(None)
    
    #Reset the index
    df.reset_index(inplace=True)
    
    #Number of characters in message custom feature
    df['message_length'] = df['Message'].apply(len)
    
    #Number of hashtags custom feature
    df['hashtag_count'] = df.apply(lambda x: x['Message'].count('#'), axis=1)
    
    # Reclassify some of the post types
    df.loc[df['Type'] == 'Vine', 'Type'] = 'Video'
    df.loc[df['Type'] == 'Native Video', 'Type'] = 'Video'
    
    #OHE for Type Field
    df = pd.concat([df,pd.get_dummies(df['Type'],prefix='type')],axis=1)
    
    #Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
    df['time_of_day'] = df['Created'].apply(lambda x : time_of_day_creation(x.hour))

    #OHE for time of day field
    df = pd.concat([df,pd.get_dummies(df['time_of_day'],prefix='tod')],axis=1)

    df.sort_values(by=['User Name','Created'], inplace=True)
    
    #Time between prior and current post
    df['time_since_last_post'] = df.groupby('User Name')['Created'].diff()
    
    df['within_week_release'] = 0
    df['within_month_release'] = 0
    
    # Columns to indicate type of social platform
    df['Facebook'] = 0
    df['Instagram'] = 0
    df['Twitter'] = 1
    df['Youtube'] = 0
    
    # Calculating social engagement score
    df['social_engagement_score'] = df.apply(lambda x: (x['Likes'] + x['Retweets']) / x['Followers at Posting'], axis=1)
    
    df = df.drop(['Type','Likes', 'Retweets','time_of_day','index'], axis=1)
    
    # Rename columns
    df.rename(columns={"Created": "created",
                            "Message": "description",
                            "Score":"crowdtangle_score", 
                            "Followers at Posting" : "count_of_followers",
                            "tod_12am-6am" : "created_12am-6am",
                            "tod_6am-12pm" : "created_6am-12pm",
                            "tod_12pm-6pm" : "created_12pm-6pm",
                            "tod_6pm-12am" : "created_6pm-12am",
                            "User Name" : "artist_name",
                            "message_length":"description_length",
                            "type_Photo":"type_photo",
                            "type_Tweet":"type_text",
                            "type_Video":"type_video",
                            "type_Link":"type_link"
                           }, inplace=True)
    
    # Calculate number of posts by artist on the platform in last 7 and 30 days
    df = calculateRollupPosts(df,'twitter','artist_name',master_artist_file)
    
    #Removing the 7 artists
    artists_to_remove = ['carlosvives', 'mirandalambert', 'BradPaisley', 'TheTimMcGraw',
                     'ChrisYoungMusic', 'lukecombs', 'WillieNelson']
    df = df[~df['artist_name'].isin(artists_to_remove)]
    
    df.reset_index(inplace=True, drop=True)
    
    return df

# %%
def read_and_clean_youtube(youtube_directory):
    '''
        This function reads the cleaned version of the youtube file
        and computes the social enagagement score for Youtube
    '''
    
    youtube_df = pd.read_csv(youtube_directory,encoding="ISO-8859-1")
    youtube_df = youtube_df.drop("Unnamed: 0",axis=1)
    youtube_df = youtube_df.drop("Unnamed: 0.1",axis=1)
    youtube_df = youtube_df.drop("hour",axis=1)
    
    youtube_df.rename(columns={"artist_name_x":"artist_name"}, inplace=True)
    
    # Columns to indicate type of social platform
    youtube_df['Facebook'] = 0
    youtube_df['Instagram'] = 0
    youtube_df['Twitter'] = 0
    youtube_df['Youtube'] = 1
    
    #Removing the 7 artists
    artists_to_remove = ['carlosvives', 'mirandalambert', 'BradPaisley', 'TheTimMcGraw',
                     'ChrisYoungMusic', 'lukecombs', 'WillieNelson']
    youtube_df = youtube_df[~youtube_df['artist_name'].isin(artists_to_remove)]
    
    youtube_df.reset_index(inplace=True, drop=True)
    
    return youtube_df

# %%
# Get the social platform name for each dataframe row
def getSocialPlatform(x):
    '''
        Function to return the social platform of the post
    '''
    if x['Facebook'] == 1:
        return 'Facebook'
    elif x['Instagram'] == 1:
        return 'Instagram'
    elif x['Twitter'] == 1:
        return 'Twitter'
    else:
        return 'Youtube'

# %%
from datetime import datetime
def days_between(d1, d2):
    '''
        Function to find days between 2 datetimes
    '''
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs((d2 - d1).days)

# %%
# Function to find the minimum difference of days w.r.t. all release dates of an artist
def find_min_diff(artist_name,created,artist_dict):
    '''
        Function to find the minimum difference of days w.r.t. all release dates of an artist
    '''
    lst = artist_dict[artist_name]
    min_days = min([days_between(x.strftime('%Y-%m-%d'),created.strftime('%Y-%m-%d')) for x in lst])
    return min_days

# %%
def calculate_youtube_score(df):
    '''
        Calculates the social engagement score for YouTube
        This function takes the combined social data dataframe
        and updates the social engagement field for YouTube data
    '''
    df = df.sort_values(by=['artist_name_x','created'])
    for i in range(1,len(df)):
        if (i+1)%200==0:
            print(str(i+1)+ ' has been completed!')
        facebook = 0
        fflag = False
        twitter = 0
        tflag = False
        ins = 0
        insflag = False
        if df['Youtube'][i] == 1:
            for j in range(i-1,-1,-1):
                if df['artist_name_x'][i]!=df['artist_name_x'][j]:
                    break
                if fflag & tflag & insflag:
                    break
                if (not fflag) & (df['Facebook'][j]==1):
                    fflag=True
                    facebook = df["count_of_followers"][j]
                if (not tflag) & (df['Twitter'][j]==1):
                    tflag=True
                    twitter = df["count_of_followers"][j]
                if (not insflag) & (df['Instagram'][j]==1):
                    insflag=True
                    ins = df["count_of_followers"][j]
            cal = np.max([facebook,twitter,ins])
            if np.isnan(np.max([facebook,twitter,ins])):
                cal = 0
            if cal != 0:
                print('Calculated: '+ str(cal))
            df['count_of_followers'][i]=cal
            try:
                df['social_engagement_score'][i]=df['social_engagement_score'][i]/df['count_of_followers'][i]
            except:
                df['social_engagement_score'][i] = 0
    return df

# %% [markdown]
# ## Main Function

# %%
from datetime import datetime
def createCombinedSocialMediaFile():
    '''
        This is the main function of the notebook that creates a combined
        social media data pickle file
    '''
    
    print("Starting the process to combine the social media data...")
    
    # Create a dictionary to store file names and their locations
    file_file_location_dict = createFileFileLocationDict()
    
    print("Reading master artists file...")
    
    # Read the master artists file
    artists = readMasterArtistFile(file_file_location_dict['master_artist_list'])
    
    print("Reading and cleaning Facebook Data...")
    # Read and clean facebook data and then merge it with master artist file
    fb_data = read_and_clean_facebook(file_file_location_dict['facebook_data'], file_file_location_dict['master_artist_list'])
    fb_data = fb_data.merge(artists, left_on='artist_name', right_on='facebook')
    print('Number of facebook records' + str(fb_data.shape))
    
    print("Reading and cleaning Instagram Data...")
    # Read and clean instagram data and then merge it with master artist file
    instagram_data = read_and_clean_instagram(file_file_location_dict['instagram_data'], file_file_location_dict['master_artist_list'])
    instagram_data = instagram_data.merge(artists, left_on='artist_name', right_on='instagram')
    print('Number of instagram records' + str(instagram_data.shape))
    
    print("Reading and cleaning Twitter Data...")
    # Read and clean twitter data and then merge it with master artist file
    twitter_data = read_and_clean_twitter(file_file_location_dict['twitter_data'], file_file_location_dict['master_artist_list'])
    twitter_data = twitter_data.merge(artists, left_on='artist_name', right_on='twitter')
    print('Number of twitter records' + str(twitter_data.shape))
    
    print("Reading and cleaning Youtube Data...")
    # Read and clean youtube data and then merge it with combined social data dataframe
    youtube_data = read_and_clean_youtube(file_file_location_dict['youtube_data']) 
    youtube_data = youtube_data.merge(artists, left_on='artist_name', right_on='youtube')
    print('Number of youtube records' + str(youtube_data.shape))
    
    print("Combining Social Media Data...")
    # Combine all the data
    df = pd.concat([fb_data,instagram_data,twitter_data,youtube_data])
    
    # Remove records prior to 2016
    start_date = pd.Timestamp('2016-01-01')
    end_date = pd.Timestamp('2019-06-30')
    df['created'] = pd.to_datetime(df['created'])
    df = df[df['created'].between(start_date, end_date)]
    print('Number of records in dataframe :' + str(df.shape[0]))
    
    # Reset index
    df.reset_index(inplace=True, drop=True)
    
    print("Calculating Social Engagement Score for YouTube")
    # calculate youtube social engagement score here
    df = calculate_youtube_score(df)
    
    # Create social platform column
    df['social_platform'] = df.apply(lambda x: getSocialPlatform(x), axis = 1)
    
    # Filtering outliers in FB data
    df = df[~((df['Facebook'] == 1) & (df['social_engagement_score'] > 1))]
    
    print("Integrating MusicBrainz Data...")
    # Get the mean & standard deviation of social engagement scores per platform and store the results in 3 dictionaries
    dict_platform_mean = df.groupby('social_platform')['social_engagement_score'].mean().to_dict()
    dict_platform_std = df.groupby('social_platform')['social_engagement_score'].std().to_dict()
    
    # Normalize the social engagement scores
    df['normalized_social_engagement_score'] = df.apply(lambda x: (x['social_engagement_score'] - dict_platform_mean[x['social_platform']]) / dict_platform_std[x['social_platform']],axis=1)
    
    # Reading music Brainz data and removing unwanted column
    df_musicbrainz = pd.read_csv(file_file_location_dict['music_brainz_data'],encoding="ISO-8859-1")
    df_musicbrainz = df_musicbrainz.drop("Unnamed: 0",axis=1)
    
    # Converting the type of release_date to datettime for date comparisons
    df_musicbrainz['release_date'] = pd.to_datetime(df_musicbrainz['release_date'])
    
    # Filter the release dates before Jan 1st 2006
    df_musicbrainz = df_musicbrainz[df_musicbrainz['release_date'] > date(2006,1,1)]
    
    # Convert master data 'created' column to datetime for date comparisons
    df['created'] = pd.to_datetime(df['created']).dt.tz_localize(None)
    
    # Filter records prior to 2016
    df = df[df['created'] > date(2006,1,1)]

    artist_dict = df_musicbrainz.groupby('artist_name')['release_date'].apply(list).to_dict()
    
    print("Computing Number of Days To Track Release...")
    df['num_days_to_track_release'] = df.apply(lambda x: find_min_diff(x['artist_name_y'],x['created'],artist_dict),axis=1)
    
    return df

# %%
df = createCombinedSocialMediaFile()
# Out:
# Starting the process to combine the social media data...
# Reading master artists file...
# Reading and cleaning Facebook Data...
# Number of facebook records(311188, 39)
# Reading and cleaning Instagram Data...
# Number of instagram records(425000, 39)
# Reading and cleaning Twitter Data...
# Number of twitter records(324396, 39)
# Reading and cleaning Youtube Data...
# Number of youtube records(34536, 39)
# Combining Social Media Data...
# Number of records in dataframe :693237
# Calculating Social Engagement Score for YouTube
# 200 has been completed!
# 400 has been completed!
# 600 has been completed!
# 800 has been completed!
# 1000 has been completed!
# 1200 has been completed!
# 1400 has been completed!
# 1600 has been completed!
# 1800 has been completed!
# 2000 has been completed!
# 2200 has been completed!
# 2400 has been completed!
# 2600 has been completed!
# 2800 has been completed!
# 3000 has been completed!
# 3200 has been completed!
# 3400 has been completed!
# 3600 has been completed!
# 3800 has been completed!
# 4000 has been completed!
# 4200 has been completed!
# 4400 has been completed!
# 4600 has been completed!
# 4800 has been completed!
# 5000 has been completed!
# 5200 has been completed!
# 5400 has been completed!
# 5600 has been completed!
# 5800 has been completed!
# 6000 has been completed!
# 6200 has been completed!
# 6400 has been completed!
# 6600 has been completed!
# 6800 has been completed!
# 7000 has been completed!
# 7200 has been completed!
# 7400 has been completed!
# 7600 has been completed!
# 7800 has been completed!
# 8000 has been completed!
# 8200 has been completed!
# 8400 has been completed!
# 8600 has been completed!
# 8800 has been completed!
# 9000 has been completed!
# 9200 has been completed!
# 9400 has been completed!
# 9600 has been completed!
# 9800 has been completed!
# 10000 has been completed!
# 10200 has been completed!
# 10400 has been completed!
# 10600 has been completed!
# 10800 has been completed!
# 11000 has been completed!
# 11200 has been completed!
# 11400 has been completed!
# 11600 has been completed!
# 11800 has been completed!
# 12000 has been completed!
# 12200 has been completed!
# 12400 has been completed!
# 12600 has been completed!
# 12800 has been completed!
# 13000 has been completed!
# 13200 has been completed!
# 13400 has been completed!
# 13600 has been completed!
# 13800 has been completed!
# 14000 has been completed!
# 14200 has been completed!
# 14400 has been completed!
# 14600 has been completed!
# 14800 has been completed!
# 15000 has been completed!
# 15200 has been completed!
# 15400 has been completed!
# 15600 has been completed!
# 15800 has been completed!
# 16000 has been completed!
# 16200 has been completed!
# 16400 has been completed!
# 16600 has been completed!
# 16800 has been completed!
# 17000 has been completed!
# 17200 has been completed!
# 17400 has been completed!
# 17600 has been completed!
# 17800 has been completed!
# 18000 has been completed!
# 18200 has been completed!
# 18400 has been completed!
# 18600 has been completed!
# 18800 has been completed!
# 19000 has been completed!
# 19200 has been completed!
# 19400 has been completed!
# 19600 has been completed!
# 19800 has been completed!
# 20000 has been completed!
# 20200 has been completed!
# 20400 has been completed!
# 20600 has been completed!
# 20800 has been completed!
# 21000 has been completed!
# 21200 has been completed!
# 21400 has been completed!
# 21600 has been completed!
# 21800 has been completed!
# 22000 has been completed!
# 22200 has been completed!
# 22400 has been completed!
# 22600 has been completed!
# 22800 has been completed!
# 23000 has been completed!
# 23200 has been completed!
# 23400 has been completed!
# 23600 has been completed!
# 23800 has been completed!
# 24000 has been completed!
# 24200 has been completed!
# 24400 has been completed!
# 24600 has been completed!
# 24800 has been completed!
# 25000 has been completed!
# 25200 has been completed!
# 25400 has been completed!
# 25600 has been completed!
# 25800 has been completed!
# 26000 has been completed!
# 26200 has been completed!
# 26400 has been completed!
# 26600 has been completed!
# 26800 has been completed!
# 27000 has been completed!
# 27200 has been completed!
# 27400 has been completed!
# 27600 has been completed!
# 27800 has been completed!
# 28000 has been completed!
# 28200 has been completed!
# 28400 has been completed!
# 28600 has been completed!
# 28800 has been completed!
# 29000 has been completed!
# 29200 has been completed!
# 29400 has been completed!
# 29600 has been completed!
# 29800 has been completed!
# 30000 has been completed!
# 30200 has been completed!
# 30400 has been completed!
# 30600 has been completed!
# 30800 has been completed!
# 31000 has been completed!
# 31200 has been completed!
# 31400 has been completed!
# 31600 has been completed!
# 31800 has been completed!
# 32000 has been completed!
# 32200 has been completed!
# 32400 has been completed!
# 32600 has been completed!
# 32800 has been completed!
# 33000 has been completed!
# 33200 has been completed!
# 33400 has been completed!
# 33600 has been completed!
# 33800 has been completed!
# 34000 has been completed!
# 34200 has been completed!
# 34400 has been completed!
# 34600 has been completed!
# 34800 has been completed!
# 35000 has been completed!
# 35200 has been completed!
# 35400 has been completed!
# 35600 has been completed!
# 35800 has been completed!
# 36000 has been completed!
# 36200 has been completed!
# 36400 has been completed!
# 36600 has been completed!
# 36800 has been completed!
# 37000 has been completed!
# 37200 has been completed!
# 37400 has been completed!
# 37600 has been completed!
# 37800 has been completed!
# 38000 has been completed!
# 38200 has been completed!
# 38400 has been completed!
# 38600 has been completed!
# 38800 has been completed!
# 39000 has been completed!
# 39200 has been completed!
# 39400 has been completed!
# 39600 has been completed!
# 39800 has been completed!
# 40000 has been completed!
# 40200 has been completed!
# 40400 has been completed!
# 40600 has been completed!
# 40800 has been completed!
# 41000 has been completed!
# 41200 has been completed!
# 41400 has been completed!
# 41600 has been completed!
# 41800 has been completed!
# 42000 has been completed!
# 42200 has been completed!
# 42400 has been completed!
# 42600 has been completed!
# 42800 has been completed!
# 43000 has been completed!
# 43200 has been completed!
# 43400 has been completed!
# 43600 has been completed!
# 43800 has been completed!
# 44000 has been completed!
# 44200 has been completed!
# 44400 has been completed!
# 44600 has been completed!
# 44800 has been completed!
# 45000 has been completed!
# 45200 has been completed!
# 45400 has been completed!
# 45600 has been completed!
# 45800 has been completed!
# 46000 has been completed!
# 46200 has been completed!
# 46400 has been completed!
# 46600 has been completed!
# 46800 has been completed!
# 47000 has been completed!
# 47200 has been completed!
# 47400 has been completed!
# 47600 has been completed!
# 47800 has been completed!
# 48000 has been completed!
# 48200 has been completed!
# 48400 has been completed!
# 48600 has been completed!
# 48800 has been completed!
# 49000 has been completed!
# 49200 has been completed!
# 49400 has been completed!
# 49600 has been completed!
# 49800 has been completed!
# 50000 has been completed!
# 50200 has been completed!
# 50400 has been completed!
# 50600 has been completed!
# 50800 has been completed!
# 51000 has been completed!
# 51200 has been completed!
# 51400 has been completed!
# 51600 has been completed!
# 51800 has been completed!
# 52000 has been completed!
# 52200 has been completed!
# 52400 has been completed!
# 52600 has been completed!
# 52800 has been completed!
# 53000 has been completed!
# 53200 has been completed!
# 53400 has been completed!
# 53600 has been completed!
# 53800 has been completed!
# 54000 has been completed!
# 54200 has been completed!
# 54400 has been completed!
# 54600 has been completed!
# 54800 has been completed!
# 55000 has been completed!
# 55200 has been completed!
# 55400 has been completed!
# 55600 has been completed!
# 55800 has been completed!
# 56000 has been completed!
# 56200 has been completed!
# 56400 has been completed!
# 56600 has been completed!
# 56800 has been completed!
# 57000 has been completed!
# 57200 has been completed!
# 57400 has been completed!
# 57600 has been completed!
# 57800 has been completed!
# 58000 has been completed!
# 58200 has been completed!
# 58400 has been completed!
# 58600 has been completed!
# 58800 has been completed!
# 59000 has been completed!
# 59200 has been completed!
# 59400 has been completed!
# 59600 has been completed!
# 59800 has been completed!
# 60000 has been completed!
# 60200 has been completed!
# 60400 has been completed!
# 60600 has been completed!
# 60800 has been completed!
# 61000 has been completed!
# 61200 has been completed!
# 61400 has been completed!
# 61600 has been completed!
# 61800 has been completed!
# 62000 has been completed!
# 62200 has been completed!
# 62400 has been completed!
# 62600 has been completed!
# 62800 has been completed!
# 63000 has been completed!
# 63200 has been completed!
# 63400 has been completed!
# 63600 has been completed!
# 63800 has been completed!
# 64000 has been completed!
# 64200 has been completed!
# 64400 has been completed!
# 64600 has been completed!
# 64800 has been completed!
# 65000 has been completed!
# 65200 has been completed!
# 65400 has been completed!
# 65600 has been completed!
# 65800 has been completed!
# 66000 has been completed!
# 66200 has been completed!
# 66400 has been completed!
# 66600 has been completed!
# 66800 has been completed!
# 67000 has been completed!
# 67200 has been completed!
# 67400 has been completed!
# 67600 has been completed!
# 67800 has been completed!
# 68000 has been completed!
# 68200 has been completed!
# 68400 has been completed!
# 68600 has been completed!
# 68800 has been completed!
# 69000 has been completed!
# 69200 has been completed!
# 69400 has been completed!
# 69600 has been completed!
# 69800 has been completed!
# 70000 has been completed!
# 70200 has been completed!
# 70400 has been completed!
# 70600 has been completed!
# 70800 has been completed!
# 71000 has been completed!
# 71200 has been completed!
# 71400 has been completed!
# 71600 has been completed!
# 71800 has been completed!
# 72000 has been completed!
# 72200 has been completed!
# 72400 has been completed!
# 72600 has been completed!
# 72800 has been completed!
# 73000 has been completed!
# 73200 has been completed!
# 73400 has been completed!
# 73600 has been completed!
# 73800 has been completed!
# 74000 has been completed!
# 74200 has been completed!
# 74400 has been completed!
# 74600 has been completed!
# 74800 has been completed!
# 75000 has been completed!
# 75200 has been completed!
# 75400 has been completed!
# 75600 has been completed!
# 75800 has been completed!
# 76000 has been completed!
# 76200 has been completed!
# 76400 has been completed!
# 76600 has been completed!
# 76800 has been completed!
# 77000 has been completed!
# 77200 has been completed!
# 77400 has been completed!
# 77600 has been completed!
# 77800 has been completed!
# 78000 has been completed!
# 78200 has been completed!
# 78400 has been completed!
# 78600 has been completed!
# 78800 has been completed!
# 79000 has been completed!
# 79200 has been completed!
# 79400 has been completed!
# 79600 has been completed!
# 79800 has been completed!
# 80000 has been completed!
# 80200 has been completed!
# 80400 has been completed!
# 80600 has been completed!
# 80800 has been completed!
# 81000 has been completed!
# 81200 has been completed!
# 81400 has been completed!
# 81600 has been completed!
# 81800 has been completed!
# 82000 has been completed!
# 82200 has been completed!
# 82400 has been completed!
# 82600 has been completed!
# 82800 has been completed!
# 83000 has been completed!
# 83200 has been completed!
# 83400 has been completed!
# 83600 has been completed!
# 83800 has been completed!
# 84000 has been completed!
# 84200 has been completed!
# 84400 has been completed!
# 84600 has been completed!
# 84800 has been completed!
# 85000 has been completed!
# 85200 has been completed!
# 85400 has been completed!
# 85600 has been completed!
# 85800 has been completed!
# 86000 has been completed!
# 86200 has been completed!
# 86400 has been completed!
# 86600 has been completed!
# 86800 has been completed!
# 87000 has been completed!
# 87200 has been completed!
# 87400 has been completed!
# 87600 has been completed!
# 87800 has been completed!
# 88000 has been completed!
# 88200 has been completed!
# 88400 has been completed!
# 88600 has been completed!
# 88800 has been completed!
# 89000 has been completed!
# 89200 has been completed!
# 89400 has been completed!
# 89600 has been completed!
# 89800 has been completed!
# 90000 has been completed!
# 90200 has been completed!
# 90400 has been completed!
# 90600 has been completed!
# 90800 has been completed!
# 91000 has been completed!
# 91200 has been completed!
# 91400 has been completed!
# 91600 has been completed!
# 91800 has been completed!
# 92000 has been completed!
# 92200 has been completed!
# 92400 has been completed!
# 92600 has been completed!
# 92800 has been completed!
# 93000 has been completed!
# 93200 has been completed!
# 93400 has been completed!
# 93600 has been completed!
# 93800 has been completed!
# 94000 has been completed!
# 94200 has been completed!
# 94400 has been completed!
# 94600 has been completed!
# 94800 has been completed!
# 95000 has been completed!
# 95200 has been completed!
# 95400 has been completed!
# 95600 has been completed!
# 95800 has been completed!
# 96000 has been completed!
# 96200 has been completed!
# 96400 has been completed!
# 96600 has been completed!
# 96800 has been completed!
# 97000 has been completed!
# 97200 has been completed!
# 97400 has been completed!
# 97600 has been completed!
# 97800 has been completed!
# 98000 has been completed!
# 98200 has been completed!
# 98400 has been completed!
# 98600 has been completed!
# 98800 has been completed!
# 99000 has been completed!
# 99200 has been completed!
# 99400 has been completed!
# 99600 has been completed!
# 99800 has been completed!
# 100000 has been completed!
# 100200 has been completed!
# 100400 has been completed!
# 100600 has been completed!
# 100800 has been completed!
# 101000 has been completed!
# 101200 has been completed!
# 101400 has been completed!
# 101600 has been completed!
# 101800 has been completed!
# 102000 has been completed!
# 102200 has been completed!
# 102400 has been completed!
# 102600 has been completed!
# 102800 has been completed!
# 103000 has been completed!
# 103200 has been completed!
# 103400 has been completed!
# 103600 has been completed!
# 103800 has been completed!
# 104000 has been completed!
# 104200 has been completed!
# 104400 has been completed!
# 104600 has been completed!
# 104800 has been completed!
# 105000 has been completed!
# 105200 has been completed!
# 105400 has been completed!
# 105600 has been completed!
# 105800 has been completed!
# 106000 has been completed!
# 106200 has been completed!
# 106400 has been completed!
# 106600 has been completed!
# 106800 has been completed!
# 107000 has been completed!
# 107200 has been completed!
# 107400 has been completed!
# 107600 has been completed!
# 107800 has been completed!
# 108000 has been completed!
# 108200 has been completed!
# 108400 has been completed!
# 108600 has been completed!
# 108800 has been completed!
# 109000 has been completed!
# 109200 has been completed!
# 109400 has been completed!
# 109600 has been completed!
# 109800 has been completed!
# 110000 has been completed!
# 110200 has been completed!
# 110400 has been completed!
# 110600 has been completed!
# 110800 has been completed!
# 111000 has been completed!
# 111200 has been completed!
# 111400 has been completed!
# 111600 has been completed!
# 111800 has been completed!
# 112000 has been completed!
# 112200 has been completed!
# 112400 has been completed!
# 112600 has been completed!
# 112800 has been completed!
# 113000 has been completed!
# 113200 has been completed!
# 113400 has been completed!
# 113600 has been completed!
# 113800 has been completed!
# 114000 has been completed!
# 114200 has been completed!
# 114400 has been completed!
# 114600 has been completed!
# 114800 has been completed!
# 115000 has been completed!
# 115200 has been completed!
# 115400 has been completed!
# 115600 has been completed!
# 115800 has been completed!
# 116000 has been completed!
# 116200 has been completed!
# 116400 has been completed!
# 116600 has been completed!
# 116800 has been completed!
# 117000 has been completed!
# 117200 has been completed!
# 117400 has been completed!
# 117600 has been completed!
# 117800 has been completed!
# 118000 has been completed!
# 118200 has been completed!
# 118400 has been completed!
# 118600 has been completed!
# 118800 has been completed!
# 119000 has been completed!
# 119200 has been completed!
# 119400 has been completed!
# 119600 has been completed!
# 119800 has been completed!
# 120000 has been completed!
# 120200 has been completed!
# 120400 has been completed!
# 120600 has been completed!
# 120800 has been completed!
# 121000 has been completed!
# 121200 has been completed!
# 121400 has been completed!
# 121600 has been completed!
# 121800 has been completed!
# 122000 has been completed!
# 122200 has been completed!
# 122400 has been completed!
# 122600 has been completed!
# 122800 has been completed!
# 123000 has been completed!
# 123200 has been completed!
# 123400 has been completed!
# 123600 has been completed!
# 123800 has been completed!
# 124000 has been completed!
# 124200 has been completed!
# 124400 has been completed!
# 124600 has been completed!
# 124800 has been completed!
# 125000 has been completed!
# 125200 has been completed!
# 125400 has been completed!
# 125600 has been completed!
# 125800 has been completed!
# 126000 has been completed!
# 126200 has been completed!
# 126400 has been completed!
# 126600 has been completed!
# 126800 has been completed!
# 127000 has been completed!
# 127200 has been completed!
# 127400 has been completed!
# 127600 has been completed!
# 127800 has been completed!
# 128000 has been completed!
# 128200 has been completed!
# 128400 has been completed!
# 128600 has been completed!
# 128800 has been completed!
# 129000 has been completed!
# 129200 has been completed!
# 129400 has been completed!
# 129600 has been completed!
# 129800 has been completed!
# 130000 has been completed!
# 130200 has been completed!
# 130400 has been completed!
# 130600 has been completed!
# 130800 has been completed!
# 131000 has been completed!
# 131200 has been completed!
# 131400 has been completed!
# 131600 has been completed!
# 131800 has been completed!
# 132000 has been completed!
# 132200 has been completed!
# 132400 has been completed!
# 132600 has been completed!
# 132800 has been completed!
# 133000 has been completed!
# 133200 has been completed!
# 133400 has been completed!
# 133600 has been completed!
# 133800 has been completed!
# 134000 has been completed!
# 134200 has been completed!
# 134400 has been completed!
# 134600 has been completed!
# 134800 has been completed!
# 135000 has been completed!
# 135200 has been completed!
# 135400 has been completed!
# 135600 has been completed!
# 135800 has been completed!
# 136000 has been completed!
# 136200 has been completed!
# 136400 has been completed!
# 136600 has been completed!
# 136800 has been completed!
# 137000 has been completed!
# 137200 has been completed!
# 137400 has been completed!
# 137600 has been completed!
# 137800 has been completed!
# 138000 has been completed!
# 138200 has been completed!
# 138400 has been completed!
# 138600 has been completed!
# 138800 has been completed!
# 139000 has been completed!
# 139200 has been completed!
# 139400 has been completed!
# 139600 has been completed!
# 139800 has been completed!
# 140000 has been completed!
# 140200 has been completed!
# 140400 has been completed!
# 140600 has been completed!
# 140800 has been completed!
# 141000 has been completed!
# 141200 has been completed!
# 141400 has been completed!
# 141600 has been completed!
# 141800 has been completed!
# 142000 has been completed!
# 142200 has been completed!
# 142400 has been completed!
# 142600 has been completed!
# 142800 has been completed!
# 143000 has been completed!
# 143200 has been completed!
# 143400 has been completed!
# 143600 has been completed!
# 143800 has been completed!
# 144000 has been completed!
# 144200 has been completed!
# 144400 has been completed!
# 144600 has been completed!
# 144800 has been completed!
# 145000 has been completed!
# 145200 has been completed!
# 145400 has been completed!
# 145600 has been completed!
# 145800 has been completed!
# 146000 has been completed!
# 146200 has been completed!
# 146400 has been completed!
# 146600 has been completed!
# 146800 has been completed!
# 147000 has been completed!
# 147200 has been completed!
# 147400 has been completed!
# 147600 has been completed!
# 147800 has been completed!
# 148000 has been completed!
# 148200 has been completed!
# 148400 has been completed!
# 148600 has been completed!
# 148800 has been completed!
# 149000 has been completed!
# 149200 has been completed!
# 149400 has been completed!
# 149600 has been completed!
# 149800 has been completed!
# 150000 has been completed!
# 150200 has been completed!
# 150400 has been completed!
# 150600 has been completed!
# 150800 has been completed!
# 151000 has been completed!
# 151200 has been completed!
# 151400 has been completed!
# 151600 has been completed!
# 151800 has been completed!
# 152000 has been completed!
# 152200 has been completed!
# 152400 has been completed!
# 152600 has been completed!
# 152800 has been completed!
# 153000 has been completed!
# 153200 has been completed!
# 153400 has been completed!
# 153600 has been completed!
# 153800 has been completed!
# 154000 has been completed!
# 154200 has been completed!
# 154400 has been completed!
# 154600 has been completed!
# 154800 has been completed!
# 155000 has been completed!
# 155200 has been completed!
# 155400 has been completed!
# 155600 has been completed!
# 155800 has been completed!
# 156000 has been completed!
# 156200 has been completed!
# 156400 has been completed!
# 156600 has been completed!
# 156800 has been completed!
# 157000 has been completed!
# 157200 has been completed!
# 157400 has been completed!
# 157600 has been completed!
# 157800 has been completed!
# 158000 has been completed!
# 158200 has been completed!
# 158400 has been completed!
# 158600 has been completed!
# 158800 has been completed!
# 159000 has been completed!
# 159200 has been completed!
# 159400 has been completed!
# 159600 has been completed!
# 159800 has been completed!
# 160000 has been completed!
# 160200 has been completed!
# 160400 has been completed!
# 160600 has been completed!
# 160800 has been completed!
# 161000 has been completed!
# 161200 has been completed!
# 161400 has been completed!
# 161600 has been completed!
# 161800 has been completed!
# 162000 has been completed!
# 162200 has been completed!
# 162400 has been completed!
# 162600 has been completed!
# 162800 has been completed!
# 163000 has been completed!
# 163200 has been completed!
# 163400 has been completed!
# 163600 has been completed!
# 163800 has been completed!
# 164000 has been completed!
# 164200 has been completed!
# 164400 has been completed!
# 164600 has been completed!
# 164800 has been completed!
# 165000 has been completed!
# 165200 has been completed!
# 165400 has been completed!
# 165600 has been completed!
# 165800 has been completed!
# 166000 has been completed!
# 166200 has been completed!
# 166400 has been completed!
# 166600 has been completed!
# 166800 has been completed!
# 167000 has been completed!
# 167200 has been completed!
# 167400 has been completed!
# 167600 has been completed!
# 167800 has been completed!
# 168000 has been completed!
# 168200 has been completed!
# 168400 has been completed!
# 168600 has been completed!
# 168800 has been completed!
# 169000 has been completed!
# 169200 has been completed!
# 169400 has been completed!
# 169600 has been completed!
# 169800 has been completed!
# 170000 has been completed!
# 170200 has been completed!
# 170400 has been completed!
# 170600 has been completed!
# 170800 has been completed!
# 171000 has been completed!
# 171200 has been completed!
# 171400 has been completed!
# 171600 has been completed!
# 171800 has been completed!
# 172000 has been completed!
# 172200 has been completed!
# 172400 has been completed!
# 172600 has been completed!
# 172800 has been completed!
# 173000 has been completed!
# 173200 has been completed!
# 173400 has been completed!
# 173600 has been completed!
# 173800 has been completed!
# 174000 has been completed!
# 174200 has been completed!
# 174400 has been completed!
# 174600 has been completed!
# 174800 has been completed!
# 175000 has been completed!
# 175200 has been completed!
# 175400 has been completed!
# 175600 has been completed!
# 175800 has been completed!
# 176000 has been completed!
# 176200 has been completed!
# 176400 has been completed!
# 176600 has been completed!
# 176800 has been completed!
# 177000 has been completed!
# 177200 has been completed!
# 177400 has been completed!
# 177600 has been completed!
# 177800 has been completed!
# 178000 has been completed!
# 178200 has been completed!
# 178400 has been completed!
# 178600 has been completed!
# 178800 has been completed!
# 179000 has been completed!
# 179200 has been completed!
# 179400 has been completed!
# 179600 has been completed!
# 179800 has been completed!
# 180000 has been completed!
# 180200 has been completed!
# 180400 has been completed!
# 180600 has been completed!
# 180800 has been completed!
# 181000 has been completed!
# 181200 has been completed!
# 181400 has been completed!
# 181600 has been completed!
# 181800 has been completed!
# 182000 has been completed!
# 182200 has been completed!
# 182400 has been completed!
# 182600 has been completed!
# 182800 has been completed!
# 183000 has been completed!
# 183200 has been completed!
# 183400 has been completed!
# 183600 has been completed!
# 183800 has been completed!
# 184000 has been completed!
# 184200 has been completed!
# 184400 has been completed!
# 184600 has been completed!
# 184800 has been completed!
# 185000 has been completed!
# 185200 has been completed!
# 185400 has been completed!
# 185600 has been completed!
# 185800 has been completed!
# 186000 has been completed!
# 186200 has been completed!
# 186400 has been completed!
# 186600 has been completed!
# 186800 has been completed!
# 187000 has been completed!
# 187200 has been completed!
# 187400 has been completed!
# 187600 has been completed!
# 187800 has been completed!
# 188000 has been completed!
# 188200 has been completed!
# 188400 has been completed!
# 188600 has been completed!
# 188800 has been completed!
# 189000 has been completed!
# 189200 has been completed!
# 189400 has been completed!
# 189600 has been completed!
# 189800 has been completed!
# 190000 has been completed!
# 190200 has been completed!
# 190400 has been completed!
# 190600 has been completed!
# 190800 has been completed!
# 191000 has been completed!
# 191200 has been completed!
# 191400 has been completed!
# 191600 has been completed!
# 191800 has been completed!
# 192000 has been completed!
# 192200 has been completed!
# 192400 has been completed!
# 192600 has been completed!
# 192800 has been completed!
# 193000 has been completed!
# 193200 has been completed!
# 193400 has been completed!
# 193600 has been completed!
# 193800 has been completed!
# 194000 has been completed!
# 194200 has been completed!
# 194400 has been completed!
# 194600 has been completed!
# 194800 has been completed!
# 195000 has been completed!
# 195200 has been completed!
# 195400 has been completed!
# 195600 has been completed!
# 195800 has been completed!
# 196000 has been completed!
# 196200 has been completed!
# 196400 has been completed!
# 196600 has been completed!
# 196800 has been completed!
# 197000 has been completed!
# 197200 has been completed!
# 197400 has been completed!
# 197600 has been completed!
# 197800 has been completed!
# 198000 has been completed!
# 198200 has been completed!
# 198400 has been completed!
# 198600 has been completed!
# 198800 has been completed!
# 199000 has been completed!
# 199200 has been completed!
# 199400 has been completed!
# 199600 has been completed!
# 199800 has been completed!
# 200000 has been completed!
# 200200 has been completed!
# 200400 has been completed!
# 200600 has been completed!
# 200800 has been completed!
# 201000 has been completed!
# 201200 has been completed!
# 201400 has been completed!
# 201600 has been completed!
# 201800 has been completed!
# 202000 has been completed!
# 202200 has been completed!
# 202400 has been completed!
# 202600 has been completed!
# 202800 has been completed!
# 203000 has been completed!
# 203200 has been completed!
# 203400 has been completed!
# 203600 has been completed!
# 203800 has been completed!
# 204000 has been completed!
# 204200 has been completed!
# 204400 has been completed!
# 204600 has been completed!
# 204800 has been completed!
# 205000 has been completed!
# 205200 has been completed!
# 205400 has been completed!
# 205600 has been completed!
# 205800 has been completed!
# 206000 has been completed!
# 206200 has been completed!
# 206400 has been completed!
# 206600 has been completed!
# 206800 has been completed!
# 207000 has been completed!
# 207200 has been completed!
# 207400 has been completed!
# 207600 has been completed!
# 207800 has been completed!
# 208000 has been completed!
# 208200 has been completed!
# 208400 has been completed!
# 208600 has been completed!
# 208800 has been completed!
# 209000 has been completed!
# 209200 has been completed!
# 209400 has been completed!
# 209600 has been completed!
# 209800 has been completed!
# 210000 has been completed!
# 210200 has been completed!
# 210400 has been completed!
# 210600 has been completed!
# 210800 has been completed!
# 211000 has been completed!
# 211200 has been completed!
# 211400 has been completed!
# 211600 has been completed!
# 211800 has been completed!
# 212000 has been completed!
# 212200 has been completed!
# 212400 has been completed!
# 212600 has been completed!
# 212800 has been completed!
# 213000 has been completed!
# 213200 has been completed!
# 213400 has been completed!
# 213600 has been completed!
# 213800 has been completed!
# 214000 has been completed!
# 214200 has been completed!
# 214400 has been completed!
# 214600 has been completed!
# 214800 has been completed!
# 215000 has been completed!
# 215200 has been completed!
# 215400 has been completed!
# 215600 has been completed!
# 215800 has been completed!
# 216000 has been completed!
# 216200 has been completed!
# 216400 has been completed!
# 216600 has been completed!
# 216800 has been completed!
# 217000 has been completed!
# 217200 has been completed!
# 217400 has been completed!
# 217600 has been completed!
# 217800 has been completed!
# 218000 has been completed!
# 218200 has been completed!
# 218400 has been completed!
# 218600 has been completed!
# 218800 has been completed!
# 219000 has been completed!
# 219200 has been completed!
# 219400 has been completed!
# 219600 has been completed!
# 219800 has been completed!
# 220000 has been completed!
# 220200 has been completed!
# 220400 has been completed!
# 220600 has been completed!
# 220800 has been completed!
# 221000 has been completed!
# 221200 has been completed!
# 221400 has been completed!
# 221600 has been completed!
# 221800 has been completed!
# 222000 has been completed!
# 222200 has been completed!
# 222400 has been completed!
# 222600 has been completed!
# 222800 has been completed!
# 223000 has been completed!
# 223200 has been completed!
# 223400 has been completed!
# 223600 has been completed!
# 223800 has been completed!
# 224000 has been completed!
# 224200 has been completed!
# 224400 has been completed!
# 224600 has been completed!
# 224800 has been completed!
# 225000 has been completed!
# 225200 has been completed!
# 225400 has been completed!
# 225600 has been completed!
# 225800 has been completed!
# 226000 has been completed!
# 226200 has been completed!
# 226400 has been completed!
# 226600 has been completed!
# 226800 has been completed!
# 227000 has been completed!
# 227200 has been completed!
# 227400 has been completed!
# 227600 has been completed!
# 227800 has been completed!
# 228000 has been completed!
# 228200 has been completed!
# 228400 has been completed!
# 228600 has been completed!
# 228800 has been completed!
# 229000 has been completed!
# 229200 has been completed!
# 229400 has been completed!
# 229600 has been completed!
# 229800 has been completed!
# 230000 has been completed!
# 230200 has been completed!
# 230400 has been completed!
# 230600 has been completed!
# 230800 has been completed!
# 231000 has been completed!
# 231200 has been completed!
# 231400 has been completed!
# 231600 has been completed!
# 231800 has been completed!
# 232000 has been completed!
# 232200 has been completed!
# 232400 has been completed!
# 232600 has been completed!
# 232800 has been completed!
# 233000 has been completed!
# 233200 has been completed!
# 233400 has been completed!
# 233600 has been completed!
# 233800 has been completed!
# 234000 has been completed!
# 234200 has been completed!
# 234400 has been completed!
# 234600 has been completed!
# 234800 has been completed!
# 235000 has been completed!
# 235200 has been completed!
# 235400 has been completed!
# 235600 has been completed!
# 235800 has been completed!
# 236000 has been completed!
# 236200 has been completed!
# 236400 has been completed!
# 236600 has been completed!
# 236800 has been completed!
# 237000 has been completed!
# 237200 has been completed!
# 237400 has been completed!
# 237600 has been completed!
# 237800 has been completed!
# 238000 has been completed!
# 238200 has been completed!
# 238400 has been completed!
# 238600 has been completed!
# 238800 has been completed!
# 239000 has been completed!
# 239200 has been completed!
# 239400 has been completed!
# 239600 has been completed!
# 239800 has been completed!
# 240000 has been completed!
# 240200 has been completed!
# 240400 has been completed!
# 240600 has been completed!
# 240800 has been completed!
# 241000 has been completed!
# 241200 has been completed!
# 241400 has been completed!
# 241600 has been completed!
# 241800 has been completed!
# 242000 has been completed!
# 242200 has been completed!
# 242400 has been completed!
# 242600 has been completed!
# 242800 has been completed!
# 243000 has been completed!
# 243200 has been completed!
# 243400 has been completed!
# 243600 has been completed!
# 243800 has been completed!
# 244000 has been completed!
# 244200 has been completed!
# 244400 has been completed!
# 244600 has been completed!
# 244800 has been completed!
# 245000 has been completed!
# 245200 has been completed!
# 245400 has been completed!
# 245600 has been completed!
# 245800 has been completed!
# 246000 has been completed!
# 246200 has been completed!
# 246400 has been completed!
# 246600 has been completed!
# 246800 has been completed!
# 247000 has been completed!
# 247200 has been completed!
# 247400 has been completed!
# 247600 has been completed!
# 247800 has been completed!
# 248000 has been completed!
# 248200 has been completed!
# 248400 has been completed!
# 248600 has been completed!
# 248800 has been completed!
# 249000 has been completed!
# 249200 has been completed!
# 249400 has been completed!
# 249600 has been completed!
# 249800 has been completed!
# 250000 has been completed!
# 250200 has been completed!
# 250400 has been completed!
# 250600 has been completed!
# 250800 has been completed!
# 251000 has been completed!
# 251200 has been completed!
# 251400 has been completed!
# 251600 has been completed!
# 251800 has been completed!
# 252000 has been completed!
# 252200 has been completed!
# 252400 has been completed!
# 252600 has been completed!
# 252800 has been completed!
# 253000 has been completed!
# 253200 has been completed!
# 253400 has been completed!
# 253600 has been completed!
# 253800 has been completed!
# 254000 has been completed!
# 254200 has been completed!
# 254400 has been completed!
# 254600 has been completed!
# 254800 has been completed!
# 255000 has been completed!
# 255200 has been completed!
# 255400 has been completed!
# 255600 has been completed!
# 255800 has been completed!
# 256000 has been completed!
# 256200 has been completed!
# 256400 has been completed!
# 256600 has been completed!
# 256800 has been completed!
# 257000 has been completed!
# 257200 has been completed!
# 257400 has been completed!
# 257600 has been completed!
# 257800 has been completed!
# 258000 has been completed!
# 258200 has been completed!
# 258400 has been completed!
# 258600 has been completed!
# 258800 has been completed!
# 259000 has been completed!
# 259200 has been completed!
# 259400 has been completed!
# 259600 has been completed!
# 259800 has been completed!
# 260000 has been completed!
# 260200 has been completed!
# 260400 has been completed!
# 260600 has been completed!
# 260800 has been completed!
# 261000 has been completed!
# 261200 has been completed!
# 261400 has been completed!
# 261600 has been completed!
# 261800 has been completed!
# 262000 has been completed!
# 262200 has been completed!
# 262400 has been completed!
# 262600 has been completed!
# 262800 has been completed!
# 263000 has been completed!
# 263200 has been completed!
# 263400 has been completed!
# 263600 has been completed!
# 263800 has been completed!
# 264000 has been completed!
# 264200 has been completed!
# 264400 has been completed!
# 264600 has been completed!
# 264800 has been completed!
# 265000 has been completed!
# 265200 has been completed!
# 265400 has been completed!
# 265600 has been completed!
# 265800 has been completed!
# 266000 has been completed!
# 266200 has been completed!
# 266400 has been completed!
# 266600 has been completed!
# 266800 has been completed!
# 267000 has been completed!
# 267200 has been completed!
# 267400 has been completed!
# 267600 has been completed!
# 267800 has been completed!
# 268000 has been completed!
# 268200 has been completed!
# 268400 has been completed!
# 268600 has been completed!
# 268800 has been completed!
# 269000 has been completed!
# 269200 has been completed!
# 269400 has been completed!
# 269600 has been completed!
# 269800 has been completed!
# 270000 has been completed!
# 270200 has been completed!
# 270400 has been completed!
# 270600 has been completed!
# 270800 has been completed!
# 271000 has been completed!
# 271200 has been completed!
# 271400 has been completed!
# 271600 has been completed!
# 271800 has been completed!
# 272000 has been completed!
# 272200 has been completed!
# 272400 has been completed!
# 272600 has been completed!
# 272800 has been completed!
# 273000 has been completed!
# 273200 has been completed!
# 273400 has been completed!
# 273600 has been completed!
# 273800 has been completed!
# 274000 has been completed!
# 274200 has been completed!
# 274400 has been completed!
# 274600 has been completed!
# 274800 has been completed!
# 275000 has been completed!
# 275200 has been completed!
# 275400 has been completed!
# 275600 has been completed!
# 275800 has been completed!
# 276000 has been completed!
# 276200 has been completed!
# 276400 has been completed!
# 276600 has been completed!
# 276800 has been completed!
# 277000 has been completed!
# 277200 has been completed!
# 277400 has been completed!
# 277600 has been completed!
# 277800 has been completed!
# 278000 has been completed!
# 278200 has been completed!
# 278400 has been completed!
# 278600 has been completed!
# 278800 has been completed!
# 279000 has been completed!
# 279200 has been completed!
# 279400 has been completed!
# 279600 has been completed!
# 279800 has been completed!
# 280000 has been completed!
# 280200 has been completed!
# 280400 has been completed!
# 280600 has been completed!
# 280800 has been completed!
# 281000 has been completed!
# 281200 has been completed!
# 281400 has been completed!
# 281600 has been completed!
# 281800 has been completed!
# 282000 has been completed!
# 282200 has been completed!
# 282400 has been completed!
# 282600 has been completed!
# 282800 has been completed!
# 283000 has been completed!
# 283200 has been completed!
# 283400 has been completed!
# 283600 has been completed!
# 283800 has been completed!
# 284000 has been completed!
# 284200 has been completed!
# 284400 has been completed!
# 284600 has been completed!
# 284800 has been completed!
# 285000 has been completed!
# 285200 has been completed!
# 285400 has been completed!
# 285600 has been completed!
# 285800 has been completed!
# 286000 has been completed!
# 286200 has been completed!
# 286400 has been completed!
# 286600 has been completed!
# 286800 has been completed!
# 287000 has been completed!
# 287200 has been completed!
# 287400 has been completed!
# 287600 has been completed!
# 287800 has been completed!
# 288000 has been completed!
# 288200 has been completed!
# 288400 has been completed!
# 288600 has been completed!
# 288800 has been completed!
# 289000 has been completed!
# 289200 has been completed!
# 289400 has been completed!
# 289600 has been completed!
# 289800 has been completed!
# 290000 has been completed!
# 290200 has been completed!
# 290400 has been completed!
# 290600 has been completed!
# 290800 has been completed!
# 291000 has been completed!
# 291200 has been completed!
# 291400 has been completed!
# 291600 has been completed!
# 291800 has been completed!
# 292000 has been completed!
# 292200 has been completed!
# 292400 has been completed!
# 292600 has been completed!
# 292800 has been completed!
# 293000 has been completed!
# 293200 has been completed!
# 293400 has been completed!
# 293600 has been completed!
# 293800 has been completed!
# 294000 has been completed!
# 294200 has been completed!
# 294400 has been completed!
# 294600 has been completed!
# 294800 has been completed!
# 295000 has been completed!
# 295200 has been completed!
# 295400 has been completed!
# 295600 has been completed!
# 295800 has been completed!
# 296000 has been completed!
# 296200 has been completed!
# 296400 has been completed!
# 296600 has been completed!
# 296800 has been completed!
# 297000 has been completed!
# 297200 has been completed!
# 297400 has been completed!
# 297600 has been completed!
# 297800 has been completed!
# 298000 has been completed!
# 298200 has been completed!
# 298400 has been completed!
# 298600 has been completed!
# 298800 has been completed!
# 299000 has been completed!
# 299200 has been completed!
# 299400 has been completed!
# 299600 has been completed!
# 299800 has been completed!
# 300000 has been completed!
# 300200 has been completed!
# 300400 has been completed!
# 300600 has been completed!
# 300800 has been completed!
# 301000 has been completed!
# 301200 has been completed!
# 301400 has been completed!
# 301600 has been completed!
# 301800 has been completed!
# 302000 has been completed!
# 302200 has been completed!
# 302400 has been completed!
# 302600 has been completed!
# 302800 has been completed!
# 303000 has been completed!
# 303200 has been completed!
# 303400 has been completed!
# 303600 has been completed!
# 303800 has been completed!
# 304000 has been completed!
# 304200 has been completed!
# 304400 has been completed!
# 304600 has been completed!
# 304800 has been completed!
# 305000 has been completed!
# 305200 has been completed!
# 305400 has been completed!
# 305600 has been completed!
# 305800 has been completed!
# 306000 has been completed!
# 306200 has been completed!
# 306400 has been completed!
# 306600 has been completed!
# 306800 has been completed!
# 307000 has been completed!
# 307200 has been completed!
# 307400 has been completed!
# 307600 has been completed!
# 307800 has been completed!
# 308000 has been completed!
# 308200 has been completed!
# 308400 has been completed!
# 308600 has been completed!
# 308800 has been completed!
# 309000 has been completed!
# 309200 has been completed!
# 309400 has been completed!
# 309600 has been completed!
# 309800 has been completed!
# 310000 has been completed!
# 310200 has been completed!
# 310400 has been completed!
# 310600 has been completed!
# 310800 has been completed!
# 311000 has been completed!
# 311200 has been completed!
# 311400 has been completed!
# 311600 has been completed!
# 311800 has been completed!
# 312000 has been completed!
# 312200 has been completed!
# 312400 has been completed!
# 312600 has been completed!
# 312800 has been completed!
# 313000 has been completed!
# 313200 has been completed!
# 313400 has been completed!
# 313600 has been completed!
# 313800 has been completed!
# 314000 has been completed!
# 314200 has been completed!
# 314400 has been completed!
# 314600 has been completed!
# 314800 has been completed!
# 315000 has been completed!
# 315200 has been completed!
# 315400 has been completed!
# 315600 has been completed!
# 315800 has been completed!
# 316000 has been completed!
# 316200 has been completed!
# 316400 has been completed!
# 316600 has been completed!
# 316800 has been completed!
# 317000 has been completed!
# 317200 has been completed!
# 317400 has been completed!
# 317600 has been completed!
# 317800 has been completed!
# 318000 has been completed!
# 318200 has been completed!
# 318400 has been completed!
# 318600 has been completed!
# 318800 has been completed!
# 319000 has been completed!
# 319200 has been completed!
# 319400 has been completed!
# 319600 has been completed!
# 319800 has been completed!
# 320000 has been completed!
# 320200 has been completed!
# 320400 has been completed!
# 320600 has been completed!
# 320800 has been completed!
# 321000 has been completed!
# 321200 has been completed!
# 321400 has been completed!
# 321600 has been completed!
# 321800 has been completed!
# 322000 has been completed!
# 322200 has been completed!
# 322400 has been completed!
# 322600 has been completed!
# 322800 has been completed!
# 323000 has been completed!
# 323200 has been completed!
# 323400 has been completed!
# 323600 has been completed!
# 323800 has been completed!
# 324000 has been completed!
# 324200 has been completed!
# 324400 has been completed!
# 324600 has been completed!
# 324800 has been completed!
# 325000 has been completed!
# 325200 has been completed!
# 325400 has been completed!
# 325600 has been completed!
# 325800 has been completed!
# 326000 has been completed!
# 326200 has been completed!
# 326400 has been completed!
# 326600 has been completed!
# 326800 has been completed!
# 327000 has been completed!
# 327200 has been completed!
# 327400 has been completed!
# 327600 has been completed!
# 327800 has been completed!
# 328000 has been completed!
# 328200 has been completed!
# 328400 has been completed!
# 328600 has been completed!
# 328800 has been completed!
# 329000 has been completed!
# 329200 has been completed!
# 329400 has been completed!
# 329600 has been completed!
# 329800 has been completed!
# 330000 has been completed!
# 330200 has been completed!
# 330400 has been completed!
# 330600 has been completed!
# 330800 has been completed!
# 331000 has been completed!
# 331200 has been completed!
# 331400 has been completed!
# 331600 has been completed!
# 331800 has been completed!
# 332000 has been completed!
# 332200 has been completed!
# 332400 has been completed!
# 332600 has been completed!
# 332800 has been completed!
# 333000 has been completed!
# 333200 has been completed!
# 333400 has been completed!
# 333600 has been completed!
# 333800 has been completed!
# 334000 has been completed!
# 334200 has been completed!
# 334400 has been completed!
# 334600 has been completed!
# 334800 has been completed!
# 335000 has been completed!
# 335200 has been completed!
# 335400 has been completed!
# 335600 has been completed!
# 335800 has been completed!
# 336000 has been completed!
# 336200 has been completed!
# 336400 has been completed!
# 336600 has been completed!
# 336800 has been completed!
# 337000 has been completed!
# 337200 has been completed!
# 337400 has been completed!
# 337600 has been completed!
# 337800 has been completed!
# 338000 has been completed!
# 338200 has been completed!
# 338400 has been completed!
# 338600 has been completed!
# 338800 has been completed!
# 339000 has been completed!
# 339200 has been completed!
# 339400 has been completed!
# 339600 has been completed!
# 339800 has been completed!
# 340000 has been completed!
# 340200 has been completed!
# 340400 has been completed!
# 340600 has been completed!
# 340800 has been completed!
# 341000 has been completed!
# 341200 has been completed!
# 341400 has been completed!
# 341600 has been completed!
# 341800 has been completed!
# 342000 has been completed!
# 342200 has been completed!
# 342400 has been completed!
# 342600 has been completed!
# 342800 has been completed!
# 343000 has been completed!
# 343200 has been completed!
# 343400 has been completed!
# 343600 has been completed!
# 343800 has been completed!
# 344000 has been completed!
# 344200 has been completed!
# 344400 has been completed!
# 344600 has been completed!
# 344800 has been completed!
# 345000 has been completed!
# 345200 has been completed!
# 345400 has been completed!
# 345600 has been completed!
# 345800 has been completed!
# 346000 has been completed!
# 346200 has been completed!
# 346400 has been completed!
# 346600 has been completed!
# 346800 has been completed!
# 347000 has been completed!
# 347200 has been completed!
# 347400 has been completed!
# 347600 has been completed!
# 347800 has been completed!
# 348000 has been completed!
# 348200 has been completed!
# 348400 has been completed!
# 348600 has been completed!
# 348800 has been completed!
# 349000 has been completed!
# 349200 has been completed!
# 349400 has been completed!
# 349600 has been completed!
# 349800 has been completed!
# 350000 has been completed!
# 350200 has been completed!
# 350400 has been completed!
# 350600 has been completed!
# 350800 has been completed!
# 351000 has been completed!
# 351200 has been completed!
# 351400 has been completed!
# 351600 has been completed!
# 351800 has been completed!
# 352000 has been completed!
# 352200 has been completed!
# 352400 has been completed!
# 352600 has been completed!
# 352800 has been completed!
# 353000 has been completed!
# 353200 has been completed!
# 353400 has been completed!
# 353600 has been completed!
# 353800 has been completed!
# 354000 has been completed!
# 354200 has been completed!
# 354400 has been completed!
# 354600 has been completed!
# 354800 has been completed!
# 355000 has been completed!
# 355200 has been completed!
# 355400 has been completed!
# 355600 has been completed!
# 355800 has been completed!
# ...
# 575600 has been completed!
# 575800 has been completed!
# 576000 has been completed!
# 576200 has been completed!
# 576400 has been completed!
# 576600 has been completed!
# 576800 has been completed!
# 577000 has been completed!
# 577200 has been completed!
# 577400 has been completed!
# 577600 has been completed!
# 577800 has been completed!
# 578000 has been completed!
# 578200 has been completed!
# 578400 has been completed!
# 578600 has been completed!
# 578800 has been completed!
# 579000 has been completed!
# 579200 has been completed!
# 579400 has been completed!
# 579600 has been completed!
# 579800 has been completed!
# 580000 has been completed!
# 580200 has been completed!
# 580400 has been completed!
# 580600 has been completed!
# 580800 has been completed!
# 581000 has been completed!
# 581200 has been completed!
# 581400 has been completed!
# 581600 has been completed!
# 581800 has been completed!
# 582000 has been completed!
# 582200 has been completed!
# 582400 has been completed!
# 582600 has been completed!
# 582800 has been completed!
# 583000 has been completed!
# 583200 has been completed!
# 583400 has been completed!
# 583600 has been completed!
# 583800 has been completed!
# 584000 has been completed!
# 584200 has been completed!
# 584400 has been completed!
# 584600 has been completed!
# 584800 has been completed!
# 585000 has been completed!
# 585200 has been completed!
# 585400 has been completed!
# 585600 has been completed!
# 585800 has been completed!
# 586000 has been completed!
# 586200 has been completed!
# 586400 has been completed!
# 586600 has been completed!
# 586800 has been completed!
# 587000 has been completed!
# 587200 has been completed!
# 587400 has been completed!
# 587600 has been completed!
# 587800 has been completed!
# 588000 has been completed!
# 588200 has been completed!
# 588400 has been completed!
# 588600 has been completed!
# 588800 has been completed!
# 589000 has been completed!
# 589200 has been completed!
# 589400 has been completed!
# 589600 has been completed!
# 589800 has been completed!
# 590000 has been completed!
# 590200 has been completed!
# 590400 has been completed!
# 590600 has been completed!
# 590800 has been completed!
# 591000 has been completed!
# 591200 has been completed!
# 591400 has been completed!
# 591600 has been completed!
# 591800 has been completed!
# 592000 has been completed!
# 592200 has been completed!
# 592400 has been completed!
# 592600 has been completed!
# 592800 has been completed!
# 593000 has been completed!
# 593200 has been completed!
# 593400 has been completed!
# 593600 has been completed!
# 593800 has been completed!
# 594000 has been completed!
# 594200 has been completed!
# 594400 has been completed!
# 594600 has been completed!
# 594800 has been completed!
# 595000 has been completed!
# 595200 has been completed!
# 595400 has been completed!
# 595600 has been completed!
# 595800 has been completed!
# 596000 has been completed!
# 596200 has been completed!
# 596400 has been completed!
# 596600 has been completed!
# 596800 has been completed!
# 597000 has been completed!
# 597200 has been completed!
# 597400 has been completed!
# 597600 has been completed!
# 597800 has been completed!
# 598000 has been completed!
# 598200 has been completed!
# 598400 has been completed!
# 598600 has been completed!
# 598800 has been completed!
# 599000 has been completed!
# 599200 has been completed!
# 599400 has been completed!
# 599600 has been completed!
# 599800 has been completed!
# 600000 has been completed!
# 600200 has been completed!
# 600400 has been completed!
# 600600 has been completed!
# 600800 has been completed!
# 601000 has been completed!
# 601200 has been completed!
# 601400 has been completed!
# 601600 has been completed!
# 601800 has been completed!
# 602000 has been completed!
# 602200 has been completed!
# 602400 has been completed!
# 602600 has been completed!
# 602800 has been completed!
# 603000 has been completed!
# 603200 has been completed!
# 603400 has been completed!
# 603600 has been completed!
# 603800 has been completed!
# 604000 has been completed!
# 604200 has been completed!
# 604400 has been completed!
# 604600 has been completed!
# 604800 has been completed!
# 605000 has been completed!
# 605200 has been completed!
# 605400 has been completed!
# 605600 has been completed!
# 605800 has been completed!
# 606000 has been completed!
# 606200 has been completed!
# 606400 has been completed!
# 606600 has been completed!
# 606800 has been completed!
# 607000 has been completed!
# 607200 has been completed!
# 607400 has been completed!
# 607600 has been completed!
# 607800 has been completed!
# 608000 has been completed!
# 608200 has been completed!
# 608400 has been completed!
# 608600 has been completed!
# 608800 has been completed!
# 609000 has been completed!
# 609200 has been completed!
# 609400 has been completed!
# 609600 has been completed!
# 609800 has been completed!
# 610000 has been completed!
# 610200 has been completed!
# 610400 has been completed!
# 610600 has been completed!
# 610800 has been completed!
# 611000 has been completed!
# 611200 has been completed!
# 611400 has been completed!
# 611600 has been completed!
# 611800 has been completed!
# 612000 has been completed!
# 612200 has been completed!
# 612400 has been completed!
# 612600 has been completed!
# 612800 has been completed!
# 613000 has been completed!
# 613200 has been completed!
# 613400 has been completed!
# 613600 has been completed!
# 613800 has been completed!
# 614000 has been completed!
# 614200 has been completed!
# 614400 has been completed!
# 614600 has been completed!
# 614800 has been completed!
# 615000 has been completed!
# 615200 has been completed!
# 615400 has been completed!
# 615600 has been completed!
# 615800 has been completed!
# 616000 has been completed!
# 616200 has been completed!
# 616400 has been completed!
# 616600 has been completed!
# 616800 has been completed!
# 617000 has been completed!
# 617200 has been completed!
# 617400 has been completed!
# 617600 has been completed!
# 617800 has been completed!
# 618000 has been completed!
# 618200 has been completed!
# 618400 has been completed!
# 618600 has been completed!
# 618800 has been completed!
# 619000 has been completed!
# 619200 has been completed!
# 619400 has been completed!
# 619600 has been completed!
# 619800 has been completed!
# 620000 has been completed!
# 620200 has been completed!
# 620400 has been completed!
# 620600 has been completed!
# 620800 has been completed!
# 621000 has been completed!
# 621200 has been completed!
# 621400 has been completed!
# 621600 has been completed!
# 621800 has been completed!
# 622000 has been completed!
# 622200 has been completed!
# 622400 has been completed!
# 622600 has been completed!
# 622800 has been completed!
# 623000 has been completed!
# 623200 has been completed!
# 623400 has been completed!
# 623600 has been completed!
# 623800 has been completed!
# 624000 has been completed!
# 624200 has been completed!
# 624400 has been completed!
# 624600 has been completed!
# 624800 has been completed!
# 625000 has been completed!
# 625200 has been completed!
# 625400 has been completed!
# 625600 has been completed!
# 625800 has been completed!
# 626000 has been completed!
# 626200 has been completed!
# 626400 has been completed!
# 626600 has been completed!
# 626800 has been completed!
# 627000 has been completed!
# 627200 has been completed!
# 627400 has been completed!
# 627600 has been completed!
# 627800 has been completed!
# 628000 has been completed!
# 628200 has been completed!
# 628400 has been completed!
# 628600 has been completed!
# 628800 has been completed!
# 629000 has been completed!
# 629200 has been completed!
# 629400 has been completed!
# 629600 has been completed!
# 629800 has been completed!
# 630000 has been completed!
# 630200 has been completed!
# 630400 has been completed!
# 630600 has been completed!
# 630800 has been completed!
# 631000 has been completed!
# 631200 has been completed!
# 631400 has been completed!
# 631600 has been completed!
# 631800 has been completed!
# 632000 has been completed!
# 632200 has been completed!
# 632400 has been completed!
# 632600 has been completed!
# 632800 has been completed!
# 633000 has been completed!
# 633200 has been completed!
# 633400 has been completed!
# 633600 has been completed!
# 633800 has been completed!
# 634000 has been completed!
# 634200 has been completed!
# 634400 has been completed!
# 634600 has been completed!
# 634800 has been completed!
# 635000 has been completed!
# 635200 has been completed!
# 635400 has been completed!
# 635600 has been completed!
# 635800 has been completed!
# 636000 has been completed!
# 636200 has been completed!
# 636400 has been completed!
# 636600 has been completed!
# 636800 has been completed!
# 637000 has been completed!
# 637200 has been completed!
# 637400 has been completed!
# 637600 has been completed!
# 637800 has been completed!
# 638000 has been completed!
# 638200 has been completed!
# 638400 has been completed!
# 638600 has been completed!
# 638800 has been completed!
# 639000 has been completed!
# 639200 has been completed!
# 639400 has been completed!
# 639600 has been completed!
# 639800 has been completed!
# 640000 has been completed!
# 640200 has been completed!
# 640400 has been completed!
# 640600 has been completed!
# 640800 has been completed!
# 641000 has been completed!
# 641200 has been completed!
# 641400 has been completed!
# 641600 has been completed!
# 641800 has been completed!
# 642000 has been completed!
# 642200 has been completed!
# 642400 has been completed!
# 642600 has been completed!
# 642800 has been completed!
# 643000 has been completed!
# 643200 has been completed!
# 643400 has been completed!
# 643600 has been completed!
# 643800 has been completed!
# 644000 has been completed!
# 644200 has been completed!
# 644400 has been completed!
# 644600 has been completed!
# 644800 has been completed!
# 645000 has been completed!
# 645200 has been completed!
# 645400 has been completed!
# 645600 has been completed!
# 645800 has been completed!
# 646000 has been completed!
# 646200 has been completed!
# 646400 has been completed!
# 646600 has been completed!
# 646800 has been completed!
# 647000 has been completed!
# 647200 has been completed!
# 647400 has been completed!
# 647600 has been completed!
# 647800 has been completed!
# 648000 has been completed!
# 648200 has been completed!
# 648400 has been completed!
# 648600 has been completed!
# 648800 has been completed!
# 649000 has been completed!
# 649200 has been completed!
# 649400 has been completed!
# 649600 has been completed!
# 649800 has been completed!
# 650000 has been completed!
# 650200 has been completed!
# 650400 has been completed!
# 650600 has been completed!
# 650800 has been completed!
# 651000 has been completed!
# 651200 has been completed!
# 651400 has been completed!
# 651600 has been completed!
# 651800 has been completed!
# 652000 has been completed!
# 652200 has been completed!
# 652400 has been completed!
# 652600 has been completed!
# 652800 has been completed!
# 653000 has been completed!
# 653200 has been completed!
# 653400 has been completed!
# 653600 has been completed!
# 653800 has been completed!
# 654000 has been completed!
# 654200 has been completed!
# 654400 has been completed!
# 654600 has been completed!
# 654800 has been completed!
# 655000 has been completed!
# 655200 has been completed!
# 655400 has been completed!
# 655600 has been completed!
# 655800 has been completed!
# 656000 has been completed!
# 656200 has been completed!
# 656400 has been completed!
# 656600 has been completed!
# 656800 has been completed!
# 657000 has been completed!
# 657200 has been completed!
# 657400 has been completed!
# 657600 has been completed!
# 657800 has been completed!
# 658000 has been completed!
# 658200 has been completed!
# 658400 has been completed!
# 658600 has been completed!
# 658800 has been completed!
# 659000 has been completed!
# 659200 has been completed!
# 659400 has been completed!
# 659600 has been completed!
# 659800 has been completed!
# 660000 has been completed!
# 660200 has been completed!
# 660400 has been completed!
# 660600 has been completed!
# 660800 has been completed!
# 661000 has been completed!
# 661200 has been completed!
# 661400 has been completed!
# 661600 has been completed!
# 661800 has been completed!
# 662000 has been completed!
# 662200 has been completed!
# 662400 has been completed!
# 662600 has been completed!
# 662800 has been completed!
# 663000 has been completed!
# 663200 has been completed!
# 663400 has been completed!
# 663600 has been completed!
# 663800 has been completed!
# 664000 has been completed!
# 664200 has been completed!
# 664400 has been completed!
# 664600 has been completed!
# 664800 has been completed!
# 665000 has been completed!
# 665200 has been completed!
# 665400 has been completed!
# 665600 has been completed!
# 665800 has been completed!
# 666000 has been completed!
# 666200 has been completed!
# 666400 has been completed!
# 666600 has been completed!
# 666800 has been completed!
# 667000 has been completed!
# 667200 has been completed!
# 667400 has been completed!
# 667600 has been completed!
# 667800 has been completed!
# 668000 has been completed!
# 668200 has been completed!
# 668400 has been completed!
# 668600 has been completed!
# 668800 has been completed!
# 669000 has been completed!
# 669200 has been completed!
# 669400 has been completed!
# 669600 has been completed!
# 669800 has been completed!
# 670000 has been completed!
# 670200 has been completed!
# 670400 has been completed!
# 670600 has been completed!
# 670800 has been completed!
# 671000 has been completed!
# 671200 has been completed!
# 671400 has been completed!
# 671600 has been completed!
# 671800 has been completed!
# 672000 has been completed!
# 672200 has been completed!
# 672400 has been completed!
# 672600 has been completed!
# 672800 has been completed!
# 673000 has been completed!
# 673200 has been completed!
# 673400 has been completed!
# 673600 has been completed!
# 673800 has been completed!
# 674000 has been completed!
# 674200 has been completed!
# 674400 has been completed!
# 674600 has been completed!
# 674800 has been completed!
# 675000 has been completed!
# 675200 has been completed!
# 675400 has been completed!
# 675600 has been completed!
# 675800 has been completed!
# 676000 has been completed!
# 676200 has been completed!
# 676400 has been completed!
# 676600 has been completed!
# 676800 has been completed!
# 677000 has been completed!
# 677200 has been completed!
# 677400 has been completed!
# 677600 has been completed!
# 677800 has been completed!
# 678000 has been completed!
# 678200 has been completed!
# 678400 has been completed!
# 678600 has been completed!
# 678800 has been completed!
# 679000 has been completed!
# 679200 has been completed!
# 679400 has been completed!
# 679600 has been completed!
# 679800 has been completed!
# 680000 has been completed!
# 680200 has been completed!
# 680400 has been completed!
# 680600 has been completed!
# 680800 has been completed!
# 681000 has been completed!
# 681200 has been completed!
# 681400 has been completed!
# 681600 has been completed!
# 681800 has been completed!
# 682000 has been completed!
# 682200 has been completed!
# 682400 has been completed!
# 682600 has been completed!
# 682800 has been completed!
# 683000 has been completed!
# 683200 has been completed!
# 683400 has been completed!
# 683600 has been completed!
# 683800 has been completed!
# 684000 has been completed!
# 684200 has been completed!
# 684400 has been completed!
# 684600 has been completed!
# 684800 has been completed!
# 685000 has been completed!
# 685200 has been completed!
# 685400 has been completed!
# 685600 has been completed!
# 685800 has been completed!
# 686000 has been completed!
# 686200 has been completed!
# 686400 has been completed!
# 686600 has been completed!
# 686800 has been completed!
# 687000 has been completed!
# 687200 has been completed!
# 687400 has been completed!
# 687600 has been completed!
# 687800 has been completed!
# 688000 has been completed!
# 688200 has been completed!
# 688400 has been completed!
# 688600 has been completed!
# 688800 has been completed!
# 689000 has been completed!
# 689200 has been completed!
# 689400 has been completed!
# 689600 has been completed!
# 689800 has been completed!
# 690000 has been completed!
# 690200 has been completed!
# 690400 has been completed!
# 690600 has been completed!
# 690800 has been completed!
# 691000 has been completed!
# 691200 has been completed!
# 691400 has been completed!
# 691600 has been completed!
# 691800 has been completed!
# 692000 has been completed!
# 692200 has been completed!
# 692400 has been completed!
# 692600 has been completed!
# 692800 has been completed!
# 693000 has been completed!
# 693200 has been completed!
# Integrating MusicBrainz Data...
# Computing Number of Days To Track Release...

# %%
df.to_pickle('./Data/Output/Combined_Social_Data.pkl')
