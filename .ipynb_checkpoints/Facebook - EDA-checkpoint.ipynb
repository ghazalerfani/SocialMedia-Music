# %%
## required imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline

# %%
## read data
df1 = pd.read_csv('Data/Facebook_7_year.csv')
df2 = pd.read_csv('Data/SZA_Chainsmoker_FB.csv')
df = pd.concat([df1,df2])
# 297,603 total rows
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
## convert time from object to datetime
df['Created'] = df['Created'].apply(lambda x: pd.to_datetime(x))
# df.dtypes

# %%
## round down to nearest hour
# df['Created_Hour'] = df.Created_new.dt.floor('H')

# %%
df_numerics = df[['Page Name','Page Likes at Posting', 'Likes','Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Thankful', 'Post Views', 'Total Views','Total Views for all Crossposts', 'Score']].reset_index(drop=True)
df_categoricals= df[['Page Name','Type','Video Share Status']].reset_index(drop=True)

# %%
df.head(5).T
# Out:
#                                                                                 0  \
# Page Name                                                            Adam Lambert
# User Name                                                             AdamLambert
# Page Id                                                               82805678650
# Page Likes at Posting                                                 4.69738e+06
# Created                                                       2019-06-14 03:02:50
# Type                                                                        Photo
# Likes                                                                         528
# Comments                                                                       29
# Shares                                                                         19
# Love                                                                          118
# Wow                                                                            11
# Haha                                                                            1
# Sad                                                                             1
# Angry                                                                           0
# Thankful                                                                        0
# Video Share Status                                                            NaN
# Post Views                                                                      0
# Total Views                                                                     0
# Total Views for all Crossposts                                                  0
# Video Length                                                                  NaN
# URL                             https://www.facebook.com/AdamLambert/posts/101...
# Message                         Korea! Tickets are on sale NOW for Queen + Ada...
# Link                            https://www.facebook.com/AdamLambert/photos/a....
# Final Link                                                                    NaN
# Link Text                                                                     NaN
# Description                                                                   NaN
# Sponsor Id                                                                    NaN
# Sponsor Name                                                                  NaN
# Score                                                                       -6.02
#
#                                                                                 1  \
# Page Name                                                           Gerardo Ortiz
# User Name                                                         GerardoOrtizNet
# Page Id                                                              181220942708
# Page Likes at Posting                                                 1.10389e+07
# Created                                                       2019-06-14 02:43:06
# Type                                                                        Photo
# Likes                                                                        5534
# Comments                                                                      332
# Shares                                                                        602
# Love                                                                         6527
# Wow                                                                            61
# Haha                                                                           16
# Sad                                                                             2
# Angry                                                                           1
# Thankful                                                                        0
# Video Share Status                                                            NaN
# Post Views                                                                      0
# Total Views                                                                     0
# Total Views for all Crossposts                                                  0
# Video Length                                                                  NaN
# URL                             https://www.facebook.com/GerardoOrtizNet/posts...
# Message                                                                       🚘😎😜
# Link                            https://www.facebook.com/GerardoOrtizNet/photo...
# Final Link                                                                    NaN
# Link Text                                                         Timeline Photos
# Description                                                                   NaN
# Sponsor Id                                                                    NaN
# Sponsor Name                                                                  NaN
# Score                                                                        3.57
#
#                                                                                 2  \
# Page Name                                                           Natti Natasha
# User Name                                                    NattiNatashaOfficial
# Page Id                                                           108097215927323
# Page Likes at Posting                                                 1.94752e+06
# Created                                                       2019-06-14 02:38:12
# Type                                                                        Photo
# Likes                                                                       13118
# Comments                                                                      394
# Shares                                                                        302
# Love                                                                         6897
# Wow                                                                           257
# Haha                                                                           23
# Sad                                                                             2
# Angry                                                                           0
# Thankful                                                                        0
# Video Share Status                                                            NaN
# Post Views                                                                      0
# Total Views                                                                     0
# Total Views for all Crossposts                                                  0
# Video Length                                                                  NaN
# URL                             https://www.facebook.com/NattiNatashaOfficial/...
# Message                                                                 #TBT 🇵🇷 🏝
# Link                            https://www.facebook.com/NattiNatashaOfficial/...
# Final Link                                                                    NaN
# Link Text                                                         Timeline Photos
# Description                                                                   NaN
# Sponsor Id                                                                    NaN
# Sponsor Name                                                                  NaN
# Score                                                                        3.33
#
#                                                                                 3  \
# Page Name                                                                  Thalia
# User Name                                                                  Thalia
# Page Id                                                               19717739728
# Page Likes at Posting                                                 1.79403e+07
# Created                                                       2019-06-14 02:18:40
# Type                                                                        Photo
# Likes                                                                        2831
# Comments                                                                      128
# Shares                                                                         83
# Love                                                                          677
# Wow                                                                            15
# Haha                                                                           17
# Sad                                                                             1
# Angry                                                                           2
# Thankful                                                                        0
# Video Share Status                                                            NaN
# Post Views                                                                      0
# Total Views                                                                     0
# Total Views for all Crossposts                                                  0
# Video Length                                                                  NaN
# URL                             https://www.facebook.com/Thalia/posts/10157447...
# Message                         ¡Sorpresa! Surprise!!!! 🎉💃🏼💋 #TRetro #Thalia #...
# Link                            https://www.facebook.com/Thalia/photos/a.10151...
# Final Link                                                                    NaN
# Link Text                                                                     NaN
# Description                                                                   NaN
# Sponsor Id                                                                    NaN
# Sponsor Name                                                                  NaN
# Score                                                                       -1.19
#
#                                                                                 4
# Page Name                                                      Christina Aguilera
# User Name                                                       christinaaguilera
# Page Id                                                                5565627823
# Page Likes at Posting                                                 2.38994e+07
# Created                                                       2019-06-14 02:17:47
# Type                                                                 Native Video
# Likes                                                                        2413
# Comments                                                                      375
# Shares                                                                        148
# Love                                                                         1252
# Wow                                                                            45
# Haha                                                                           71
# Sad                                                                             4
# Angry                                                                           2
# Thankful                                                                        0
# Video Share Status                                                       original
# Post Views                                                                  74527
# Total Views                                                                 76488
# Total Views for all Crossposts                                                  0
# Video Length                                                             00:00:07
# URL                             https://www.facebook.com/christinaaguilera/pos...
# Message                                                                       NaN
# Link                            https://www.facebook.com/christinaaguilera/vid...
# Final Link                                                                    NaN
# Link Text                                                                     NaN
# Description                                                                   NaN
# Sponsor Id                                                                    NaN
# Sponsor Name                                                                  NaN
# Score                                                                       -1.24

# %%
## understand types of posts
df['Type'].value_counts().plot(kind='bar')
plt.show()

# %%
# understand distribution of numerical data
df_numerics.describe()
# Out:
#        Page Likes at Posting         Likes       Comments        Shares  \
# count           2.454740e+05  2.976030e+05  297603.000000  2.976030e+05
# mean            1.170577e+07  1.469852e+04     336.540579  8.965660e+02
# std             1.460924e+07  4.173205e+04    1692.347043  9.724372e+03
# min             3.000000e+00  0.000000e+00       0.000000  0.000000e+00
# 25%             2.389266e+06  8.250000e+02      18.000000  2.000000e+01
# 50%             5.738030e+06  3.328000e+03      76.000000  1.030000e+02
# 75%             1.487343e+07  1.181600e+04     240.000000  4.130000e+02
# max             1.073855e+08  5.461698e+06  270424.000000  1.996798e+06
#
#                 Love            Wow           Haha            Sad  \
# count  297603.000000  297603.000000  297603.000000  297603.000000
# mean     1011.833973      47.546876      85.351156      28.548788
# std      4479.528625     403.616509    1114.403905    1206.527643
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%        25.000000       1.000000       0.000000       0.000000
# 75%       476.000000      18.000000       7.000000       1.000000
# max    513405.000000  141444.000000  175456.000000  374236.000000
#
#                Angry       Thankful    Post Views   Total Views  \
# count  297603.000000  297603.000000  2.976030e+05  2.976030e+05
# mean        2.924803       1.601687  1.861783e+04  6.057012e+04
# std        48.598205      58.980579  2.052102e+05  1.290861e+06
# min         0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%         0.000000       0.000000  0.000000e+00  0.000000e+00
# 50%         0.000000       0.000000  0.000000e+00  0.000000e+00
# 75%         1.000000       0.000000  0.000000e+00  0.000000e+00
# max      8895.000000   13370.000000  5.988562e+07  3.656423e+08
#
#        Total Views for all Crossposts
# count                    2.976030e+05
# mean                     1.427625e+04
# std                      9.183029e+05
# min                      0.000000e+00
# 25%                      0.000000e+00
# 50%                      0.000000e+00
# 75%                      0.000000e+00
# max                      2.654994e+08

# %%
# get data for top 5 artists
top5_artists = ['Justin Timberlake', 'MALUMA', 'P!nk', 'Avril Lavigne', 'Willie Nelson']
df_top5 = df[df['Page Name'].isin(top5_artists)].reset_index(drop=True)
df_numerics_top5 = df_numerics[df_numerics['Page Name'].isin(top5_artists)].reset_index(drop=True)
df_categoricals_top5 = df_categoricals[df_categoricals['Page Name'].isin(top5_artists)].reset_index(drop=True)

# %%
# type of post by top 5 artists
df_posttypes = df_top5.groupby(['Page Name', 'Type'])['Created'].count().unstack('Type').fillna(0)
df_posttypes[['Link', 'Live Video', 'Live Video Complete', 'Native Video', 'Photo', 'Status', 'Video', 'YouTube']].plot(kind='bar', stacked = True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
boxplot = df_numerics_top5.boxplot(column=['Likes'], by='Page Name', ax=ax)
# boxplot.set_ylim = (-5,400000) # ylim not working, not sure why

# %%
# create selected df to export and combine with other data sources
df_selected = df[["User Name", "Created", "Message", "Score", 'Page Likes at Posting', 'Likes','Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Thankful']]

# %%
def update_post_types(post_type_value):
    if (str(post_type_value)=='Photo'):
        return 'photo'
    elif (str(post_type_value)=='Link'):
        return 'link'
    elif (str(post_type_value)=='Status'):
        return 'text'
    elif (str(post_type_value)=='Native Video' or str(post_type_value)=='YouTube' or str(post_type_value)=='Video' or str(post_type_value)=='Live Video Complete' or str(post_type_value)=='Vine' or str(post_type_value)=='Live Video' or str(post_type_value)=='Live Video Scheduled'):
        return 'video'
    else:
        return 'NaN'

# %%
# Update types to 4 only and OHE type
# df1 = df.copy()
# df1['Type'] = df1['Type'].astype(str)
df['Type'] = df['Type'].apply(lambda x : update_post_types(x))
df_type_ohe = pd.get_dummies(df["Type"],prefix='type')
df_selected = pd.concat([df_selected, df_type_ohe], axis=1)

# %%
# get number of characters in each message
df_selected['Message'] = df_selected['Message'].astype(str)
df_selected['description_length'] = df_selected['Message'].apply(len)

# %%
def time_of_day_creation(x):
    '''
    Takes in an integer and returns one of four time slots:
    ['12am-6am', '6am-12pm', '12pm-6pm', '6pm-12am']
    '''
    
    slots_out = ['12am-6am', '6am-12pm', '12pm-6pm', '6pm-12am']
    slot0 = np.arange(0,6)
    slot1 = np.arange(6,12)
    slot2 = np.arange(12,18)
    slot3 = np.arange(18,24)

    if x in slot0:
        return slots_out[0]
    elif x in slot1:
        return slots_out[1]
    elif x in slot2:
        return slots_out[2]
    elif x in slot3:
        return slots_out[3]
    else:
        return 'NaN'

# %%
# Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
df_selected['time_of_day'] = df_selected['Created'].apply(lambda x : time_of_day_creation(x.hour))

# %%
# OHE time of day
df_time_of_day_ohe = pd.get_dummies(df_selected["time_of_day"],prefix='created_')
df_selected = pd.concat([df_selected, df_time_of_day_ohe], axis=1)
df_selected = df_selected.drop(['time_of_day'], axis = 1)

# %%
# Time between prior and current post
df_selected.sort_values(by=['User Name','Created'], inplace=True)
df_selected['time_since_last_post'] = df_selected.groupby('User Name')['Created'].diff()

# %%
#Number of hashtags custom feature
df_selected['hashtag_count'] = df_selected['Message'].apply(lambda x : x.count('#'))

# %%
# placeholder for within 1 week of month of release
df_selected['within_week_release'] = 0
df_selected['within_month_release'] = 0

# %%
# posts in last 7 days (and 30) WIP

# def find_posts_count(period):
#     results = pd.Series(index=df_selected.index, name=period)
#     for index, date in df_selected.items():
#         time_range = df_selected.between_time(date - period, date )
#         results[index] = time_range.sum() - 1
#     return results.fillna(0).astype(int)

# %%
# posts in last 7 days (and 30) WIP

# results = pd.DataFrame(index=df_selected.index)
# period=pd.to_timedelta(1, 'd')
# for days in [7, 30]:
#     results['posts_last_%i'% days] = df_selected.groupby('User Name')[['Created']].transform(find_posts_count(pd.to_timedelta(days, 'd')))
# results.index = t['leadid']


# for index, row in df_selected.iterrows():
#     mask = (df_selected['User Name'] == row['User Name']) & (df_selected['Created'] > (row['Created'] - pd.Timedelta(days=7))) & (df_selected['Created'] < row['Created'])
#     df_selected.loc[index, 'posts_last_7days'] = sum(mask) # insert to the new column

# print(df_selected)

# df_selected.groupby('User Name')
# df_selected
# df_selected_rolling = df_selected.set_index(df_selected['Created'])
# df_selected_rolling
# df_selected_rolling.groupby('User Name')['Created'].rolling(7,freq='D').count()
# df_selected_rolling.groupby('User Name').resample('d').sum().fillna(0).\
#    groupby('User Name').rolling(14,min_periods=1).sum()

# %%
# calculate engagement score
df_selected['social_engagement_score'] = (df_selected['Likes'] + df_selected['Comments'] + df_selected['Shares'] + df_selected['Love'] + df_selected['Wow'] + df_selected['Haha'] + df_selected['Sad'] + df_selected['Angry']+ df_selected['Thankful'])  / df_selected['Page Likes at Posting']

# %%
df_selected = df_selected.drop(['Likes','Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Thankful'], axis=1)

# %%
## aggregate posts to artist & hour level
# df["Page Likes at Posting"] = df["Page Likes at Posting"].fillna(0)
# df_aggregate = df.groupby(["Page Name", "User Name", "Created_Hour"], as_index=False).agg({"Created": "count", "Page Likes at Posting": "max", "Likes":"mean", "Comments":"mean"})

# df_aggregate.rename({"Page Name": "FB Page Name", "Created_Hour": "FB Created_Hour", "User Name": "FB User Name", 'Created': 'FB Post Count', 'Page Likes at Posting': 'FB Page Likes at Posting', 'Likes': 'FB Likes', 'Comments': 'FB Comments'}, axis=1, inplace=True)
## 248709 rows

# %%
# df_aggregate_top5 = df_aggregate[df_aggregate['FB Page Name'].isin(top5_artists)].reset_index(drop=True)

# %%
# df_aggregate_top5.dtypes
# import datetime
# fig, ax = plt.subplots(figsize=(15,8))                      
# for x in top5_artists:
#     df_artist = df_aggregate_top5[df_aggregate_top5['FB Page Name']==x].reset_index(drop=True)
#     plot = plt.plot(df_artist['FB Created_Hour'], df_artist['FB Post Count'], label = x)
# ax.legend()
# ax.set_xlim([datetime.date(2016, 1, 1), datetime.date(2019, 1, 1)]) # can adjust time interval here
# ax.set_ylim(0,8)
# plt.show()

# %%
# add all other columns & rename
df_selected.rename({"User Name": "fb_handle_artist_name", "Created": "created", "Message": "description", "Score": "crowdtangle_score", "Page Likes at Posting": "count_of_followers", "Score": "crowdtangle_score"}, axis=1, inplace=True)
placeholder_columns = ["posts_last_7days", "posts_last_30days"]
for col in placeholder_columns:
    df_selected[col] = 0
df_selected
# Out:
#        fb_handle_artist_name             created  \
# 208531              21Savage 2015-05-18 19:24:23
# 207326              21Savage 2015-05-25 16:00:00
# 207251              21Savage 2015-05-25 22:26:12
# 193673              21Savage 2015-08-14 16:00:00
# 189932              21Savage 2015-09-05 16:00:00
# 189498              21Savage 2015-09-08 17:21:00
# 185977              21Savage 2015-09-28 17:54:17
# 185972              21Savage 2015-09-28 18:01:11
# 185970              21Savage 2015-09-28 18:06:23
# 185963              21Savage 2015-09-28 18:34:24
# 185685              21Savage 2015-09-30 12:44:21
# 185404              21Savage 2015-10-01 22:04:09
# 185268              21Savage 2015-10-02 17:09:00
# 184928              21Savage 2015-10-04 17:43:31
# 183665              21Savage 2015-10-10 16:49:16
# 183173              21Savage 2015-10-13 15:45:55
# 182534              21Savage 2015-10-16 16:30:35
# 182317              21Savage 2015-10-17 16:15:43
# 181894              21Savage 2015-10-19 17:28:54
# 181678              21Savage 2015-10-20 19:19:45
# 181673              21Savage 2015-10-20 19:25:48
# 181665              21Savage 2015-10-20 20:06:08
# 181661              21Savage 2015-10-20 20:11:48
# 181493              21Savage 2015-10-21 15:45:49
# 180465              21Savage 2015-10-26 18:40:21
# 180113              21Savage 2015-10-28 15:48:10
# 179674              21Savage 2015-10-30 16:25:02
# 179486              21Savage 2015-10-31 15:30:14
# 179266              21Savage 2015-11-01 21:06:58
# 179674  Dallas just got shut the fuxk down, Lauderdale...                 0
# 179486  Dallas fuxks with the Slaughter Gang. (🎥 by Ba...             -9.09
# 179266  Ft. Lauderdale Piped Up With The Gang (📷 by @w...           -129.91
# 176960              More Fan Art // Slaughter King otw...            -25.82
# ...                                                   ...               ...
# 12564                                                 nan             -1.48
# 12017                                                 nan             -2.41
# 11462   #MeMyselfAndI #BestCoverSong #iHeartAwards vot...            -68.18
# 11254                                                 nan              1.05
# 10915   #MeMyselfAndI #BestCoverSong #iHeartAwards vot...           -114.06
# 10906                                                 nan              3.13
# 10867                                                 nan              1.69
# 10327                                                 nan             -2.04
# 9803                           #PenshoppeSpringSummer2019              1.23
# 9680                                                  nan              1.63
# 9616                                                  nan             -2.21
# 9165                                                  nan              1.91
# 9001                                                  nan             -1.88
# 8875                                                  nan              3.73
# 8329                                                  nan             -2.18
# 7162                                                  nan             -2.07
# 6897                                  Sometimes I cry 🔈🎧🎶             -1.33
# 6651                                                  nan              4.55
# 6544        Good morning! sending happy vibes and love ❤️              3.36
# 6499    thanks for all the love & support on this the ...              2.01
# 5477                                                  nan             -1.28
# 4770    #StandStillVideo out now http://smarturl.it/ss...             -1.22
# 4415                                                  nan             -2.35
# 3809                                                  nan             -1.52
# 3760                                                  nan              2.27
# 3246                                                  nan             -1.88
# 3204                                                  nan              3.05
# 3154                                                  nan              2.77
# 2883    “A Whole New World” 🎵 Out Now! #Aladdin smartu...              5.89
# 2759                                                  nan             -1.44
#
#         count_of_followers  type_link  type_photo  type_text  type_video  \
# 208531                 NaN          0           0          1           0
# 207326                 NaN          0           1          0           0
# 207251                 NaN          1           0          0           0
# 193673                 NaN          0           1          0           0
# 189932                 NaN          0           1          0           0
# 189498                 NaN          0           0          1           0
# 185977                 NaN          0           1          0           0
# 185972                 NaN          0           1          0           0
# 185970                 NaN          0           1          0           0
# 185963                 NaN          0           0          0           1
# 185685                 NaN          0           0          0           1
# 185404                 NaN          1           0          0           0
# 185268                 NaN          0           0          0           1
# 184928                 NaN          0           0          0           1
# 183665                 NaN          0           0          0           1
# 183173                 NaN          1           0          0           0
# 182534                 NaN          0           0          0           1
# 182317                 NaN          0           1          0           0
# 181894                 NaN          1           0          0           0
# 181678                 NaN          1           0          0           0
# 181673                 NaN          1           0          0           0
# 181665                 NaN          1           0          0           0
# 181661                 NaN          1           0          0           0
# 181493                 NaN          0           0          0           1
# 180465                 NaN          0           1          0           0
# 180113                 NaN          1           0          0           0
# 179674                 NaN          1           0          0           0
# 179486                 NaN          0           0          0           1
# 179266                 NaN          0           1          0           0
# 176960                 NaN          0           1          0           0
# ...                    ...        ...         ...        ...         ...
# 12564           19795186.0          0           1          0           0
# 12017           19794201.0          0           1          0           0
# 11462           19788966.0          0           1          0           0
# 11254           19787377.0          0           1          0           0
# 10915           19782932.0          0           1          0           0
# 10906           19782932.0          0           1          0           0
# 10867           19782932.0          0           1          0           0
# 10327           19777482.0          0           1          0           0
# 9803            19772783.0          0           0          0           1
# 9680            19771664.0          0           1          0           0
# 9616            19770466.0          0           1          0           0
# 9165            19764945.0          0           1          0           0
# 9001            19763528.0          0           1          0           0
# 8875            19762010.0          0           1          0           0
# 8329            19759704.0          0           1          0           0
# 7162            19748293.0          0           1          0           0
# 6897            19745216.0          0           0          1           0
# 6651            19745074.0          0           1          0           0
# 6544            19749407.0          0           1          0           0
# 6499            19749407.0          0           0          0           1
# 5477            19741119.0          0           1          0           0
# 4770            19732956.0          0           0          0           1
# 4415            19731212.0          0           1          0           0
# 3809            19726798.0          0           1          0           0
# 3760            19726798.0          0           1          0           0
# 3246            19724855.0          0           1          0           0
# 3204            19724855.0          0           1          0           0
# 3154            19724616.0          0           1          0           0
# 2883            19725377.0          0           0          0           1
# 2759            19727123.0          0           1          0           0
#
#         description_length        ...          created__12pm-6pm  \
# 208531                  29        ...                          0
# 207326                  41        ...                          1
# 207251                 107        ...                          0
# 193673                  75        ...                          1
# 189932                 100        ...                          1
# 189498                  36        ...                          1
# 185977                  41        ...                          1
# 185972                 100        ...                          0
# 185970                  75        ...                          0
# 185963                 136        ...                          0
# 185685                 100        ...                          1
# 185404                  69        ...                          0
# 185268                 101        ...                          1
# 184928                 102        ...                          1
# 183665                 137        ...                          1
# 183173                 221        ...                          1
# 182534                 113        ...                          1
# 182317                  28        ...                          1
# 181894                   3        ...                          1
# 181678                 154        ...                          0
# 181673                   3        ...                          0
# 181665                   3        ...                          0
# 181661                   3        ...                          0
# 181493                  24        ...                          1
# 180465                  26        ...                          0
# 180113                  38        ...                          1
# 179674                  56        ...                          1
# 179486                  59        ...                          1
# 179266                  54        ...                          0
# 176960                  37        ...                          1
# ...                    ...        ...                        ...
# 12564                    3        ...                          1
# 12017                    3        ...                          0
# 11462                   79        ...                          0
# 11254                    3        ...                          0
# 10915                  125        ...                          0
# 10906                    3        ...                          0
# 10867                    3        ...                          0
# 10327                    3        ...                          0
# 9803                    26        ...                          0
# 9680                     3        ...                          1
# 9616                     3        ...                          0
# 9165                     3        ...                          1
# 9001                     3        ...                          0
# 8875                     3        ...                          1
# 8329                     3        ...                          0
# 7162                     3        ...                          0
# 6897                    19        ...                          0
# 6651                     3        ...                          1
# 6544                    45        ...                          0
# 6499                    63        ...                          0
# 5477                     3        ...                          0
# 4770                    63        ...                          0
# 4415                     3        ...                          0
# 3809                     3        ...                          0
# 3760                     3        ...                          0
# 3246                     3        ...                          0
# 3204                     3        ...                          0
# 3154                     3        ...                          0
# 2883                   112        ...                          1
# 2759                     3        ...                          1
#
#         created__6am-12pm  created__6pm-12am  time_since_last_post  \
# 208531                  0                  1                   NaT
# 207326                  0                  0       6 days 20:35:37
# 207251                  0                  1       0 days 06:26:12
# 193673                  0                  0      80 days 17:33:48
# 189932                  0                  0      22 days 00:00:00
# 189498                  0                  0       3 days 01:21:00
# 185977                  0                  0      20 days 00:33:17
# 185972                  0                  1       0 days 00:06:54
# 185970                  0                  1       0 days 00:05:12
# 185963                  0                  1       0 days 00:28:01
