# %% [markdown]
# ## Import Statements

# %%
import glob
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from collections import Counter
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Reading Data in and Descriptive Statistics

# %%
files = glob.glob('./InstagramData/*.csv')

# %%
files
# Out:
# ['./InstagramData\\Instagram_Year_1.csv',
#  './InstagramData\\Instagram_Year_2.csv',
#  './InstagramData\\Instagram_Year_3.csv',
#  './InstagramData\\Instagram_Year_4.csv',
#  './InstagramData\\Instagram_Year_5.csv',
#  './InstagramData\\Instagram_Year_6.csv',
#  './InstagramData\\Instagram_Year_7.csv',
#  './InstagramData\\SZA_Chainsmoker_Insta.csv']

# %%
df_list = [pd.read_csv(file) for file in files]

# %%
df = pd.concat(df_list)

# %%
df.columns
# Out:
# Index(['Account', 'User Name', 'Followers at Posting', 'Created', 'Type',
#        'Likes', 'Comments', 'Views', 'URL', 'Link', 'Photo', 'Description',
#        'Sponsor Id', 'Sponsor Name', 'Score'],
#       dtype='object')

# %% [markdown]
# ##### Description of the fields:
# https://github.com/CrowdTangle/API/wiki/Post

# %%
df.shape
# Out:
# (385381, 15)

# %%
df.describe()
# Out:
#        Followers at Posting         Likes       Comments         Views  \
# count          2.634390e+05  3.853810e+05  385381.000000  3.853810e+05
# mean           8.036545e+06  7.100864e+04     984.764747  6.735627e+04
# std            1.236633e+07  1.852657e+05    3650.072572  4.276920e+05
# min            1.105900e+04  0.000000e+00       0.000000  0.000000e+00
# 25%            1.308932e+06  7.322000e+03      90.000000  0.000000e+00
# 50%            3.687874e+06  2.013700e+04     250.000000  0.000000e+00
# 75%            9.247391e+06  5.785300e+04     735.000000  0.000000e+00
# max            1.281907e+08  1.124974e+07  586469.000000  4.343266e+07
#
#          Sponsor Id
# count  3.740000e+02
# mean   9.783525e+08
# std    1.680954e+09
# min    6.398370e+05
# 25%    8.548354e+07
# 50%    2.995531e+08
# 75%    1.153133e+09
# max    8.482989e+09

# %%
df.sample(4).T
# Out:
#                                                                   2725   \
# Account                                                       snoopdogg
# User Name                                                     snoopdogg
# Followers at Posting                                        1.79345e+07
# Created                                         2017-06-26 22:45:24 EDT
# Type                                                              Video
# Likes                                                             14223
# Comments                                                            129
# Views                                                             74375
# URL                            https://www.instagram.com/p/BV06SyCDd0i/
# Link                           https://www.instagram.com/p/BV06SyCDd0i/
# Photo                 https://scontent.cdninstagram.com/t51.2885-15/...
# Description                                                         NaN
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -2.16
#
#                                                                   57671  \
# Account                                                      Zayn Malik
# User Name                                                          zayn
# Followers at Posting                                        8.63843e+06
# Created                                         2016-04-04 03:26:30 EDT
# Type                                                              Photo
# Likes                                                            956689
# Comments                                                          12384
# Views                                                                 0
# URL                            https://www.instagram.com/p/BDxRiuTpqfp/
# Link                           https://www.instagram.com/p/BDxRiuTpqfp/
# Photo                 https://scontent.cdninstagram.com/t51.2885-15/...
# Description                                                         NaN
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -1.03
#
#                                                                   50778  \
# Account                                                         Shakira
# User Name                                                       shakira
# Followers at Posting                                        1.68977e+07
# Created                                         2016-02-26 17:03:39 EST
# Type                                                              Photo
# Likes                                                            226567
# Comments                                                            819
# Views                                                                 0
# URL                            https://www.instagram.com/p/BCQ_t4poji8/
# Link                           https://www.instagram.com/p/BCQ_t4poji8/
# Photo                 https://scontent.cdninstagram.com/t51.2885-15/...
# Description           #Repost @danid2ois ・・・\n"Nos fuimos de zotropo...
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -2.09
#
#                                                                   45562
# Account                                                       DJ KHALED
# User Name                                                      djkhaled
# Followers at Posting                                        1.53799e+07
# Created                                         2019-06-04 13:02:00 EDT
# Type                                                              Video
# Likes                                                             35950
# Comments                                                            557
# Views                                                            175358
# URL                            https://www.instagram.com/p/ByS6QMoh-aS/
# Link                           https://www.instagram.com/p/ByS6QMoh-aS/
# Photo                 https://scontent.xx.fbcdn.net/v/t51.2885-15/62...
# Description           @wethebestmusic SUMMER ! \n#FATHEROFASAHD TO T...
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                              1.29

# %%
#Convert Datetimes
df['Created'] = pd.to_datetime(df['Created'])
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\oldye\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
#Rename column
#df.rename(columns={'Created':'PostTime'},inplace=True)

# %%
df.sample(4).T
# Out:
#                                                                   33802  \
# Account                                                       DJ KHALED
# User Name                                                      djkhaled
# Followers at Posting                                                NaN
# Created                                             2014-03-20 17:44:25
# Type                                                              Photo
# Likes                                                              5102
# Comments                                                             62
# Views                                                                 0
# URL                                 https://instagram.com/p/lx6tjSru2W/
# Link                                https://instagram.com/p/lx6tjSru2W/
# Photo                 https://scontent.cdninstagram.com/hphotos-xfa1...
# Description           @djfunkflex I do this !!!! @wethebestmusic @pl...
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -12.2
#
#                                                                   5178   \
# Account                                               Silvestre Dangond
# User Name                                              silvestredangond
# Followers at Posting                                        1.66037e+06
# Created                                             2016-07-08 12:53:18
# Type                                                              Video
# Likes                                                             14725
# Comments                                                            128
# Views                                                            119934
# URL                            https://www.instagram.com/p/BHm57MngJhX/
# Link                           https://www.instagram.com/p/BHm57MngJhX/
# Photo                 https://scontent.cdninstagram.com/t51.2885-15/...
# Description           Aceptando el reto de mi compadre @jmdelaesprie...
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -1.82
#
#                                                                   40046  \
# Account                                                       snoopdogg
# User Name                                                     snoopdogg
# Followers at Posting                                        4.15016e+06
# Created                                             2015-01-19 19:56:23
# Type                                                              Video
# Likes                                                             20866
# Comments                                                            312
# Views                                                                 0
# URL                                  http://instagram.com/p/yDnIW_P9AI/
# Link                                 http://instagram.com/p/yDnIW_P9AI/
# Photo                 http://scontent-a.cdninstagram.com/hphotos-xfa...
# Description                                                         NaN
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -1.16
#
#                                                                   26667
# Account                                                       DJ KHALED
# User Name                                                      djkhaled
# Followers at Posting                                        1.83434e+06
# Created                                             2015-10-24 17:30:59
# Type                                                              Video
# Likes                                                              4252
# Comments                                                             32
# Views                                                                 0
# URL                                 https://instagram.com/p/9PEnREruxB/
# Link                                https://instagram.com/p/9PEnREruxB/
# Photo                 https://scontent.cdninstagram.com/hphotos-xfa1...
# Description           big up @bigsean we had stage lit🔥! #ichangedal...
# Sponsor Id                                                          NaN
# Sponsor Name                                                        NaN
# Score                                                             -8.43

# %%
selected_columns = ['User Name', 'Followers at Posting', 'Created', 'Type', 'Likes', 'Comments', 'Views', 
                    'Description','Score']
df_selected = df[selected_columns]

# %%
df_selected.head()
# Out:
#    User Name  Followers at Posting             Created   Type  Likes  \
# 0    yogotti                   NaN 2012-06-11 00:56:00  Photo   2069
# 1  iambeckyg                   NaN 2012-06-11 01:04:15  Photo    144
# 2    yogotti                   NaN 2012-06-11 01:05:39  Photo   1741
# 3    yogotti                   NaN 2012-06-11 01:08:31  Photo   1893
# 4     maluma                   NaN 2012-06-11 02:59:43  Photo   3589
#
#    Comments  Views                                        Description  \
# 0        57      0  S/O To New Orleans!!!!!!! Last Date Da Tour A ...
# 1         5      0                                            Glasses
# 2        34      0                       #road2richestour New Orleans
# 3        56      0                                             #quiet
# 4        24      0                 Fuck...!! He has mi camisetaaaaaa!
#
#        Score
# 0      -6.84
# 1  -3,046.65
# 2      -8.19
# 3      -7.46
# 4    -242.38

# %%
df_selected.reset_index(inplace=True)

# %%
df_selected['Description'] = df_selected['Description'].astype(str)
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#Number of characters in message custom feature
df_selected['description_length'] = df_selected['Description'].apply(len)
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Number of hashtags custom feature
df_selected['hashtag_count'] = df_selected['Description'].apply(lambda x : x.count('#'))
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Social Engagement Score
df_selected['social_engagement_score'] = (df_selected['Likes'] + df_selected['Comments']) / df_selected['Followers at Posting']
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Set the types.
print(Counter(df_selected['Type']))
types = ['Photo', 'Video', 'Album']
#Combine Photo and Album
df_selected.loc[df_selected.Type == 'Album', 'Type'] = "Photo"
# Out:
# Counter({'Photo': 290276, 'Video': 86889, 'Album': 8216})
# C:\Users\oldye\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
Counter(df_selected['Type'])
# Out:
# Counter({'Photo': 298492, 'Video': 86889})

# %%
#OHE for Type Field
df_selected = pd.concat([df_selected,pd.get_dummies(df_selected['Type'],prefix='type')],axis=1)

# %%
def time_of_day_creation(x):
    '''
    Takes in an integer and returns one of four time slots:
    ['12am-6am', '6am-12pm', '12pm-6pm', '6pm-12am']
    '''
    
    slots_out = ['created_12am-6am', 'created_6am-12pm', 'created_12pm-6pm', 'created_6pm-12am']
    slot0 = np.arange(0,6)
    slot1 = np.arange(6,12)
    slot2 = np.arange(12,18)
    slot3 = np.arange(18,24)

    if x in slot0:
        return slots_out[0]
    elif x in slot1:
        return slots_out[1]
    elif x in slot2:
        return slots_out[2]
    elif x in slot3:
        return slots_out[3]
    else:
        return 'NaN'

# %%
#Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
#time_of_day_creation(df_selected['Created'][200].hour)
#df_selected['time_of_day'] = [time_of_day_creation(x) for x in df_selected['Created']]

# %%
#Creating time of day buckets (e.g. 0-6am, 6-12pm, 12-6, 6-12am)
df_selected['time_of_day'] = df_selected['Created'].apply(lambda x : time_of_day_creation(x.hour))

# %%
#OHE for time of day field
df_selected = pd.concat([df_selected,pd.get_dummies(df_selected['time_of_day'])],axis=1)

# %%
Counter(df_selected['time_of_day'])
# Out:
# Counter({'created_12am-6am': 55798,
#          'created_6am-12pm': 62653,
#          'created_12pm-6pm': 143588,
#          'created_6pm-12am': 123342})

# %%
#Time between prior and current post
df_selected.sort_values(by=['User Name','Created'], inplace=True)
df_selected['time_since_last_post'] = df_selected.groupby('User Name')['Created'].diff()

# %%
#Dropping extraneous columns 
df_selected.drop(['Likes','Comments','Views','time_of_day','index'],axis=1,inplace=True)
df_selected.drop('Type',axis=1,inplace=True)

# %%
df_selected[df_selected['User Name'] == 'shakira']
# Out:
#        User Name  Followers at Posting             Created  \
# 7195     shakira                   NaN 2012-10-12 06:42:16
# 7265     shakira                   NaN 2012-10-13 10:10:35
# 7297     shakira                   NaN 2012-10-13 16:07:02
# 7340     shakira                   NaN 2012-10-14 11:58:16
# 7341     shakira                   NaN 2012-10-14 12:42:41
# 7351     shakira                   NaN 2012-10-14 17:08:39
# 7352     shakira                   NaN 2012-10-14 17:13:29
# 7478     shakira                   NaN 2012-10-16 18:24:03
# 7480     shakira                   NaN 2012-10-16 18:30:13
# 7591     shakira                   NaN 2012-10-18 14:21:15
# 7662     shakira                   NaN 2012-10-19 04:26:05
# 8083     shakira                   NaN 2012-10-25 17:07:48
# 8085     shakira                   NaN 2012-10-25 17:10:01
# 8086     shakira                   NaN 2012-10-25 17:13:14
# 9851     shakira                   NaN 2012-11-19 19:27:01
# 10398    shakira                   NaN 2012-11-27 11:52:31
# 10754    shakira                   NaN 2012-12-01 18:44:19
# 12715    shakira                   NaN 2012-12-30 16:03:43
# 12716    shakira                   NaN 2012-12-30 16:05:19
# 13420    shakira                   NaN 2013-01-10 12:12:07
# 13769    shakira                   NaN 2013-01-16 11:16:58
# 13770    shakira                   NaN 2013-01-16 11:18:13
# 15018    shakira                   NaN 2013-02-02 18:12:42
# 15564    shakira                   NaN 2013-02-10 14:28:56
# 15942    shakira                   NaN 2013-02-14 17:23:09
# 16534    shakira                   NaN 2013-02-22 10:50:17
# 16537    shakira                   NaN 2013-02-22 11:51:29
# 16538    shakira                   NaN 2013-02-22 11:56:41
# 19021    shakira                   NaN 2013-03-22 11:18:48
# 19221    shakira                   NaN 2013-03-24 08:29:43
# ...          ...                   ...                 ...
# 374355   shakira            56165731.0 2019-04-17 16:58:37
# 15018   Gracias a todos por sus felicitaciones y bueno...   -33.8
# 15564   Su primera salida oficial al Camp Nou, con gol...   -8.84
# 15942   Happy Valentine's Day! Feliz Día de San Valent...  -21.14
# 16534   I want to thank all of you for your generosity...  -31.93
# 16537   Milan's friends helped collect 80k polio vacci...  -26.08
# 16538   Milan's friends helped collect 80k polio vacci...  -29.28
# 19021   I can't help it! I had to share this! / Milan ...   -9.51
# 19221      Shakira in Paris! / Shakira à Paris! ShakiraHQ  -16.86
# ...                                                   ...     ...
# 374355  Querido Gabo, te recordamos para mantenerte vi...    1.26
# 374456  Tratar de resumir una persona tan grande en po...    1.41
# 374566  The video for Loca has just passed 500 million...    2.42
# 374605                         Good Friday drawings! Shak   -1.19
# 374783  Hay que ver sus caritas de felicidad! To see t...   -1.15
# 375005  My team at  @sonymusiclatin... Best team in th...   -1.34
# 375601  Muchísimas gracias a todos por los premios @La...    1.84
# 375785  Discover DREAM, the new perfume by Shakira. De...    1.23
# 376831  Gracias Barça.\n\nPor regalarnos tantas alegrí...    1.33
# 377113  1.7 millones de votos ayudaron a Shak a crear ...   -1.01
# 377447  Felicidades a la mía y a todas nuestras madres...     2.1
# 377499  Con  los estudiantes emprendedores de nuestras...   -1.48
# 377634  Un poco tiesa pero han sido dos años sin jugar...   -1.75
# 377707  ~ Artist, woman, mother, traveler. This is #WH...   -1.76
# 378274  Today, Paddle surf! Hoy, Paddle Surf! \nY para...   -1.07
# 378673  Check out this behind-the-scenes film from Sha...   -1.73
# 378752                          Cherries!! Cerezas!! Shak    1.79
# 379668  Gracias Adrián!!! Increíble! \nShak \n#Repost ...     1.9
# 379776  The video for 'No' from Fijación Oral, Vol. 1 ...    1.87
# 380005                    Soy un koala! I’m a koala! Shak    5.45
# 380396  Check out these exclusive, unseen images from ...    2.05
# 380864          Sorpresa! Con mi amigo Ale en 3’ segundos    1.98
# 380876  Minutos antes de salir con @alejandrosanz esta...    1.81
# 380881  Un abrazo de un amigo - @alejandrosanz - es un...   -1.37
# 380895  Gracias Ale - @alejandrosanz - por regalarme e...   -1.26
# 380917         Esta es la pose de “miren mis flecos” Shak   -2.09
# 380918         Esta es la pose de “miren mis flecos” Shak    1.74
# 380932  Gracias por esas palabras y ese recibimiento!!...     1.5
# 380943                               En paz / peace. Shak     2.5
# 381177  Poniéndome a punto en las artes marciales con ...    1.92
#
#         description_length  hashtag_count  social_engagement_score  \
# 7195                    41              0                      NaN
# 7265                   180              3                      NaN
# 7297                   230              0                      NaN
# 7340                   107              1                      NaN
# 7341                   115              1                      NaN
# 7351                    73              1                      NaN
# 7352                    62              1                      NaN
# 7478                   174              2                      NaN
# 7480                   138              2                      NaN
# 7591                    48              0                      NaN
# 7662                    86              0                      NaN
# 8083                   147              1                      NaN
# 8085                   136              0                      NaN
# 8086                   112              1                      NaN
# 9851                   113              0                      NaN
# 10398                   75              0                      NaN
# 10754                   48              0                      NaN
# 12715                  127              2                      NaN
# 12716                  135              1                      NaN
# 13420                  147              1                      NaN
# 13769                  143              1                      NaN
# 13770                  133              2                      NaN
df_selected['posts_last_30days'] = 0 #to be removed once real coding is available
df_selected['within_week_release'] = 0 #to be removed once real coding is available
df_selected['within_month_release'] = 0 #to be removed once real coding is available

# %%
df_selected.sample(4).T
# Out:
#                                                    124755  \
# artist_name                                  camilomusica
# count_of_followers                                    NaN
# created                               2015-03-21 16:33:46
# description              ¿Qué, una pola? \n#ITSMILLERTIME
# crowdtangle_score                                   -7.93
# description_length                                     31
# hashtag_count                                           1
# social_engagement_score                               NaN
# type_photo                                              1
# type_video                                              0
# created_12am-6am                                        0
# created_12pm-6pm                                        1
# created_6am-12pm                                        0
# created_6pm-12am                                        0
# time_since_last_post                      0 days 22:58:44
# type_text                                               0
# type_link                                               0
# posts_last_7days                                        0
# posts_last_30days                                       0
# within_week_release                                     0
# within_month_release                                    0
#
#                                                                     219483  \
# artist_name                                                         noriel
# count_of_followers                                                     NaN
# created                                                2016-07-18 20:40:29
# description              Faltan 4 Dias Pa Que Salga #Diablita To El Que...
# crowdtangle_score                                                   -11.92
# description_length                                                     224
# hashtag_count                                                            1
# social_engagement_score                                                NaN
# type_photo                                                               1
# type_video                                                               0
# created_12am-6am                                                         0
# created_12pm-6pm                                                         0
# created_6am-12pm                                                         0
# created_6pm-12am                                                         1
# time_since_last_post                                       0 days 03:26:36
# type_text                                                                0
# type_link                                                                0
# posts_last_7days                                                         0
# posts_last_30days                                                        0
# within_week_release                                                      0
# within_month_release                                                     0
#
#                                                361579  \
# artist_name                                 johnmayer
# count_of_followers                        3.81632e+06
# created                           2018-12-22 21:59:13
# description              @bravoandy cool if I post? 🎄
# crowdtangle_score                                 1.5
# description_length                                 28
# hashtag_count                                       0
# social_engagement_score                      0.082655
# type_photo                                          1
# type_video                                          0
# created_12am-6am                                    0
# created_12pm-6pm                                    0
# created_6am-12pm                                    0
# created_6pm-12am                                    1
# time_since_last_post                  1 days 18:23:59
# type_text                                           0
# type_link                                           0
# posts_last_7days                                    0
# posts_last_30days                                   0
# within_week_release                                 0
# within_month_release                                0
#
#                                                                     160926
# artist_name                                                      scorpions
# count_of_followers                                                     NaN
# created                                                2015-09-24 16:36:54
# description              "Coming Home", the unreleased demo from the de...
# crowdtangle_score                                                    -2.96
# description_length                                                     112
# hashtag_count                                                            1
# social_engagement_score                                                NaN
# type_photo                                                               0
# type_video                                                               1
# created_12am-6am                                                         0
# created_12pm-6pm                                                         1
# created_6am-12pm                                                         0
# created_6pm-12am                                                         0
# time_since_last_post                                       1 days 23:58:13
# type_text                                                                0
# type_link                                                                0
# posts_last_7days                                                         0
# posts_last_30days                                                        0
# within_week_release                                                      0
# within_month_release                                                     0

# %%
df_selected.to_csv('instagram_7yrs_cleaned.csv')

# %% [markdown]
# ##### Aggregation Code (v1)

# %%
#convert times to rounded hours
df['Created'] = df.Created.dt.floor('H')

# %%
#Omitting aggregation for v2
df_aggregate = df.groupby(["User Name", "Created"], as_index=False).agg({"Account": "count"})

# %%
df_aggregate[0:3]
# Out:
#   User Name             Created  Account
# 0  21savage 2012-07-06 03:00:00        1
# 1  21savage 2012-08-04 05:00:00        1
# 2  21savage 2012-08-11 23:00:00        2

# %%
#df.rename(columns={'Created':'PostTime'},inplace=True)
df_aggregate.rename(columns={'Account':'Count'},inplace=True)

# %%
df_aggregate.to_csv('instagram_7yrs_agg.csv')

# %% [markdown]
# ## Reducing data to top 5 artists for exploratory analysis
# Justin Timberlake
# Maluma
# Pink
# Avril Lavigne
# Willie Nelson

# %%
top_5 = ['justintimberlake', 'maluma', 'pink', 'avrillavigne', 'willienelsonofficial']
df_top5 = df[df['User Name'].isin(top_5)]

# %%
set(df_top5['User Name'])
# Out:
# {'avrillavigne', 'justintimberlake', 'maluma', 'pink', 'willienelsonofficial'}

# %%
df_top5.shape
# Out:
# (10565, 15)

# %%
# Get one artist
df_j = df_top5[df_top5['User Name'] == top_5[0]]

# %%
#Posts by hour of day
df_j['Account'].groupby(df_j['Created'].dt.hour).count().plot(kind='line')

# %%
#Displaying for each user, their posts by hour aggregated for all time periods. 
df_top5.groupby(['User Name',df_top5['Created'].dt.hour]).count()['Account'].unstack('User Name').plot(kind='line')

#Users post heavily beginning around 10-11am and start slowing down around 8pm.

# %%
fig, ax = plt.subplots(figsize=(12,7))
df_top5['User Name'].value_counts().plot(ax=ax,kind='bar')
plt.plot()

# %% [markdown]
# ##### Just for Justin Timberlake

# %%
#Have to change index to datetime in order to do groupings I want
df_j.index = df_j['Created']

# %%
df_j = df_j.resample('M', how='count')
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(df_j.index,df_j['Account'])

# %% [markdown]
# ###### For Top 5 artists

# %%
df_top5.index = df_top5['Created']

# %%
df_top5['month'] = df_top5['Created'].dt.month
df_top5['year'] = df_top5['Created'].dt.year
# Out:
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\oldye\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_top5.sample(5)
# Out:
#                            Account     User Name  Followers at Posting  \
# Created
# 2016-02-15 00:00:00  Avril Lavigne  avrillavigne             2729081.0
# 2017-12-11 17:00:00         MALUMA        maluma            30001009.0
# 2016-02-20 18:00:00         MALUMA        maluma             9520736.0
# 2016-09-29 22:00:00         MALUMA        maluma            16229201.0
# 2018-04-08 17:00:00         MALUMA        maluma            32082976.0
#
#                                 Created   Type   Likes  Comments   Views  \
# Created
# 2016-02-15 00:00:00 2016-02-15 00:00:00  Photo  102235       807       0
# 2017-12-11 17:00:00 2017-12-11 17:00:00  Photo  362526      6852       0
# 2016-02-20 18:00:00 2016-02-20 18:00:00  Video   87582      1620  542196
# 2016-09-29 22:00:00 2016-09-29 22:00:00  Video  182153      6774  618574
# 2018-04-08 17:00:00 2018-04-08 17:00:00  Album  528834      3834       0
#
#                                                           URL  \
# Created
# 2016-02-15 00:00:00  https://www.instagram.com/p/BBy2OUII4Mu/
# 2017-12-11 17:00:00  https://www.instagram.com/p/Bck_lMPlelM/
# 2016-02-20 18:00:00  https://www.instagram.com/p/BCBwF7nx-m6/
# 2016-09-29 22:00:00  https://www.instagram.com/p/BK9rddnDUNd/
# 2018-04-08 17:00:00  https://www.instagram.com/p/BhUyYcYF3Vg/
#
#                                                          Link  \
# Created
# 2016-02-15 00:00:00  https://www.instagram.com/p/BBy2OUII4Mu/
# 2017-12-11 17:00:00  https://www.instagram.com/p/Bck_lMPlelM/
# 2016-02-20 18:00:00  https://www.instagram.com/p/BCBwF7nx-m6/
# 2016-09-29 22:00:00  https://www.instagram.com/p/BK9rddnDUNd/
# 2018-04-08 17:00:00  https://www.instagram.com/p/BhUyYcYF3Vg/
#
#                                                                  Photo  \
# Created
# 2016-02-15 00:00:00  https://scontent.cdninstagram.com/t51.2885-15/...
# 2017-12-11 17:00:00  https://scontent.cdninstagram.com/t51.2885-15/...
# 2016-02-20 18:00:00  https://scontent.cdninstagram.com/t51.2885-15/...
# 2016-09-29 22:00:00  https://scontent.cdninstagram.com/t51.2885-15/...
# 2018-04-08 17:00:00  https://scontent.xx.fbcdn.net/v/t51.2885-15/29...
#
#                                                            Description  \
# Created
# 2016-02-15 00:00:00     Dinner with Alice Cooper. #legend #grammyparty
# 2017-12-11 17:00:00  30 MILLONES!! Somos una familia muy numerosa, ...
# 2016-02-20 18:00:00  #Repost @katika_gomez\n・・・\nTe Amo Hermosa 💕👸👊...
# 2016-09-29 22:00:00  De camino a Bolivia. Mañana nos vemos en La Pa...
# 2018-04-08 17:00:00  @ricky_martin Que enorme placer compartir el e...
#
#                      Sponsor Id Sponsor Name  Score  month  year
# Created
# 2016-02-15 00:00:00         NaN          NaN  -1.49      2  2016
# 2017-12-11 17:00:00         NaN          NaN  -2.37     12  2017
# 2016-02-20 18:00:00         NaN          NaN  -3.16      2  2016
# 2016-09-29 22:00:00         NaN          NaN  -1.52      9  2016
# 2018-04-08 17:00:00         NaN          NaN  -1.48      4  2018

# %%
a = df_top5.groupby(['year','month','User Name']).count()['Account'].unstack('User Name')
df_top5.groupby(['year','month','User Name']).count()['Account'].unstack('User Name').plot(figsize=(20,7))

#how to get x axis to be more detailed... not working
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))


#would love to put dots where we had album / track releases... how to do?? Code below not functional
markers_on = [50, 70, 90, 1000]
plt.plot(markevery=markers_on)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-568fd0f8bf10> in <module>
#       3
#       4 #how to get x axis to be more detailed... not working
# ----> 5 ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
#       6
#       7
#
# NameError: name 'ax' is not defined

# %%
#Trying to do the above plot in a different way so I can control the x axis
daterange = pd.date_range(min(df_top5['Created']),max(df_top5['Created']),periods=len(a))
fig = plt.figure(figsize=(20,7))
ax = fig.add_subplot(1,1,1)
markers_on = [1,10, 50, 70]
for name in top_5:
    ax.plot(daterange,a[name])
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=4)) #how to get to show months instead?

# %%
daterange.shape
# Out:
# (85,)

# %%
a[name].shape
# Out:
# (85,)

# %% [markdown]
# ##### Number of Followers Review

# %%
df_top5.shape
# Out:
# (10565, 17)

# %%
print("NAs for # of followers: ", df_top5['Followers at Posting'].isna().sum())
# Out:
# NAs for # of followers:  3981
