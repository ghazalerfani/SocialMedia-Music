# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.decomposition import KernelPCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabaz_score

# %%
df = pd.read_pickle('Combined_Social_Data_Pickle.pkl')

# %%
df.head(5).T
# Out:
#                                                                        0  \
# Facebook                                                               1
# Instagram                                                              0
# Twitter                                                                0
# Youtube                                                                0
# age                                                                   26
# artist_name_x                                                   21Savage
# artist_name_y                                                  21 Savage
# count_of_followers                                                   NaN
# created                                              2015-05-18 15:24:23
# created_12am-6am                                                       0
# created_12pm-6pm                                                       1
# created_6am-12pm                                                       0
# created_6pm-12am                                                       0
# crowdtangle_score                                                 -354.2
# description                                Slaughter Tape coming 5.25.15
# description_length                                                    29
# facebook                                                        21Savage
# genre_electronic                                                       0
# genre_hip_hop                                                          1
# genre_pop                                                              0
# genre_r_and_b                                                          0
# genre_rock                                                             0
# genre_world_music                                                      0
# hashtag_count                                                          0
# instagram                                                       21savage
# last_30_days                                                         NaN
# last_7_days                                                          NaN
# musicbrainz                         37b2cb82-ef79-4d46-a184-a549450aa231
# social_engagement_score                                              NaN
# time_since_last_post                                                 NaN
# twitter                                                         21savage
# type_link                                                              0
# type_photo                                                             0
# type_text                                                              1
# type_video                                                             0
# within_month_release                                                   0
# within_week_release                                                    0
# years_active                                                           5
# youtube                                                        21 Savage
# social_platform                                                 Facebook
# normalized_social_engagement_score                                   NaN
# num_days_to_track_release                                              7
#
#                                                                             1  \
# Facebook                                                                    1
# Instagram                                                                   0
# Twitter                                                                     0
# Youtube                                                                     0
# age                                                                        26
# artist_name_x                                                        21Savage
# artist_name_y                                                       21 Savage
# count_of_followers                                                        NaN
# created                                                   2015-05-25 12:00:00
# created_12am-6am                                                            0
# created_12pm-6pm                                                            1
# created_6am-12pm                                                            0
# created_6pm-12am                                                            0
# crowdtangle_score                                                       -16.5
# description                         The Slaughter Tape released May 25, 2015.
# description_length                                                         41
# facebook                                                             21Savage
# genre_electronic                                                            0
# genre_hip_hop                                                               1
# genre_pop                                                                   0
# genre_r_and_b                                                               0
# genre_rock                                                                  0
# genre_world_music                                                           0
# hashtag_count                                                               0
# instagram                                                            21savage
# last_30_days                                                              NaN
# last_7_days                                                               NaN
# musicbrainz                              37b2cb82-ef79-4d46-a184-a549450aa231
# social_engagement_score                                                   NaN
# time_since_last_post                                6 days 20:35:37.000000000
# twitter                                                              21savage
# type_link                                                                   0
# type_photo                                                                  1
# type_text                                                                   0
# type_video                                                                  0
# within_month_release                                                        0
# within_week_release                                                         0
# years_active                                                                5
# youtube                                                             21 Savage
# social_platform                                                      Facebook
# normalized_social_engagement_score                                        NaN
# num_days_to_track_release                                                   0
#
#                                                                                     2  \
# Facebook                                                                            1
# Instagram                                                                           0
# Twitter                                                                             0
# Youtube                                                                             0
# age                                                                                26
# artist_name_x                                                                21Savage
# artist_name_y                                                               21 Savage
# count_of_followers                                                                NaN
# created                                                           2015-05-25 18:26:12
# created_12am-6am                                                                    0
# created_12pm-6pm                                                                    0
# created_6am-12pm                                                                    0
# created_6pm-12am                                                                    1
# crowdtangle_score                                                               -62.3
# description                         s/o The FADER for fuckin wit me http://www.the...
# description_length                                                                107
# facebook                                                                     21Savage
# genre_electronic                                                                    0
# genre_hip_hop                                                                       1
# genre_pop                                                                           0
# genre_r_and_b                                                                       0
# genre_rock                                                                          0
# genre_world_music                                                                   0
# hashtag_count                                                                       0
# instagram                                                                    21savage
# last_30_days                                                                      NaN
# last_7_days                                                                       NaN
# musicbrainz                                      37b2cb82-ef79-4d46-a184-a549450aa231
# social_engagement_score                                                           NaN
# time_since_last_post                                        0 days 06:26:12.000000000
# twitter                                                                      21savage
# type_link                                                                           1
# type_photo                                                                          0
# type_text                                                                           0
# type_video                                                                          0
# within_month_release                                                                0
# within_week_release                                                                 0
# years_active                                                                        5
# youtube                                                                     21 Savage
# social_platform                                                              Facebook
# normalized_social_engagement_score                                                NaN
# num_days_to_track_release                                                           0
#
#                                                                                     3  \
# Facebook                                                                            1
# Instagram                                                                           0
# Twitter                                                                             0
# Youtube                                                                             0
# age                                                                                26
# artist_name_x                                                                21Savage
# artist_name_y                                                               21 Savage
# count_of_followers                                                                NaN
# created                                                           2015-08-14 12:00:00
# created_12am-6am                                                                    0
# created_12pm-6pm                                                                    1
# created_6am-12pm                                                                    0
# created_6pm-12am                                                                    0
# crowdtangle_score                                                              -12.26
# description                         21 Savage with OPB & Slaughter Gang members be...
# description_length                                                                 75
# facebook                                                                     21Savage
# genre_electronic                                                                    0
# genre_hip_hop                                                                       1
# genre_pop                                                                           0
# genre_r_and_b                                                                       0
# genre_rock                                                                          0
# genre_world_music                                                                   0
# hashtag_count                                                                       0
# instagram                                                                    21savage
# last_30_days                                                                      NaN
# last_7_days                                                                       NaN
# musicbrainz                                      37b2cb82-ef79-4d46-a184-a549450aa231
# social_engagement_score                                                           NaN
# time_since_last_post                                       80 days 17:33:48.000000000
# twitter                                                                      21savage
# type_link                                                                           0
# type_photo                                                                          1
# type_text                                                                           0
# type_video                                                                          0
# within_month_release                                                                0
# within_week_release                                                                 0
# years_active                                                                        5
# youtube                                                                     21 Savage
# social_platform                                                              Facebook
# normalized_social_engagement_score                                                NaN
# num_days_to_track_release                                                          43
#
#                                                                                     4
# Facebook                                                                            1
# Instagram                                                                           0
# Twitter                                                                             0
# Youtube                                                                             0
# age                                                                                26
# artist_name_x                                                                21Savage
# artist_name_y                                                               21 Savage
# count_of_followers                                                                NaN
# created                                                           2015-09-05 12:00:00
# created_12am-6am                                                                    0
# created_12pm-6pm                                                                    1
# created_6am-12pm                                                                    0
# created_6pm-12am                                                                    0
# crowdtangle_score                                                              -24.89
# description                         21 Savage performs during Speakerfoxxx's set a...
# description_length                                                                100
# facebook                                                                     21Savage
# genre_electronic                                                                    0
# genre_hip_hop                                                                       1
# genre_pop                                                                           0
# genre_r_and_b                                                                       0
# genre_rock                                                                          0
# genre_world_music                                                                   0
# hashtag_count                                                                       0
# instagram                                                                    21savage
# last_30_days                                                                      NaN
# last_7_days                                                                       NaN
# musicbrainz                                      37b2cb82-ef79-4d46-a184-a549450aa231
# social_engagement_score                                                           NaN
# time_since_last_post                                       22 days 00:00:00.000000000
# twitter                                                                      21savage
# type_link                                                                           0
# type_photo                                                                          1
# type_text                                                                           0
# type_video                                                                          0
# within_month_release                                                                0
# within_week_release                                                                 0
# years_active                                                                        5
# youtube                                                                     21 Savage
# social_platform                                                              Facebook
# normalized_social_engagement_score                                                NaN
# num_days_to_track_release                                                          65

# %%
df.shape
# Out:
# (1084355, 42)

# %% [markdown]
# ## Data Cleaning for Machine Learning

# %%
#Only use data from 1/1/16 to 6/1/19
df = df[(df['created']>pd.to_datetime('01-01-2016')) & (df['created']<pd.to_datetime('06-01-2019'))]

# %%
print(min(df.created))
print(max(df.created))
# Out:
# 2016-01-01 00:00:01
# 2019-05-31 23:46:40

# %%
df.shape
# Out:
# (681571, 42)

# %%
df.columns
# Out:
# Index(['Facebook', 'Instagram', 'Twitter', 'Youtube', 'age', 'artist_name_x',
#        'artist_name_y', 'count_of_followers', 'created', 'created_12am-6am',
#        'created_12pm-6pm', 'created_6am-12pm', 'created_6pm-12am',
#        'crowdtangle_score', 'description', 'description_length', 'facebook',
#        'genre_electronic', 'genre_hip_hop', 'genre_pop', 'genre_r_and_b',
#        'genre_rock', 'genre_world_music', 'hashtag_count', 'instagram',
#        'last_30_days', 'last_7_days', 'musicbrainz', 'social_engagement_score',
#        'time_since_last_post', 'twitter', 'type_link', 'type_photo',
#        'type_text', 'type_video', 'within_month_release',
#        'within_week_release', 'years_active', 'youtube', 'social_platform',
#        'normalized_social_engagement_score', 'num_days_to_track_release'],
#       dtype='object')

# %%
#Intentionally leaving out social engagement score, genre for now.
#Omitting within_month and within_week_release since we have num_days_to_track_release
#artist_name_x will need to be removed before GMM
#NLP features should be added once available
features_to_use = ['Facebook','Instagram','Twitter','Youtube','age','artist_name_x','created_12am-6am',
                   'created_12pm-6pm','created_6am-12pm','created_6pm-12am','description_length','hashtag_count',
                   'last_30_days','last_7_days','time_since_last_post','type_link','type_photo','type_text',
                   'type_video','years_active','num_days_to_track_release', 'genre_electronic', 'genre_hip_hop', 
                   'genre_pop', 'genre_r_and_b','genre_rock', 'genre_world_music']

# %%
df = df[features_to_use]

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (648894, 27)

# %%
df['time_since_last_post'] = pd.to_timedelta(df['time_since_last_post'])
df['time_since_last_post'] = [x.total_seconds() for x in df['time_since_last_post']]

# %%
df.head().T
# Out:
#                                    702          703          704          705  \
# Facebook                             1            1            1            1
# Instagram                            0            0            0            0
# Twitter                              0            0            0            0
# Youtube                              0            0            0            0
# age                                 37           37           37           37
# artist_name_x              AdamLambert  AdamLambert  AdamLambert  AdamLambert
# created_12am-6am                     0            0            0            0
# created_12pm-6pm                     1            1            0            1
# created_6am-12pm                     0            0            1            0
# created_6pm-12am                     0            0            0            0
# description_length                  32           79           73          352
# hashtag_count                        0            2            1            1
# last_30_days                         1            2            4            4
# last_7_days                          1            2            4            4
# time_since_last_post            153999       253878       166567        20084
# type_link                            0            0            1            0
# type_photo                           1            0            0            1
# type_text                            0            0            0            0
# type_video                           0            1            0            0
# years_active                        18           18           18           18
# num_days_to_track_release           76           73           71           71
# genre_electronic                     0            0            0            0
# genre_hip_hop                        0            0            0            0
# genre_pop                            1            1            1            1
# genre_r_and_b                        0            0            0            0
# genre_rock                           1            1            1            1
# genre_world_music                    0            0            0            0
#
#                                    706
# Facebook                             1
# Instagram                            0
# Twitter                              0
# Youtube                              0
# age                                 37
# artist_name_x              AdamLambert
# created_12am-6am                     0
# created_12pm-6pm                     1
# created_6am-12pm                     0
# created_6pm-12am                     0
# description_length                  94
# hashtag_count                        0
# last_30_days                         5
# last_7_days                          5
# time_since_last_post             84560
# type_link                            1
# type_photo                           0
# type_text                            0
# type_video                           0
# years_active                        18
# num_days_to_track_release           70
# genre_electronic                     0
# genre_hip_hop                        0
# genre_pop                            1
# genre_r_and_b                        0
# genre_rock                           1
# genre_world_music                    0

# %%
df2 = df.drop(columns='artist_name_x')

# %% [markdown]
# ## Data Standardization / Normalization

# %%
#Check for skew
df2.hist(figsize = (20,15))
plt.show()

# %%
df2.describe()
# Out:
#             Facebook      Instagram        Twitter        Youtube  \
# count  648894.000000  648894.000000  648894.000000  648894.000000
# mean        0.243943       0.325207       0.428902       0.001948
# std         0.429459       0.468453       0.494920       0.044092
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       1.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                  age  created_12am-6am  created_12pm-6pm  created_6am-12pm  \
# count  648894.000000     648894.000000     648894.000000     648894.000000
# mean       38.137452          0.174814          0.344255          0.151063
# std        12.045193          0.379809          0.475125          0.358111
# min        15.000000          0.000000          0.000000          0.000000
# 25%        28.000000          0.000000          0.000000          0.000000
# 50%        38.000000          0.000000          0.000000          0.000000
# 75%        45.000000          0.000000          1.000000          0.000000
# max        78.000000          1.000000          1.000000          1.000000
#
#        created_6pm-12am  description_length  ...      type_text  \
# count     648894.000000       648894.000000  ...  648894.000000
# mean           0.329867          101.378313  ...       0.087410
# std            0.470165          102.979097  ...       0.282436
# min            0.000000            1.000000  ...       0.000000
# 25%            0.000000           38.000000  ...       0.000000
# 50%            0.000000           80.000000  ...       0.000000
# 75%            1.000000          135.000000  ...       0.000000
# max            1.000000         1000.000000  ...       1.000000
#
#           type_video   years_active  num_days_to_track_release  \
# count  648894.000000  648894.000000              648894.000000
# mean        0.206669      20.224759                  86.745284
# std         0.404916      12.259262                 184.464335
# min         0.000000       1.000000                   0.000000
# 25%         0.000000      11.000000                   7.000000
# 50%         0.000000      18.000000                  24.000000
# 75%         0.000000      28.000000                  83.000000
# max         1.000000      68.000000                3064.000000
#
#        genre_electronic  genre_hip_hop      genre_pop  genre_r_and_b  \
# count     648894.000000  648894.000000  648894.000000  648894.000000
# mean           0.048994       0.336064       0.336392       0.305373
# std            0.215856       0.472361       0.472475       0.460566
# min            0.000000       0.000000       0.000000       0.000000
# 25%            0.000000       0.000000       0.000000       0.000000
# 50%            0.000000       0.000000       0.000000       0.000000
# 75%            0.000000       1.000000       1.000000       1.000000
# max            1.000000       1.000000       1.000000       1.000000
#
#           genre_rock  genre_world_music
# count  648894.000000      648894.000000
# mean        0.148528           0.178596
# std         0.355623           0.383014
# min         0.000000           0.000000
# 25%         0.000000           0.000000
# 50%         0.000000           0.000000
# 75%         0.000000           0.000000
# max         1.000000           1.000000
#
# [8 rows x 26 columns]

# %%
# Most of the continuous features appear skewed right
skews = ['years_active','num_days_to_track_release','time_since_last_post','last_7_days','last_30_days',
        'hashtag_count','description_length','age']

# %% [markdown]
# Non-positive values can't be boxcoxed...
#
# num_days_to_track_release
#
# time_since_last_post
#
# last_7_days
#
# last_30_days
#
# hashtag_count

# %%
#df2['age'], _ = boxcox(df2['age'])

# %%
#Necessary to use this method instead of boxcox since we have 'zero' values in many of the features and
#boxcox is only capable of working with positive values.
pt = PowerTransformer(method='yeo-johnson', standardize=False)
for skew in skews:
    df2[skew] = pt.fit_transform(np.array(df2[skew]).reshape(-1, 1))

# %%
#Check for skew
df2.hist(figsize = (20,15))
plt.show()

# %%
scaler = StandardScaler()
df2_norm = scaler.fit_transform(df2)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
df2_norm.shape
# Out:
# (648894, 26)

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# ### PCA

# %%
pca_nd = PCA(n_components=10)
df2_norm_pca_nd = pca_nd.fit_transform(df2_norm)

# %%
# to be used for charting in 3D
pca_3d = PCA(n_components=3)
df2_norm_pca_3d = pca_3d.fit_transform(df2_norm)

# %%
# %%time
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df2_norm_pca_3d[:, 0], df2_norm_pca_3d[:, 1], df2_norm_pca_3d[:, 2], c='r', marker='o')
plt.show()
# Out:
# CPU times: user 40.2 s, sys: 716 ms, total: 40.9 s
# Wall time: 40.7 s

# %%
# Use variance ratio to understand how many components we should use
# based on PCA, we need 16 components to capture all variance
pca = PCA()
df2_norm_pca_n = pca.fit(df2_norm)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.13342223, 0.23157231, 0.32416849, 0.38552768, 0.44288368,
#        0.49757261, 0.5499724 , 0.59880018, 0.64443793, 0.68770698,
#        0.73009782, 0.76910205, 0.80686447, 0.84356917, 0.87728448,
#        0.90565492, 0.93055186, 0.95129195, 0.97025767, 0.98776091,
#        0.99458247, 0.99744442, 1.        , 1.        , 1.        ,
#        1.        ])

# %% [markdown]
# ### Kernel PCA

# %%
# # this kills the kernel everytime
# from sklearn.decomposition import KernelPCA
# kpca = KernelPCA(n_components=3, kernel="poly")
# df2_norm_kpca = kpca.fit_transform(df2_norm)

# %% [markdown]
# ### t-SNE (with PCA initialization)

# %%
# %%time
# we can also adjust perplexity, learning rate, and number of iterations
tsne = TSNE(n_components=3, random_state=0,n_iter=400, verbose=3)  
df2_norm_tsne_full = tsne.fit_transform(df2_norm_pca_nd)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 648894 samples in 0.773s...
# [t-SNE] Computed neighbors for 648894 samples in 112.331s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 648894
# [t-SNE] Computed conditional probabilities for sample 2000 / 648894
# [t-SNE] Computed conditional probabilities for sample 3000 / 648894
# [t-SNE] Computed conditional probabilities for sample 4000 / 648894
# [t-SNE] Computed conditional probabilities for sample 5000 / 648894
# [t-SNE] Computed conditional probabilities for sample 6000 / 648894
# [t-SNE] Computed conditional probabilities for sample 7000 / 648894
# [t-SNE] Computed conditional probabilities for sample 8000 / 648894
# [t-SNE] Computed conditional probabilities for sample 9000 / 648894
# [t-SNE] Computed conditional probabilities for sample 10000 / 648894
# [t-SNE] Computed conditional probabilities for sample 11000 / 648894
# [t-SNE] Computed conditional probabilities for sample 12000 / 648894
# [t-SNE] Computed conditional probabilities for sample 13000 / 648894
# [t-SNE] Computed conditional probabilities for sample 14000 / 648894
# [t-SNE] Computed conditional probabilities for sample 15000 / 648894
# [t-SNE] Computed conditional probabilities for sample 16000 / 648894
# [t-SNE] Computed conditional probabilities for sample 17000 / 648894
# [t-SNE] Computed conditional probabilities for sample 18000 / 648894
# [t-SNE] Computed conditional probabilities for sample 19000 / 648894
# [t-SNE] Computed conditional probabilities for sample 20000 / 648894
# [t-SNE] Computed conditional probabilities for sample 21000 / 648894
# [t-SNE] Computed conditional probabilities for sample 22000 / 648894
# [t-SNE] Computed conditional probabilities for sample 23000 / 648894
# [t-SNE] Computed conditional probabilities for sample 24000 / 648894
# [t-SNE] Computed conditional probabilities for sample 25000 / 648894
# [t-SNE] Computed conditional probabilities for sample 26000 / 648894
# [t-SNE] Computed conditional probabilities for sample 27000 / 648894
# [t-SNE] Computed conditional probabilities for sample 28000 / 648894
# [t-SNE] Computed conditional probabilities for sample 29000 / 648894
# [t-SNE] Computed conditional probabilities for sample 30000 / 648894
# [t-SNE] Computed conditional probabilities for sample 31000 / 648894
# [t-SNE] Computed conditional probabilities for sample 32000 / 648894
# [t-SNE] Computed conditional probabilities for sample 33000 / 648894
# [t-SNE] Computed conditional probabilities for sample 34000 / 648894
# [t-SNE] Computed conditional probabilities for sample 35000 / 648894
# [t-SNE] Computed conditional probabilities for sample 36000 / 648894
# [t-SNE] Computed conditional probabilities for sample 37000 / 648894
# [t-SNE] Computed conditional probabilities for sample 38000 / 648894
# [t-SNE] Computed conditional probabilities for sample 39000 / 648894
# [t-SNE] Computed conditional probabilities for sample 40000 / 648894
# [t-SNE] Computed conditional probabilities for sample 41000 / 648894
# [t-SNE] Computed conditional probabilities for sample 42000 / 648894
# [t-SNE] Computed conditional probabilities for sample 43000 / 648894
# [t-SNE] Computed conditional probabilities for sample 44000 / 648894
# [t-SNE] Computed conditional probabilities for sample 45000 / 648894
# [t-SNE] Computed conditional probabilities for sample 46000 / 648894
# [t-SNE] Computed conditional probabilities for sample 47000 / 648894
# [t-SNE] Computed conditional probabilities for sample 48000 / 648894
# [t-SNE] Computed conditional probabilities for sample 49000 / 648894
# [t-SNE] Computed conditional probabilities for sample 50000 / 648894
# [t-SNE] Computed conditional probabilities for sample 51000 / 648894
# [t-SNE] Computed conditional probabilities for sample 52000 / 648894
# [t-SNE] Computed conditional probabilities for sample 53000 / 648894
# [t-SNE] Computed conditional probabilities for sample 54000 / 648894
# [t-SNE] Computed conditional probabilities for sample 55000 / 648894
# [t-SNE] Computed conditional probabilities for sample 56000 / 648894
# [t-SNE] Computed conditional probabilities for sample 57000 / 648894
# [t-SNE] Computed conditional probabilities for sample 58000 / 648894
# [t-SNE] Computed conditional probabilities for sample 59000 / 648894
# [t-SNE] Computed conditional probabilities for sample 60000 / 648894
# [t-SNE] Computed conditional probabilities for sample 61000 / 648894
# [t-SNE] Computed conditional probabilities for sample 62000 / 648894
# [t-SNE] Computed conditional probabilities for sample 63000 / 648894
# [t-SNE] Computed conditional probabilities for sample 64000 / 648894
# [t-SNE] Computed conditional probabilities for sample 65000 / 648894
# [t-SNE] Computed conditional probabilities for sample 66000 / 648894
# [t-SNE] Computed conditional probabilities for sample 67000 / 648894
# [t-SNE] Computed conditional probabilities for sample 68000 / 648894
# [t-SNE] Computed conditional probabilities for sample 69000 / 648894
# [t-SNE] Computed conditional probabilities for sample 70000 / 648894
# [t-SNE] Computed conditional probabilities for sample 71000 / 648894
# [t-SNE] Computed conditional probabilities for sample 72000 / 648894
# [t-SNE] Computed conditional probabilities for sample 73000 / 648894
# [t-SNE] Computed conditional probabilities for sample 74000 / 648894
# [t-SNE] Computed conditional probabilities for sample 75000 / 648894
# [t-SNE] Computed conditional probabilities for sample 76000 / 648894
# [t-SNE] Computed conditional probabilities for sample 77000 / 648894
# [t-SNE] Computed conditional probabilities for sample 78000 / 648894
# [t-SNE] Computed conditional probabilities for sample 79000 / 648894
# [t-SNE] Computed conditional probabilities for sample 80000 / 648894
# [t-SNE] Computed conditional probabilities for sample 81000 / 648894
# [t-SNE] Computed conditional probabilities for sample 82000 / 648894
# [t-SNE] Computed conditional probabilities for sample 83000 / 648894
# [t-SNE] Computed conditional probabilities for sample 84000 / 648894
# [t-SNE] Computed conditional probabilities for sample 85000 / 648894
# [t-SNE] Computed conditional probabilities for sample 86000 / 648894
# [t-SNE] Computed conditional probabilities for sample 87000 / 648894
# [t-SNE] Computed conditional probabilities for sample 88000 / 648894
# [t-SNE] Computed conditional probabilities for sample 89000 / 648894
# [t-SNE] Computed conditional probabilities for sample 90000 / 648894
# [t-SNE] Computed conditional probabilities for sample 91000 / 648894
# [t-SNE] Computed conditional probabilities for sample 92000 / 648894
# [t-SNE] Computed conditional probabilities for sample 93000 / 648894
# [t-SNE] Computed conditional probabilities for sample 94000 / 648894
# [t-SNE] Computed conditional probabilities for sample 95000 / 648894
# [t-SNE] Computed conditional probabilities for sample 96000 / 648894
# [t-SNE] Computed conditional probabilities for sample 97000 / 648894
# [t-SNE] Computed conditional probabilities for sample 98000 / 648894
# [t-SNE] Computed conditional probabilities for sample 99000 / 648894
# [t-SNE] Computed conditional probabilities for sample 100000 / 648894
# [t-SNE] Computed conditional probabilities for sample 101000 / 648894
# [t-SNE] Computed conditional probabilities for sample 102000 / 648894
# [t-SNE] Computed conditional probabilities for sample 103000 / 648894
# [t-SNE] Computed conditional probabilities for sample 104000 / 648894
# [t-SNE] Computed conditional probabilities for sample 105000 / 648894
# [t-SNE] Computed conditional probabilities for sample 106000 / 648894
# [t-SNE] Computed conditional probabilities for sample 107000 / 648894
# [t-SNE] Computed conditional probabilities for sample 108000 / 648894
# [t-SNE] Computed conditional probabilities for sample 109000 / 648894
# [t-SNE] Computed conditional probabilities for sample 110000 / 648894
# [t-SNE] Computed conditional probabilities for sample 111000 / 648894
# [t-SNE] Computed conditional probabilities for sample 112000 / 648894
# [t-SNE] Computed conditional probabilities for sample 113000 / 648894
# [t-SNE] Computed conditional probabilities for sample 114000 / 648894
# [t-SNE] Computed conditional probabilities for sample 115000 / 648894
# [t-SNE] Computed conditional probabilities for sample 116000 / 648894
# [t-SNE] Computed conditional probabilities for sample 117000 / 648894
# [t-SNE] Computed conditional probabilities for sample 118000 / 648894
# [t-SNE] Computed conditional probabilities for sample 119000 / 648894
# [t-SNE] Computed conditional probabilities for sample 120000 / 648894
# [t-SNE] Computed conditional probabilities for sample 121000 / 648894
# [t-SNE] Computed conditional probabilities for sample 122000 / 648894
# [t-SNE] Computed conditional probabilities for sample 123000 / 648894
# [t-SNE] Computed conditional probabilities for sample 124000 / 648894
# [t-SNE] Computed conditional probabilities for sample 125000 / 648894
# [t-SNE] Computed conditional probabilities for sample 126000 / 648894
# [t-SNE] Computed conditional probabilities for sample 127000 / 648894
# [t-SNE] Computed conditional probabilities for sample 128000 / 648894
# [t-SNE] Computed conditional probabilities for sample 129000 / 648894
# [t-SNE] Computed conditional probabilities for sample 130000 / 648894
# [t-SNE] Computed conditional probabilities for sample 131000 / 648894
# [t-SNE] Computed conditional probabilities for sample 132000 / 648894
# [t-SNE] Computed conditional probabilities for sample 133000 / 648894
# [t-SNE] Computed conditional probabilities for sample 134000 / 648894
# [t-SNE] Computed conditional probabilities for sample 135000 / 648894
# [t-SNE] Computed conditional probabilities for sample 136000 / 648894
# [t-SNE] Computed conditional probabilities for sample 137000 / 648894
# [t-SNE] Computed conditional probabilities for sample 138000 / 648894
# [t-SNE] Computed conditional probabilities for sample 139000 / 648894
# [t-SNE] Computed conditional probabilities for sample 140000 / 648894
# [t-SNE] Computed conditional probabilities for sample 141000 / 648894
# [t-SNE] Computed conditional probabilities for sample 142000 / 648894
# [t-SNE] Computed conditional probabilities for sample 143000 / 648894
# [t-SNE] Computed conditional probabilities for sample 144000 / 648894
# [t-SNE] Computed conditional probabilities for sample 145000 / 648894
# [t-SNE] Computed conditional probabilities for sample 146000 / 648894
# [t-SNE] Computed conditional probabilities for sample 147000 / 648894
# [t-SNE] Computed conditional probabilities for sample 148000 / 648894
# [t-SNE] Computed conditional probabilities for sample 149000 / 648894
# [t-SNE] Computed conditional probabilities for sample 150000 / 648894
# [t-SNE] Computed conditional probabilities for sample 151000 / 648894
# [t-SNE] Computed conditional probabilities for sample 152000 / 648894
# [t-SNE] Computed conditional probabilities for sample 153000 / 648894
# [t-SNE] Computed conditional probabilities for sample 154000 / 648894
# [t-SNE] Computed conditional probabilities for sample 155000 / 648894
# [t-SNE] Computed conditional probabilities for sample 156000 / 648894
# [t-SNE] Computed conditional probabilities for sample 157000 / 648894
# [t-SNE] Computed conditional probabilities for sample 158000 / 648894
# [t-SNE] Computed conditional probabilities for sample 159000 / 648894
# [t-SNE] Computed conditional probabilities for sample 160000 / 648894
# [t-SNE] Computed conditional probabilities for sample 161000 / 648894
# [t-SNE] Computed conditional probabilities for sample 162000 / 648894
# [t-SNE] Computed conditional probabilities for sample 163000 / 648894
# [t-SNE] Computed conditional probabilities for sample 164000 / 648894
# [t-SNE] Computed conditional probabilities for sample 165000 / 648894
# [t-SNE] Computed conditional probabilities for sample 166000 / 648894
# [t-SNE] Computed conditional probabilities for sample 167000 / 648894
# [t-SNE] Computed conditional probabilities for sample 168000 / 648894
# [t-SNE] Computed conditional probabilities for sample 169000 / 648894
# [t-SNE] Computed conditional probabilities for sample 170000 / 648894
# [t-SNE] Computed conditional probabilities for sample 171000 / 648894
# [t-SNE] Computed conditional probabilities for sample 172000 / 648894
# [t-SNE] Computed conditional probabilities for sample 173000 / 648894
# [t-SNE] Computed conditional probabilities for sample 174000 / 648894
# [t-SNE] Computed conditional probabilities for sample 175000 / 648894
# [t-SNE] Computed conditional probabilities for sample 176000 / 648894
# [t-SNE] Computed conditional probabilities for sample 177000 / 648894
# [t-SNE] Computed conditional probabilities for sample 178000 / 648894
# [t-SNE] Computed conditional probabilities for sample 179000 / 648894
# [t-SNE] Computed conditional probabilities for sample 180000 / 648894
# [t-SNE] Computed conditional probabilities for sample 181000 / 648894
# [t-SNE] Computed conditional probabilities for sample 182000 / 648894
# [t-SNE] Computed conditional probabilities for sample 183000 / 648894
# [t-SNE] Computed conditional probabilities for sample 184000 / 648894
# [t-SNE] Computed conditional probabilities for sample 185000 / 648894
# [t-SNE] Computed conditional probabilities for sample 186000 / 648894
# [t-SNE] Computed conditional probabilities for sample 187000 / 648894
# [t-SNE] Computed conditional probabilities for sample 188000 / 648894
# [t-SNE] Computed conditional probabilities for sample 189000 / 648894
# [t-SNE] Computed conditional probabilities for sample 190000 / 648894
# [t-SNE] Computed conditional probabilities for sample 191000 / 648894
# [t-SNE] Computed conditional probabilities for sample 192000 / 648894
# [t-SNE] Computed conditional probabilities for sample 193000 / 648894
# [t-SNE] Computed conditional probabilities for sample 194000 / 648894
# [t-SNE] Computed conditional probabilities for sample 195000 / 648894
# [t-SNE] Computed conditional probabilities for sample 196000 / 648894
# [t-SNE] Computed conditional probabilities for sample 197000 / 648894
# [t-SNE] Computed conditional probabilities for sample 198000 / 648894
# [t-SNE] Computed conditional probabilities for sample 199000 / 648894
# [t-SNE] Computed conditional probabilities for sample 200000 / 648894
# [t-SNE] Computed conditional probabilities for sample 201000 / 648894
# [t-SNE] Computed conditional probabilities for sample 202000 / 648894
# [t-SNE] Computed conditional probabilities for sample 203000 / 648894
# [t-SNE] Computed conditional probabilities for sample 204000 / 648894
# [t-SNE] Computed conditional probabilities for sample 205000 / 648894
# [t-SNE] Computed conditional probabilities for sample 206000 / 648894
# [t-SNE] Computed conditional probabilities for sample 207000 / 648894
# [t-SNE] Computed conditional probabilities for sample 208000 / 648894
# [t-SNE] Computed conditional probabilities for sample 209000 / 648894
# [t-SNE] Computed conditional probabilities for sample 210000 / 648894
# [t-SNE] Computed conditional probabilities for sample 211000 / 648894
# [t-SNE] Computed conditional probabilities for sample 212000 / 648894
# [t-SNE] Computed conditional probabilities for sample 213000 / 648894
# [t-SNE] Computed conditional probabilities for sample 214000 / 648894
# [t-SNE] Computed conditional probabilities for sample 215000 / 648894
# [t-SNE] Computed conditional probabilities for sample 216000 / 648894
# [t-SNE] Computed conditional probabilities for sample 217000 / 648894
# [t-SNE] Computed conditional probabilities for sample 218000 / 648894
# [t-SNE] Computed conditional probabilities for sample 219000 / 648894
# [t-SNE] Computed conditional probabilities for sample 220000 / 648894
# [t-SNE] Computed conditional probabilities for sample 221000 / 648894
# [t-SNE] Computed conditional probabilities for sample 222000 / 648894
# [t-SNE] Computed conditional probabilities for sample 223000 / 648894
# [t-SNE] Computed conditional probabilities for sample 224000 / 648894
# [t-SNE] Computed conditional probabilities for sample 225000 / 648894
# [t-SNE] Computed conditional probabilities for sample 226000 / 648894
# [t-SNE] Computed conditional probabilities for sample 227000 / 648894
# [t-SNE] Computed conditional probabilities for sample 228000 / 648894
# [t-SNE] Computed conditional probabilities for sample 229000 / 648894
# [t-SNE] Computed conditional probabilities for sample 230000 / 648894
# [t-SNE] Computed conditional probabilities for sample 231000 / 648894
# [t-SNE] Computed conditional probabilities for sample 232000 / 648894
# [t-SNE] Computed conditional probabilities for sample 233000 / 648894
# [t-SNE] Computed conditional probabilities for sample 234000 / 648894
# [t-SNE] Computed conditional probabilities for sample 235000 / 648894
# [t-SNE] Computed conditional probabilities for sample 236000 / 648894
# [t-SNE] Computed conditional probabilities for sample 237000 / 648894
# [t-SNE] Computed conditional probabilities for sample 238000 / 648894
# [t-SNE] Computed conditional probabilities for sample 239000 / 648894
# [t-SNE] Computed conditional probabilities for sample 240000 / 648894
# [t-SNE] Computed conditional probabilities for sample 241000 / 648894
# [t-SNE] Computed conditional probabilities for sample 242000 / 648894
# [t-SNE] Computed conditional probabilities for sample 243000 / 648894
# [t-SNE] Computed conditional probabilities for sample 244000 / 648894
# [t-SNE] Computed conditional probabilities for sample 245000 / 648894
# [t-SNE] Computed conditional probabilities for sample 246000 / 648894
# [t-SNE] Computed conditional probabilities for sample 247000 / 648894
# [t-SNE] Computed conditional probabilities for sample 248000 / 648894
# [t-SNE] Computed conditional probabilities for sample 249000 / 648894
# [t-SNE] Computed conditional probabilities for sample 250000 / 648894
# [t-SNE] Computed conditional probabilities for sample 251000 / 648894
# [t-SNE] Computed conditional probabilities for sample 252000 / 648894
# [t-SNE] Computed conditional probabilities for sample 253000 / 648894
# [t-SNE] Computed conditional probabilities for sample 254000 / 648894
# [t-SNE] Computed conditional probabilities for sample 255000 / 648894
# [t-SNE] Computed conditional probabilities for sample 256000 / 648894
# [t-SNE] Computed conditional probabilities for sample 257000 / 648894
# [t-SNE] Computed conditional probabilities for sample 258000 / 648894
# [t-SNE] Computed conditional probabilities for sample 259000 / 648894
# [t-SNE] Computed conditional probabilities for sample 260000 / 648894
# [t-SNE] Computed conditional probabilities for sample 261000 / 648894
# [t-SNE] Computed conditional probabilities for sample 262000 / 648894
# [t-SNE] Computed conditional probabilities for sample 263000 / 648894
# [t-SNE] Computed conditional probabilities for sample 264000 / 648894
# [t-SNE] Computed conditional probabilities for sample 265000 / 648894
# [t-SNE] Computed conditional probabilities for sample 266000 / 648894
# [t-SNE] Computed conditional probabilities for sample 267000 / 648894
# [t-SNE] Computed conditional probabilities for sample 268000 / 648894
# [t-SNE] Computed conditional probabilities for sample 269000 / 648894
# [t-SNE] Computed conditional probabilities for sample 270000 / 648894
# [t-SNE] Computed conditional probabilities for sample 271000 / 648894
# [t-SNE] Computed conditional probabilities for sample 272000 / 648894
# [t-SNE] Computed conditional probabilities for sample 273000 / 648894
# [t-SNE] Computed conditional probabilities for sample 274000 / 648894
# [t-SNE] Computed conditional probabilities for sample 275000 / 648894
# [t-SNE] Computed conditional probabilities for sample 276000 / 648894
# [t-SNE] Computed conditional probabilities for sample 277000 / 648894
# [t-SNE] Computed conditional probabilities for sample 278000 / 648894
# [t-SNE] Computed conditional probabilities for sample 279000 / 648894
# [t-SNE] Computed conditional probabilities for sample 280000 / 648894
# [t-SNE] Computed conditional probabilities for sample 281000 / 648894
# [t-SNE] Computed conditional probabilities for sample 282000 / 648894
# [t-SNE] Computed conditional probabilities for sample 283000 / 648894
# [t-SNE] Computed conditional probabilities for sample 284000 / 648894
# [t-SNE] Computed conditional probabilities for sample 285000 / 648894
# [t-SNE] Computed conditional probabilities for sample 286000 / 648894
# [t-SNE] Computed conditional probabilities for sample 287000 / 648894
# [t-SNE] Computed conditional probabilities for sample 288000 / 648894
# [t-SNE] Computed conditional probabilities for sample 289000 / 648894
# [t-SNE] Computed conditional probabilities for sample 290000 / 648894
# [t-SNE] Computed conditional probabilities for sample 291000 / 648894
# [t-SNE] Computed conditional probabilities for sample 292000 / 648894
# [t-SNE] Computed conditional probabilities for sample 293000 / 648894
# [t-SNE] Computed conditional probabilities for sample 294000 / 648894
# [t-SNE] Computed conditional probabilities for sample 295000 / 648894
# [t-SNE] Computed conditional probabilities for sample 296000 / 648894
# [t-SNE] Computed conditional probabilities for sample 297000 / 648894
# [t-SNE] Computed conditional probabilities for sample 298000 / 648894
# [t-SNE] Computed conditional probabilities for sample 299000 / 648894
# [t-SNE] Computed conditional probabilities for sample 300000 / 648894
# [t-SNE] Computed conditional probabilities for sample 301000 / 648894
# [t-SNE] Computed conditional probabilities for sample 302000 / 648894
# [t-SNE] Computed conditional probabilities for sample 303000 / 648894
# [t-SNE] Computed conditional probabilities for sample 304000 / 648894
# [t-SNE] Computed conditional probabilities for sample 305000 / 648894
# [t-SNE] Computed conditional probabilities for sample 306000 / 648894
# [t-SNE] Computed conditional probabilities for sample 307000 / 648894
# [t-SNE] Computed conditional probabilities for sample 308000 / 648894
# [t-SNE] Computed conditional probabilities for sample 309000 / 648894
# [t-SNE] Computed conditional probabilities for sample 310000 / 648894
# [t-SNE] Computed conditional probabilities for sample 311000 / 648894
# [t-SNE] Computed conditional probabilities for sample 312000 / 648894
# [t-SNE] Computed conditional probabilities for sample 313000 / 648894
# [t-SNE] Computed conditional probabilities for sample 314000 / 648894
# [t-SNE] Computed conditional probabilities for sample 315000 / 648894
# [t-SNE] Computed conditional probabilities for sample 316000 / 648894
# [t-SNE] Computed conditional probabilities for sample 317000 / 648894
# [t-SNE] Computed conditional probabilities for sample 318000 / 648894
# [t-SNE] Computed conditional probabilities for sample 319000 / 648894
# [t-SNE] Computed conditional probabilities for sample 320000 / 648894
# [t-SNE] Computed conditional probabilities for sample 321000 / 648894
# [t-SNE] Computed conditional probabilities for sample 322000 / 648894
# [t-SNE] Computed conditional probabilities for sample 323000 / 648894
# [t-SNE] Computed conditional probabilities for sample 324000 / 648894
# [t-SNE] Computed conditional probabilities for sample 325000 / 648894
# [t-SNE] Computed conditional probabilities for sample 326000 / 648894
# [t-SNE] Computed conditional probabilities for sample 327000 / 648894
# [t-SNE] Computed conditional probabilities for sample 328000 / 648894
# [t-SNE] Computed conditional probabilities for sample 329000 / 648894
# [t-SNE] Computed conditional probabilities for sample 330000 / 648894
# [t-SNE] Computed conditional probabilities for sample 331000 / 648894
# [t-SNE] Computed conditional probabilities for sample 332000 / 648894
# [t-SNE] Computed conditional probabilities for sample 333000 / 648894
# [t-SNE] Computed conditional probabilities for sample 334000 / 648894
# [t-SNE] Computed conditional probabilities for sample 335000 / 648894
# [t-SNE] Computed conditional probabilities for sample 336000 / 648894
# [t-SNE] Computed conditional probabilities for sample 337000 / 648894
# [t-SNE] Computed conditional probabilities for sample 338000 / 648894
# [t-SNE] Computed conditional probabilities for sample 339000 / 648894
# [t-SNE] Computed conditional probabilities for sample 340000 / 648894
# [t-SNE] Computed conditional probabilities for sample 341000 / 648894
# [t-SNE] Computed conditional probabilities for sample 342000 / 648894
# [t-SNE] Computed conditional probabilities for sample 343000 / 648894
# [t-SNE] Computed conditional probabilities for sample 344000 / 648894
# [t-SNE] Computed conditional probabilities for sample 345000 / 648894
# [t-SNE] Computed conditional probabilities for sample 346000 / 648894
# [t-SNE] Computed conditional probabilities for sample 347000 / 648894
# [t-SNE] Computed conditional probabilities for sample 348000 / 648894
# [t-SNE] Computed conditional probabilities for sample 349000 / 648894
# [t-SNE] Computed conditional probabilities for sample 350000 / 648894
# [t-SNE] Computed conditional probabilities for sample 351000 / 648894
# [t-SNE] Computed conditional probabilities for sample 352000 / 648894
# [t-SNE] Computed conditional probabilities for sample 353000 / 648894
# [t-SNE] Computed conditional probabilities for sample 354000 / 648894
# [t-SNE] Computed conditional probabilities for sample 355000 / 648894
# [t-SNE] Computed conditional probabilities for sample 356000 / 648894
# [t-SNE] Computed conditional probabilities for sample 357000 / 648894
# [t-SNE] Computed conditional probabilities for sample 358000 / 648894
# [t-SNE] Computed conditional probabilities for sample 359000 / 648894
# [t-SNE] Computed conditional probabilities for sample 360000 / 648894
# [t-SNE] Computed conditional probabilities for sample 361000 / 648894
# [t-SNE] Computed conditional probabilities for sample 362000 / 648894
# [t-SNE] Computed conditional probabilities for sample 363000 / 648894
# [t-SNE] Computed conditional probabilities for sample 364000 / 648894
# [t-SNE] Computed conditional probabilities for sample 365000 / 648894
# [t-SNE] Computed conditional probabilities for sample 366000 / 648894
# [t-SNE] Computed conditional probabilities for sample 367000 / 648894
# [t-SNE] Computed conditional probabilities for sample 368000 / 648894
# [t-SNE] Computed conditional probabilities for sample 369000 / 648894
# [t-SNE] Computed conditional probabilities for sample 370000 / 648894
# [t-SNE] Computed conditional probabilities for sample 371000 / 648894
# [t-SNE] Computed conditional probabilities for sample 372000 / 648894
# [t-SNE] Computed conditional probabilities for sample 373000 / 648894
# [t-SNE] Computed conditional probabilities for sample 374000 / 648894
# [t-SNE] Computed conditional probabilities for sample 375000 / 648894
# [t-SNE] Computed conditional probabilities for sample 376000 / 648894
# [t-SNE] Computed conditional probabilities for sample 377000 / 648894
# [t-SNE] Computed conditional probabilities for sample 378000 / 648894
# [t-SNE] Computed conditional probabilities for sample 379000 / 648894
# [t-SNE] Computed conditional probabilities for sample 380000 / 648894
# [t-SNE] Computed conditional probabilities for sample 381000 / 648894
# [t-SNE] Computed conditional probabilities for sample 382000 / 648894
# [t-SNE] Computed conditional probabilities for sample 383000 / 648894
# [t-SNE] Computed conditional probabilities for sample 384000 / 648894
# [t-SNE] Computed conditional probabilities for sample 385000 / 648894
# [t-SNE] Computed conditional probabilities for sample 386000 / 648894
# [t-SNE] Computed conditional probabilities for sample 387000 / 648894
# [t-SNE] Computed conditional probabilities for sample 388000 / 648894
# [t-SNE] Computed conditional probabilities for sample 389000 / 648894
# [t-SNE] Computed conditional probabilities for sample 390000 / 648894
# [t-SNE] Computed conditional probabilities for sample 391000 / 648894
# [t-SNE] Computed conditional probabilities for sample 392000 / 648894
# [t-SNE] Computed conditional probabilities for sample 393000 / 648894
# [t-SNE] Computed conditional probabilities for sample 394000 / 648894
# [t-SNE] Computed conditional probabilities for sample 395000 / 648894
# [t-SNE] Computed conditional probabilities for sample 396000 / 648894
# [t-SNE] Computed conditional probabilities for sample 397000 / 648894
# [t-SNE] Computed conditional probabilities for sample 398000 / 648894
# [t-SNE] Computed conditional probabilities for sample 399000 / 648894
# [t-SNE] Computed conditional probabilities for sample 400000 / 648894
# [t-SNE] Computed conditional probabilities for sample 401000 / 648894
# [t-SNE] Computed conditional probabilities for sample 402000 / 648894
# [t-SNE] Computed conditional probabilities for sample 403000 / 648894
# [t-SNE] Computed conditional probabilities for sample 404000 / 648894
# [t-SNE] Computed conditional probabilities for sample 405000 / 648894
# [t-SNE] Computed conditional probabilities for sample 406000 / 648894
# [t-SNE] Computed conditional probabilities for sample 407000 / 648894
# [t-SNE] Computed conditional probabilities for sample 408000 / 648894
# [t-SNE] Computed conditional probabilities for sample 409000 / 648894
# [t-SNE] Computed conditional probabilities for sample 410000 / 648894
# [t-SNE] Computed conditional probabilities for sample 411000 / 648894
# [t-SNE] Computed conditional probabilities for sample 412000 / 648894
# [t-SNE] Computed conditional probabilities for sample 413000 / 648894
# [t-SNE] Computed conditional probabilities for sample 414000 / 648894
# [t-SNE] Computed conditional probabilities for sample 415000 / 648894
# [t-SNE] Computed conditional probabilities for sample 416000 / 648894
# [t-SNE] Computed conditional probabilities for sample 417000 / 648894
# [t-SNE] Computed conditional probabilities for sample 418000 / 648894
# [t-SNE] Computed conditional probabilities for sample 419000 / 648894
# [t-SNE] Computed conditional probabilities for sample 420000 / 648894
# [t-SNE] Computed conditional probabilities for sample 421000 / 648894
# [t-SNE] Computed conditional probabilities for sample 422000 / 648894
# [t-SNE] Computed conditional probabilities for sample 423000 / 648894
# [t-SNE] Computed conditional probabilities for sample 424000 / 648894
# [t-SNE] Computed conditional probabilities for sample 425000 / 648894
# [t-SNE] Computed conditional probabilities for sample 426000 / 648894
# [t-SNE] Computed conditional probabilities for sample 427000 / 648894
# [t-SNE] Computed conditional probabilities for sample 428000 / 648894
# [t-SNE] Computed conditional probabilities for sample 429000 / 648894
# [t-SNE] Computed conditional probabilities for sample 430000 / 648894
# [t-SNE] Computed conditional probabilities for sample 431000 / 648894
# [t-SNE] Computed conditional probabilities for sample 432000 / 648894
# [t-SNE] Computed conditional probabilities for sample 433000 / 648894
# [t-SNE] Computed conditional probabilities for sample 434000 / 648894
# [t-SNE] Computed conditional probabilities for sample 435000 / 648894
# [t-SNE] Computed conditional probabilities for sample 436000 / 648894
# [t-SNE] Computed conditional probabilities for sample 437000 / 648894
# [t-SNE] Computed conditional probabilities for sample 438000 / 648894
# [t-SNE] Computed conditional probabilities for sample 439000 / 648894
# [t-SNE] Computed conditional probabilities for sample 440000 / 648894
# [t-SNE] Computed conditional probabilities for sample 441000 / 648894
# [t-SNE] Computed conditional probabilities for sample 442000 / 648894
# [t-SNE] Computed conditional probabilities for sample 443000 / 648894
# [t-SNE] Computed conditional probabilities for sample 444000 / 648894
# [t-SNE] Computed conditional probabilities for sample 445000 / 648894
# [t-SNE] Computed conditional probabilities for sample 446000 / 648894
# [t-SNE] Computed conditional probabilities for sample 447000 / 648894
# [t-SNE] Computed conditional probabilities for sample 448000 / 648894
# [t-SNE] Computed conditional probabilities for sample 449000 / 648894
# [t-SNE] Computed conditional probabilities for sample 450000 / 648894
# [t-SNE] Computed conditional probabilities for sample 451000 / 648894
# [t-SNE] Computed conditional probabilities for sample 452000 / 648894
# [t-SNE] Computed conditional probabilities for sample 453000 / 648894
# [t-SNE] Computed conditional probabilities for sample 454000 / 648894
# [t-SNE] Computed conditional probabilities for sample 455000 / 648894
# [t-SNE] Computed conditional probabilities for sample 456000 / 648894
# [t-SNE] Computed conditional probabilities for sample 457000 / 648894
# [t-SNE] Computed conditional probabilities for sample 458000 / 648894
# [t-SNE] Computed conditional probabilities for sample 459000 / 648894
# [t-SNE] Computed conditional probabilities for sample 460000 / 648894
# [t-SNE] Computed conditional probabilities for sample 461000 / 648894
# [t-SNE] Computed conditional probabilities for sample 462000 / 648894
# [t-SNE] Computed conditional probabilities for sample 463000 / 648894
# [t-SNE] Computed conditional probabilities for sample 464000 / 648894
# [t-SNE] Computed conditional probabilities for sample 465000 / 648894
# [t-SNE] Computed conditional probabilities for sample 466000 / 648894
# [t-SNE] Computed conditional probabilities for sample 467000 / 648894
# [t-SNE] Computed conditional probabilities for sample 468000 / 648894
# [t-SNE] Computed conditional probabilities for sample 469000 / 648894
# [t-SNE] Computed conditional probabilities for sample 470000 / 648894
# [t-SNE] Computed conditional probabilities for sample 471000 / 648894
# [t-SNE] Computed conditional probabilities for sample 472000 / 648894
# [t-SNE] Computed conditional probabilities for sample 473000 / 648894
# [t-SNE] Computed conditional probabilities for sample 474000 / 648894
# [t-SNE] Computed conditional probabilities for sample 475000 / 648894
# [t-SNE] Computed conditional probabilities for sample 476000 / 648894
# [t-SNE] Computed conditional probabilities for sample 477000 / 648894
# [t-SNE] Computed conditional probabilities for sample 478000 / 648894
# [t-SNE] Computed conditional probabilities for sample 479000 / 648894
# [t-SNE] Computed conditional probabilities for sample 480000 / 648894
# [t-SNE] Computed conditional probabilities for sample 481000 / 648894
# [t-SNE] Computed conditional probabilities for sample 482000 / 648894
# [t-SNE] Computed conditional probabilities for sample 483000 / 648894
# [t-SNE] Computed conditional probabilities for sample 484000 / 648894
# [t-SNE] Computed conditional probabilities for sample 485000 / 648894
# [t-SNE] Computed conditional probabilities for sample 486000 / 648894
# [t-SNE] Computed conditional probabilities for sample 487000 / 648894
# [t-SNE] Computed conditional probabilities for sample 488000 / 648894
# [t-SNE] Computed conditional probabilities for sample 489000 / 648894
# [t-SNE] Computed conditional probabilities for sample 490000 / 648894
# [t-SNE] Computed conditional probabilities for sample 491000 / 648894
# [t-SNE] Computed conditional probabilities for sample 492000 / 648894
# [t-SNE] Computed conditional probabilities for sample 493000 / 648894
# [t-SNE] Computed conditional probabilities for sample 494000 / 648894
# [t-SNE] Computed conditional probabilities for sample 495000 / 648894
# [t-SNE] Computed conditional probabilities for sample 496000 / 648894
# [t-SNE] Computed conditional probabilities for sample 497000 / 648894
# [t-SNE] Computed conditional probabilities for sample 498000 / 648894
# [t-SNE] Computed conditional probabilities for sample 499000 / 648894
# [t-SNE] Computed conditional probabilities for sample 500000 / 648894
# [t-SNE] Computed conditional probabilities for sample 501000 / 648894
# [t-SNE] Computed conditional probabilities for sample 502000 / 648894
# [t-SNE] Computed conditional probabilities for sample 503000 / 648894
# [t-SNE] Computed conditional probabilities for sample 504000 / 648894
# [t-SNE] Computed conditional probabilities for sample 505000 / 648894
# [t-SNE] Computed conditional probabilities for sample 506000 / 648894
# [t-SNE] Computed conditional probabilities for sample 507000 / 648894
# [t-SNE] Computed conditional probabilities for sample 508000 / 648894
# [t-SNE] Computed conditional probabilities for sample 509000 / 648894
# [t-SNE] Computed conditional probabilities for sample 510000 / 648894
# [t-SNE] Computed conditional probabilities for sample 511000 / 648894
# [t-SNE] Computed conditional probabilities for sample 512000 / 648894
# [t-SNE] Computed conditional probabilities for sample 513000 / 648894
# [t-SNE] Computed conditional probabilities for sample 514000 / 648894
# [t-SNE] Computed conditional probabilities for sample 515000 / 648894
# [t-SNE] Computed conditional probabilities for sample 516000 / 648894
# [t-SNE] Computed conditional probabilities for sample 517000 / 648894
# [t-SNE] Computed conditional probabilities for sample 518000 / 648894
# [t-SNE] Computed conditional probabilities for sample 519000 / 648894
# [t-SNE] Computed conditional probabilities for sample 520000 / 648894
# [t-SNE] Computed conditional probabilities for sample 521000 / 648894
# [t-SNE] Computed conditional probabilities for sample 522000 / 648894
# [t-SNE] Computed conditional probabilities for sample 523000 / 648894
# [t-SNE] Computed conditional probabilities for sample 524000 / 648894
# [t-SNE] Computed conditional probabilities for sample 525000 / 648894
# [t-SNE] Computed conditional probabilities for sample 526000 / 648894
# [t-SNE] Computed conditional probabilities for sample 527000 / 648894
# [t-SNE] Computed conditional probabilities for sample 528000 / 648894
# [t-SNE] Computed conditional probabilities for sample 529000 / 648894
# [t-SNE] Computed conditional probabilities for sample 530000 / 648894
# [t-SNE] Computed conditional probabilities for sample 531000 / 648894
# [t-SNE] Computed conditional probabilities for sample 532000 / 648894
# [t-SNE] Computed conditional probabilities for sample 533000 / 648894
# [t-SNE] Computed conditional probabilities for sample 534000 / 648894
# [t-SNE] Computed conditional probabilities for sample 535000 / 648894
# [t-SNE] Computed conditional probabilities for sample 536000 / 648894
# [t-SNE] Computed conditional probabilities for sample 537000 / 648894
# [t-SNE] Computed conditional probabilities for sample 538000 / 648894
# [t-SNE] Computed conditional probabilities for sample 539000 / 648894
# [t-SNE] Computed conditional probabilities for sample 540000 / 648894
# [t-SNE] Computed conditional probabilities for sample 541000 / 648894
# [t-SNE] Computed conditional probabilities for sample 542000 / 648894
# [t-SNE] Computed conditional probabilities for sample 543000 / 648894
# [t-SNE] Computed conditional probabilities for sample 544000 / 648894
# [t-SNE] Computed conditional probabilities for sample 545000 / 648894
# [t-SNE] Computed conditional probabilities for sample 546000 / 648894
# [t-SNE] Computed conditional probabilities for sample 547000 / 648894
# [t-SNE] Computed conditional probabilities for sample 548000 / 648894
# [t-SNE] Computed conditional probabilities for sample 549000 / 648894
# [t-SNE] Computed conditional probabilities for sample 550000 / 648894
# [t-SNE] Computed conditional probabilities for sample 551000 / 648894
# [t-SNE] Computed conditional probabilities for sample 552000 / 648894
# [t-SNE] Computed conditional probabilities for sample 553000 / 648894
# [t-SNE] Computed conditional probabilities for sample 554000 / 648894
# [t-SNE] Computed conditional probabilities for sample 555000 / 648894
# [t-SNE] Computed conditional probabilities for sample 556000 / 648894
# [t-SNE] Computed conditional probabilities for sample 557000 / 648894
# [t-SNE] Computed conditional probabilities for sample 558000 / 648894
# [t-SNE] Computed conditional probabilities for sample 559000 / 648894
# [t-SNE] Computed conditional probabilities for sample 560000 / 648894
# [t-SNE] Computed conditional probabilities for sample 561000 / 648894
# [t-SNE] Computed conditional probabilities for sample 562000 / 648894
# [t-SNE] Computed conditional probabilities for sample 563000 / 648894
# [t-SNE] Computed conditional probabilities for sample 564000 / 648894
# [t-SNE] Computed conditional probabilities for sample 565000 / 648894
# [t-SNE] Computed conditional probabilities for sample 566000 / 648894
# [t-SNE] Computed conditional probabilities for sample 567000 / 648894
# [t-SNE] Computed conditional probabilities for sample 568000 / 648894
# [t-SNE] Computed conditional probabilities for sample 569000 / 648894
# [t-SNE] Computed conditional probabilities for sample 570000 / 648894
# [t-SNE] Computed conditional probabilities for sample 571000 / 648894
# [t-SNE] Computed conditional probabilities for sample 572000 / 648894
# [t-SNE] Computed conditional probabilities for sample 573000 / 648894
# [t-SNE] Computed conditional probabilities for sample 574000 / 648894
# [t-SNE] Computed conditional probabilities for sample 575000 / 648894
# [t-SNE] Computed conditional probabilities for sample 576000 / 648894
# [t-SNE] Computed conditional probabilities for sample 577000 / 648894
# [t-SNE] Computed conditional probabilities for sample 578000 / 648894
# [t-SNE] Computed conditional probabilities for sample 579000 / 648894
# [t-SNE] Computed conditional probabilities for sample 580000 / 648894
# [t-SNE] Computed conditional probabilities for sample 581000 / 648894
# [t-SNE] Computed conditional probabilities for sample 582000 / 648894
# [t-SNE] Computed conditional probabilities for sample 583000 / 648894
# [t-SNE] Computed conditional probabilities for sample 584000 / 648894
# [t-SNE] Computed conditional probabilities for sample 585000 / 648894
# [t-SNE] Computed conditional probabilities for sample 586000 / 648894
# [t-SNE] Computed conditional probabilities for sample 587000 / 648894
# [t-SNE] Computed conditional probabilities for sample 588000 / 648894
# [t-SNE] Computed conditional probabilities for sample 589000 / 648894
# [t-SNE] Computed conditional probabilities for sample 590000 / 648894
# [t-SNE] Computed conditional probabilities for sample 591000 / 648894
# [t-SNE] Computed conditional probabilities for sample 592000 / 648894
# [t-SNE] Computed conditional probabilities for sample 593000 / 648894
# [t-SNE] Computed conditional probabilities for sample 594000 / 648894
# [t-SNE] Computed conditional probabilities for sample 595000 / 648894
# [t-SNE] Computed conditional probabilities for sample 596000 / 648894
# [t-SNE] Computed conditional probabilities for sample 597000 / 648894
# [t-SNE] Computed conditional probabilities for sample 598000 / 648894
# [t-SNE] Computed conditional probabilities for sample 599000 / 648894
# [t-SNE] Computed conditional probabilities for sample 600000 / 648894
# [t-SNE] Computed conditional probabilities for sample 601000 / 648894
# [t-SNE] Computed conditional probabilities for sample 602000 / 648894
# [t-SNE] Computed conditional probabilities for sample 603000 / 648894
# [t-SNE] Computed conditional probabilities for sample 604000 / 648894
# [t-SNE] Computed conditional probabilities for sample 605000 / 648894
# [t-SNE] Computed conditional probabilities for sample 606000 / 648894
# [t-SNE] Computed conditional probabilities for sample 607000 / 648894
# [t-SNE] Computed conditional probabilities for sample 608000 / 648894
# [t-SNE] Computed conditional probabilities for sample 609000 / 648894
# [t-SNE] Computed conditional probabilities for sample 610000 / 648894
# [t-SNE] Computed conditional probabilities for sample 611000 / 648894
# [t-SNE] Computed conditional probabilities for sample 612000 / 648894
# [t-SNE] Computed conditional probabilities for sample 613000 / 648894
# [t-SNE] Computed conditional probabilities for sample 614000 / 648894
# [t-SNE] Computed conditional probabilities for sample 615000 / 648894
# [t-SNE] Computed conditional probabilities for sample 616000 / 648894
# [t-SNE] Computed conditional probabilities for sample 617000 / 648894
# [t-SNE] Computed conditional probabilities for sample 618000 / 648894
# [t-SNE] Computed conditional probabilities for sample 619000 / 648894
# [t-SNE] Computed conditional probabilities for sample 620000 / 648894
# [t-SNE] Computed conditional probabilities for sample 621000 / 648894
# [t-SNE] Computed conditional probabilities for sample 622000 / 648894
# [t-SNE] Computed conditional probabilities for sample 623000 / 648894
# [t-SNE] Computed conditional probabilities for sample 624000 / 648894
# [t-SNE] Computed conditional probabilities for sample 625000 / 648894
# [t-SNE] Computed conditional probabilities for sample 626000 / 648894
# [t-SNE] Computed conditional probabilities for sample 627000 / 648894
# [t-SNE] Computed conditional probabilities for sample 628000 / 648894
# [t-SNE] Computed conditional probabilities for sample 629000 / 648894
# [t-SNE] Computed conditional probabilities for sample 630000 / 648894
# [t-SNE] Computed conditional probabilities for sample 631000 / 648894
# [t-SNE] Computed conditional probabilities for sample 632000 / 648894
# [t-SNE] Computed conditional probabilities for sample 633000 / 648894
# [t-SNE] Computed conditional probabilities for sample 634000 / 648894
# [t-SNE] Computed conditional probabilities for sample 635000 / 648894
# [t-SNE] Computed conditional probabilities for sample 636000 / 648894
# [t-SNE] Computed conditional probabilities for sample 637000 / 648894
# [t-SNE] Computed conditional probabilities for sample 638000 / 648894
# [t-SNE] Computed conditional probabilities for sample 639000 / 648894
# [t-SNE] Computed conditional probabilities for sample 640000 / 648894
# [t-SNE] Computed conditional probabilities for sample 641000 / 648894
# [t-SNE] Computed conditional probabilities for sample 642000 / 648894
# [t-SNE] Computed conditional probabilities for sample 643000 / 648894
# [t-SNE] Computed conditional probabilities for sample 644000 / 648894
# [t-SNE] Computed conditional probabilities for sample 645000 / 648894
# [t-SNE] Computed conditional probabilities for sample 646000 / 648894
# [t-SNE] Computed conditional probabilities for sample 647000 / 648894
# [t-SNE] Computed conditional probabilities for sample 648000 / 648894
# [t-SNE] Computed conditional probabilities for sample 648894 / 648894
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 36.708s
# [t-SNE] Iteration 50: error = 129.7681427, gradient norm = 0.0000001 (50 iterations in 4852.570s)
# [t-SNE] Iteration 100: error = 129.7681427, gradient norm = 0.0000001 (50 iterations in 4330.609s)
# [t-SNE] Iteration 150: error = 129.7681427, gradient norm = 0.0000006 (50 iterations in 4178.444s)
# [t-SNE] Iteration 200: error = 129.7681274, gradient norm = 0.0000076 (50 iterations in 5881.737s)
# [t-SNE] Iteration 250: error = 129.7212524, gradient norm = 0.0002047 (50 iterations in 8823.754s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 129.721252
# [t-SNE] Iteration 300: error = 8.6111050, gradient norm = 0.0005180 (50 iterations in 8067.702s)
# [t-SNE] Iteration 350: error = 8.0456915, gradient norm = 0.0010260 (50 iterations in 5501.749s)
# [t-SNE] Iteration 400: error = 7.0362000, gradient norm = 0.0005464 (50 iterations in 3906.288s)
# [t-SNE] KL divergence after 400 iterations: 7.036200
# CPU times: user 12h 42min 9s, sys: 2min 14s, total: 12h 44min 23s
# Wall time: 12h 41min 33s

# %%
# plt.scatter(df2_norm_tsne[:, 0], df2_norm_tsne[:, 1])
# plt.axis('equal')

# %% [markdown]
# ## GMM Modeling

# %% [markdown]
# ### Get Best K using Silhouette Score
# Do not rerun these 3 cells, they take too long

# %%
# function to run GMM with given dataset & automatically choose best k
# prints distribution of posts across clusters
def find_best_k(dataset):
    best_score = -np.inf
    best_k = None
    best_model = None
    best_cluster_assignments = None

    for k in range(4, 11):
        candidate_gmm = GaussianMixture(n_components=k, n_init=1, random_state=0)
        candidate_gmm.fit(dataset)
        cluster_assignments = candidate_gmm.predict(dataset)
        score = silhouette_score(dataset, cluster_assignments)

        print('k =', k, 'has silhouette score', score)

        if score > best_score:
            best_score = score
            best_k = k
            best_model = candidate_gmm
            best_cluster_assignments = cluster_assignments

    print('Best k according to Silhouette Score:', best_k)

    gmm_cluster_assignments = best_model.predict(dataset)
    
    # print breakdown of posts by gmm cluster assignment
    print('Distribution of posts by cluster:')
    y = np.bincount(gmm_cluster_assignments)
    ii = np.nonzero(y)[0]
    cluster_distribution = pd.DataFrame(np.vstack((ii,y[ii])).T, columns = ['Cluster', 'Count of Posts'])
    print(cluster_distribution)
    
    return gmm_cluster_assignments

# %%
# %%time
# find best k with 3 Dimensions for visualization
gmm_3d = find_best_k(df2_norm_pca_3d)
# Out:
# k = 4 has silhouette score 0.24465139139794245
# k = 5 has silhouette score 0.27273995142826357
# k = 6 has silhouette score 0.28081116259706845
# k = 7 has silhouette score 0.22898091311843818
# k = 8 has silhouette score 0.1918232390743749
# k = 9 has silhouette score 0.22160229658876868
# k = 10 has silhouette score 0.21700002482032088
# Best k according to Silhouette Score: 6
# Distribution of posts by cluster:
#    Cluster  Count of Posts
# 0        0          170377
# 1        1          101571
# 2        2           77092
# 3        3          110235
# 4        4           85302
# 5        5          104317
# CPU times: user 14h 37min 41s, sys: 2h 44min 13s, total: 17h 21min 54s
# Wall time: 14h 20s

# %%
# %%time
# find best k with 10 Dimensions for analysis (captures 80% of variance according to PCA)
gmm_nd = find_best_k(df2_norm_pca_nd)
# Out:
# k = 4 has silhouette score 0.1497864295036958
# k = 5 has silhouette score 0.15455347187498056
# k = 6 has silhouette score 0.17180197734082467
# k = 7 has silhouette score 0.15547251585942562
# k = 8 has silhouette score 0.13771353980950227
# k = 9 has silhouette score 0.13586517810203155
# k = 10 has silhouette score 0.15649923504716642
# Best k according to Silhouette Score: 6
# Distribution of posts by cluster:
#    Cluster  Count of Posts
# 0        0          185569
# 1        1          109861
# 2        2           91259
# 3        3           98945
# 4        4           57049
# 5        5          111180
# CPU times: user 12h 57min 44s, sys: 2h 37min 18s, total: 15h 35min 2s
# Wall time: 12h 14min 47s

# %%
# %%time
# find best k with 3 Dimensions for visualization
gmm_3d = find_best_k(df2_norm_tsne_full)

# %% [markdown]
# ## Run GMM PCA

# %%
# %%time
# run GMM with 3 Dimensions and 4 clusters & visualize
gmm_3d = GaussianMixture(n_components=4, n_init=1, random_state=0)
gmm_3d.fit(df2_norm_pca_3d)
gmm_3d_clusters = gmm_3d.predict(df2_norm_pca_3d)
# plot 3D Clusters
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(221, projection='3d')
ax.scatter(df2_norm_pca_3d[:, 0], df2_norm_pca_3d[:, 1], df2_norm_pca_3d[:, 2], c=gmm_3d_clusters, cmap='Spectral')
ax.title.set_text('3D Plot')
# plot 3D Clusters in 2D (1)
ax1 = fig.add_subplot(222)
ax1.scatter(df2_norm_pca_3d[:, 0], df2_norm_pca_3d[:, 1], c=gmm_3d_clusters, cmap='Spectral')
ax1.title.set_text('2D Plot (1)')
# plot 3D Clusters in 2D (2)
ax2 = fig.add_subplot(223)
ax2.scatter(df2_norm_pca_3d[:, 0], df2_norm_pca_3d[:, 2], c=gmm_3d_clusters, cmap='Spectral')
ax2.title.set_text('2D Plot (2)')
# plot 3D Clusters in 2D (3)
ax3 = fig.add_subplot(224)
ax3.scatter(df2_norm_pca_3d[:, 1], df2_norm_pca_3d[:, 2], c=gmm_3d_clusters, cmap='Spectral')
ax3.title.set_text('2D Plot (3)')
plt.show()
# Out:
# CPU times: user 2min 17s, sys: 4.63 s, total: 2min 21s
# Wall time: 2min 12s

# %%
# %%time
# run GMM with 10 Dimensions and 6 clusters & add cluster assignments back to original df
gmm_nd = GaussianMixture(n_components=6, n_init=1, random_state=0)
gmm_nd.fit(df2_norm_pca_nd)
gmm_nd_clusters = gmm_nd.predict(df2_norm_pca_nd)
# add cluster assignments as new column to original dataset
df['Cluster'] = gmm_nd_clusters.tolist()
# Out:
# CPU times: user 21 s, sys: 2.77 s, total: 23.8 s
# Wall time: 12.6 s

# %% [markdown]
# ## Run GMM with T-SNE

# %%
# %%time
# run GMM with 3 Dimensions and 6 clusters for visualization
gmm = GaussianMixture(n_components=6, n_init=1, random_state=0)
gmm.fit(df2_norm_tsne_full)
cluster_assignments_3d = gmm.predict(df2_norm_tsne_full)
# Out:
# CPU times: user 8.07 s, sys: 5.47 s, total: 13.5 s
# Wall time: 6.19 s

# %%
score = silhouette_score(df2_norm_tsne_full, cluster_assignments_3d)
print(score)
# Out:
# 0.28702712

# %%
# %%time
# run GMM with 3 Dimensions and 5 clusters for visualization
gmm = GaussianMixture(n_components=5, n_init=1, random_state=0)
gmm.fit(df2_norm_tsne_full)
cluster_assignments_3d = gmm.predict(df2_norm_tsne_full)
# Out:
# CPU times: user 7.9 s, sys: 5.31 s, total: 13.2 s
# Wall time: 5.83 s

# %%
score = silhouette_score(df2_norm_tsne_full, cluster_assignments_3d)
print(score)
# Out:
# 0.26729098

# %%
pd.to_pickle(df2_norm_tsne_full,"sony_music_tsne_gmm.pkl")

# %%
#random subsample
r = np.random.random_integers(0,df2_norm_tsne_full.shape[0],1000)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: This function is deprecated. Please call randint(0, 648894 + 1) instead

# %%
df2_sample = df2_norm_tsne_full[r]

# %%
df2_sample.shape
# Out:
# (1000, 3)

# %%
# plot 3D Clusters
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(221, projection='3d')
ax.scatter(df2_norm_tsne_full[:, 0], df2_norm_tsne_full[:, 1], df2_norm_tsne_full[:, 2], c=cluster_assignments_3d, cmap='Spectral')
ax.title.set_text('3D Plot')
# plot 3D Clusters in 2D (1)
ax1 = fig.add_subplot(222)
ax1.scatter(df2_norm_tsne_full[:, 0], df2_norm_tsne_full[:, 1], c=cluster_assignments_3d, cmap='Spectral')
ax1.title.set_text('2D Plot (1)')
# plot 3D Clusters in 2D (2)
ax2 = fig.add_subplot(223)
ax2.scatter(df2_norm_tsne_full[:, 0], df2_norm_tsne_full[:, 2], c=cluster_assignments_3d, cmap='Spectral')
ax2.title.set_text('2D Plot (2)')
# plot 3D Clusters in 2D (3)
ax3 = fig.add_subplot(224)
ax3.scatter(df2_norm_tsne_full[:, 1], df2_norm_tsne_full[:, 2], c=cluster_assignments_3d, cmap='Spectral')
ax3.title.set_text('2D Plot (3)')
plt.show()

# %%
# plot 3D Clusters
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(221, projection='3d')
ax.scatter(df2_sample[:, 0], df2_sample[:, 1], df2_sample[:, 2], c=cluster_assignments_3d[r], cmap='Spectral')
ax.title.set_text('3D Plot')
# plot 3D Clusters in 2D (1)
ax1 = fig.add_subplot(222)
ax1.scatter(df2_sample[:, 0], df2_sample[:, 1], c=cluster_assignments_3d[r], cmap='Spectral')
ax1.title.set_text('2D Plot (1)')
# plot 3D Clusters in 2D (2)
ax2 = fig.add_subplot(223)
ax2.scatter(df2_sample[:, 0], df2_sample[:, 2], c=cluster_assignments_3d[r], cmap='Spectral')
ax2.title.set_text('2D Plot (2)')
# plot 3D Clusters in 2D (3)
ax3 = fig.add_subplot(224)
ax3.scatter(df2_sample[:, 1], df2_sample[:, 2], c=cluster_assignments_3d[r], cmap='Spectral')
ax3.title.set_text('2D Plot (3)')
plt.show()

# %%
#Going with 6 clusters
df['Cluster'] = cluster_assignments_3d.tolist()

# %% [markdown]
# ## Calculate Artist Distribution in each Cluster

# %%
# convert clusters to dummy variables
# this df has cluster per post: ready for qualitative analysis 
df1 = df.copy()
df_cluster_ohe = pd.get_dummies(df1["Cluster"],prefix='cluster')
df1_dropcluster = df1.drop(['Cluster'], axis=1)
df_with_clusters = pd.concat([df1_dropcluster, df_cluster_ohe], axis=1)
df_with_clusters.head().T
# Out:
#                                    702          703          704          705  \
# Facebook                             1            1            1            1
# Instagram                            0            0            0            0
# Twitter                              0            0            0            0
# Youtube                              0            0            0            0
# age                                 37           37           37           37
# artist_name_x              AdamLambert  AdamLambert  AdamLambert  AdamLambert
# created_12am-6am                     0            0            0            0
# created_12pm-6pm                     1            1            0            1
# created_6am-12pm                     0            0            1            0
# created_6pm-12am                     0            0            0            0
# description_length                  32           79           73          352
# hashtag_count                        0            2            1            1
# last_30_days                         1            2            4            4
# last_7_days                          1            2            4            4
# time_since_last_post            153999       253878       166567        20084
# type_link                            0            0            1            0
# type_photo                           1            0            0            1
# type_text                            0            0            0            0
# type_video                           0            1            0            0
# years_active                        18           18           18           18
# num_days_to_track_release           76           73           71           71
# genre_electronic                     0            0            0            0
# genre_hip_hop                        0            0            0            0
# genre_pop                            1            1            1            1
# genre_r_and_b                        0            0            0            0
# genre_rock                           1            1            1            1
# genre_world_music                    0            0            0            0
# cluster_0                            1            0            0            1
# cluster_1                            0            0            0            0
# cluster_2                            0            0            0            0
# cluster_3                            0            0            1            0
# cluster_4                            0            1            0            0
# cluster_5                            0            0            0            0
#
#                                    706
# Facebook                             1
# Instagram                            0
# Twitter                              0
# Youtube                              0
# age                                 37
# artist_name_x              AdamLambert
# created_12am-6am                     0
# created_12pm-6pm                     1
# created_6am-12pm                     0
# created_6pm-12am                     0
# description_length                  94
# hashtag_count                        0
# last_30_days                         5
# last_7_days                          5
# time_since_last_post             84560
# type_link                            1
# type_photo                           0
# type_text                            0
# type_video                           0
# years_active                        18
# num_days_to_track_release           70
# genre_electronic                     0
# genre_hip_hop                        0
# genre_pop                            1
# genre_r_and_b                        0
# genre_rock                           1
# genre_world_music                    0
# cluster_0                            0
# cluster_1                            0
# cluster_2                            0
# cluster_3                            1
# cluster_4                            0
# cluster_5                            0

# %%
pd.to_pickle(df_with_clusters,"sony_music_tsne_gmm_dfCluster.pkl")

# %%
# create df with each artists distribution across each cluster
# this df has distribution of each artist by cluster: ready for qualitative analysis 
df_artists = df[['artist_name_x', 'Cluster']]
df1_artists = df_artists.copy()
df1_artists_ohe = pd.get_dummies(df1_artists["Cluster"],prefix='cluster')
df1_artists_dropcluster = df1_artists.drop(['Cluster'], axis=1)
df_artists_by_cluster = pd.concat([df1_artists_dropcluster, df1_artists_ohe], axis=1)
cluster_columns = df_artists_by_cluster.drop(['artist_name_x'], axis=1).columns.values.tolist()
# sum cluster count grouped by artist
df_artists_by_cluster = df_artists_by_cluster.groupby(['artist_name_x']).sum()
df_artists_by_cluster['clusters_sum'] = df_artists_by_cluster.sum(axis=1)
for c in cluster_columns:
    df_artists_by_cluster[c] = df_artists_by_cluster[c]/df_artists_by_cluster['clusters_sum']
df_artists_by_cluster = df_artists_by_cluster.drop(['clusters_sum'], axis=1)
df_artists_by_cluster.head()
# Out:
#                cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  \
# artist_name_x
# 1future         0.208024   0.050520   0.075037   0.097325   0.388559
# 21savage        0.028769   0.246260   0.300345   0.135788   0.243959
# ASAPferg        0.247074   0.086801   0.210338   0.162549   0.173602
# AdamLambert     0.306283   0.164921   0.159686   0.125654   0.201571
# Adele           0.311475   0.065574   0.065574   0.065574   0.344262
#
#                cluster_5
# artist_name_x
# 1future         0.180535
# 21savage        0.044879
# ASAPferg        0.119636
# AdamLambert     0.041885
# Adele           0.147541
